# %%
import os
from pathlib import Path
import nibabel as nib
import numpy as np
from PIL import Image

# Define the source directory for the dataset
dataset_dir = r"E:\CAMUS_public\CAMUS_public\dataset"

def create_png_directory_structure(base_dir):
    """Create the required directory structure for PNG images."""
    png_base = os.path.join(os.path.dirname(base_dir), "dataset_png")
    for split in ['train', 'valid', 'test']:
        for subdir in ['images', 'labels']:
            Path(os.path.join(png_base, split, subdir)).mkdir(parents=True, exist_ok=True)
    return png_base

def normalize_array(array):
    """Normalize array to 0-255 range for PNG conversion."""
    min_val = np.min(array)
    max_val = np.max(array)
    if max_val == min_val:
        return np.zeros_like(array)
    normalized = ((array - min_val) * 255 / (max_val - min_val)).astype(np.uint8)
    return normalized

def convert_nifti_to_png(nifti_path, png_path):
    """Convert a single NIfTI file to PNG."""
    # Load NIfTI file
    nifti_img = nib.load(nifti_path)
    # Get data array
    data = nifti_img.get_fdata()
    
    # If 3D, take the middle slice
    if len(data.shape) == 3:
        middle_slice = data.shape[2] // 2
        data = data[:, :, middle_slice]
    
    # Normalize the data to 0-255 range
    normalized_data = normalize_array(data)
    
    # Create PIL Image and save as PNG
    img = Image.fromarray(normalized_data)
    img.save(png_path)

def convert_dataset(nifti_base_dir, png_base_dir):
    """Convert all NIfTI files in the dataset to PNG format."""
    for split in ['train', 'valid', 'test']:
        for subdir in ['images', 'labels']:
            nifti_dir = os.path.join(nifti_base_dir, split, subdir)
            png_dir = os.path.join(png_base_dir, split, subdir)
            
            # Skip if source directory doesn't exist
            if not os.path.exists(nifti_dir):
                print(f"Directory not found: {nifti_dir}")
                continue
                
            # Process each NIfTI file
            print(f"Processing {split}/{subdir}...")
            for filename in os.listdir(nifti_dir):
                if filename.endswith('.nii'):
                    nifti_path = os.path.join(nifti_dir, filename)
                    png_path = os.path.join(png_dir, filename.replace('.nii', '.png'))
                    
                    try:
                        convert_nifti_to_png(nifti_path, png_path)
                        print(f"Converted: {filename}")
                    except Exception as e:
                        print(f"Error converting {filename}: {str(e)}")

def main():
    # Create PNG dataset directory structure
    png_base_dir = create_png_directory_structure(dataset_dir)
    
    # Convert all files
    convert_dataset(dataset_dir, png_base_dir)
    
    # Print summary
    print("\nConversion Summary:")
    for split in ['train', 'valid', 'test']:
        img_count = len([f for f in os.listdir(os.path.join(png_base_dir, split, 'images')) 
                        if f.endswith('.png')])
        label_count = len([f for f in os.listdir(os.path.join(png_base_dir, split, 'labels'))
                          if f.endswith('.png')])
        print(f"{split.capitalize()} set: {img_count} images, {label_count} labels converted to PNG")

if __name__ == "__main__":
    main()
# Out:
# Processing train/images...
# Converted: patient0001_4CH_ES.nii
# Converted: patient0001_4CH_ED.nii
# Converted: patient0002_4CH_ES.nii
# Converted: patient0002_4CH_ED.nii
# Converted: patient0003_4CH_ES.nii
# Converted: patient0003_4CH_ED.nii
# Converted: patient0004_4CH_ES.nii
# Converted: patient0004_4CH_ED.nii
# Converted: patient0005_4CH_ES.nii
# Converted: patient0005_4CH_ED.nii
# Converted: patient0006_4CH_ES.nii
# Converted: patient0006_4CH_ED.nii
# Converted: patient0007_4CH_ES.nii
# Converted: patient0007_4CH_ED.nii
# Converted: patient0008_4CH_ES.nii
# Converted: patient0008_4CH_ED.nii
# Converted: patient0009_4CH_ES.nii
# Converted: patient0009_4CH_ED.nii
# Converted: patient0010_4CH_ES.nii
# Converted: patient0010_4CH_ED.nii
# Converted: patient0011_4CH_ES.nii
# Converted: patient0011_4CH_ED.nii
# Converted: patient0012_4CH_ES.nii
# Converted: patient0012_4CH_ED.nii
# Converted: patient0013_4CH_ES.nii
# Converted: patient0013_4CH_ED.nii
# Converted: patient0014_4CH_ES.nii
# Converted: patient0014_4CH_ED.nii
# Converted: patient0015_4CH_ES.nii
# Converted: patient0015_4CH_ED.nii
# Converted: patient0016_4CH_ES.nii
# Converted: patient0016_4CH_ED.nii
# Converted: patient0017_4CH_ES.nii
# Converted: patient0017_4CH_ED.nii
# Converted: patient0018_4CH_ES.nii
# Converted: patient0018_4CH_ED.nii
# Converted: patient0019_4CH_ES.nii
# Converted: patient0019_4CH_ED.nii
# Converted: patient0020_4CH_ES.nii
# Converted: patient0020_4CH_ED.nii
# Converted: patient0021_4CH_ES.nii
# Converted: patient0021_4CH_ED.nii
# Converted: patient0022_4CH_ES.nii
# Converted: patient0022_4CH_ED.nii
# Converted: patient0023_4CH_ES.nii
# Converted: patient0023_4CH_ED.nii
# Converted: patient0024_4CH_ES.nii
# Converted: patient0024_4CH_ED.nii
# Converted: patient0025_4CH_ES.nii
# Converted: patient0025_4CH_ED.nii
# Converted: patient0026_4CH_ES.nii
# Converted: patient0026_4CH_ED.nii
# Converted: patient0028_4CH_ES.nii
# Converted: patient0028_4CH_ED.nii
# Converted: patient0029_4CH_ES.nii
# Converted: patient0029_4CH_ED.nii
# Converted: patient0030_4CH_ES.nii
# Converted: patient0030_4CH_ED.nii
# Converted: patient0031_4CH_ES.nii
# Converted: patient0031_4CH_ED.nii
# Converted: patient0032_4CH_ES.nii
# Converted: patient0032_4CH_ED.nii
# Converted: patient0033_4CH_ES.nii
# Converted: patient0033_4CH_ED.nii
# Converted: patient0034_4CH_ES.nii
# Converted: patient0034_4CH_ED.nii
# Converted: patient0035_4CH_ES.nii
# Converted: patient0035_4CH_ED.nii
# Converted: patient0036_4CH_ES.nii
# Converted: patient0036_4CH_ED.nii
# Converted: patient0037_4CH_ES.nii
# Converted: patient0037_4CH_ED.nii
# Converted: patient0038_4CH_ES.nii
# Converted: patient0038_4CH_ED.nii
# Converted: patient0039_4CH_ES.nii
# Converted: patient0039_4CH_ED.nii
# Converted: patient0040_4CH_ES.nii
# Converted: patient0040_4CH_ED.nii
# Converted: patient0041_4CH_ES.nii
# Converted: patient0041_4CH_ED.nii
# Converted: patient0042_4CH_ES.nii
# Converted: patient0042_4CH_ED.nii
# Converted: patient0043_4CH_ES.nii
# Converted: patient0043_4CH_ED.nii
# Converted: patient0044_4CH_ES.nii
# Converted: patient0044_4CH_ED.nii
# Converted: patient0045_4CH_ES.nii
# Converted: patient0045_4CH_ED.nii
# Converted: patient0046_4CH_ES.nii
# Converted: patient0046_4CH_ED.nii
# Converted: patient0048_4CH_ES.nii
# Converted: patient0048_4CH_ED.nii
# Converted: patient0049_4CH_ES.nii
# Converted: patient0049_4CH_ED.nii
# Converted: patient0050_4CH_ES.nii
# Converted: patient0050_4CH_ED.nii
# Converted: patient0053_4CH_ES.nii
# Converted: patient0053_4CH_ED.nii
# Converted: patient0054_4CH_ES.nii
# Converted: patient0054_4CH_ED.nii
# Converted: patient0055_4CH_ES.nii
# Converted: patient0055_4CH_ED.nii
# Converted: patient0056_4CH_ES.nii
# Converted: patient0056_4CH_ED.nii
# Converted: patient0057_4CH_ES.nii
# Converted: patient0057_4CH_ED.nii
# Converted: patient0058_4CH_ES.nii
# Converted: patient0058_4CH_ED.nii
# Converted: patient0059_4CH_ES.nii
# Converted: patient0059_4CH_ED.nii
# Converted: patient0060_4CH_ES.nii
# Converted: patient0060_4CH_ED.nii
# Converted: patient0061_4CH_ES.nii
# Converted: patient0061_4CH_ED.nii
# Converted: patient0062_4CH_ES.nii
# Converted: patient0062_4CH_ED.nii
# Converted: patient0063_4CH_ES.nii
# Converted: patient0063_4CH_ED.nii
# Converted: patient0064_4CH_ES.nii
# Converted: patient0064_4CH_ED.nii
# Converted: patient0065_4CH_ES.nii
# Converted: patient0065_4CH_ED.nii
# Converted: patient0066_4CH_ES.nii
# Converted: patient0066_4CH_ED.nii
# Converted: patient0067_4CH_ES.nii
# Converted: patient0067_4CH_ED.nii
# Converted: patient0068_4CH_ES.nii
# Converted: patient0068_4CH_ED.nii
# Converted: patient0069_4CH_ES.nii
# Converted: patient0069_4CH_ED.nii
# Converted: patient0070_4CH_ES.nii
# Converted: patient0070_4CH_ED.nii
# Converted: patient0071_4CH_ES.nii
# Converted: patient0071_4CH_ED.nii
# Converted: patient0072_4CH_ES.nii
# Converted: patient0072_4CH_ED.nii
# Converted: patient0073_4CH_ES.nii
# Converted: patient0073_4CH_ED.nii
# Converted: patient0074_4CH_ES.nii
# Converted: patient0074_4CH_ED.nii
# Converted: patient0075_4CH_ES.nii
# Converted: patient0075_4CH_ED.nii
# Converted: patient0076_4CH_ES.nii
# Converted: patient0076_4CH_ED.nii
# Converted: patient0077_4CH_ES.nii
# Converted: patient0077_4CH_ED.nii
# Converted: patient0078_4CH_ES.nii
# Converted: patient0078_4CH_ED.nii
# Converted: patient0079_4CH_ES.nii
# Converted: patient0079_4CH_ED.nii
# Converted: patient0080_4CH_ES.nii
# Converted: patient0080_4CH_ED.nii
# Converted: patient0081_4CH_ES.nii
# Converted: patient0081_4CH_ED.nii
# Converted: patient0082_4CH_ES.nii
# Converted: patient0082_4CH_ED.nii
# Converted: patient0083_4CH_ES.nii
# Converted: patient0083_4CH_ED.nii
# Converted: patient0084_4CH_ES.nii
# Converted: patient0084_4CH_ED.nii
# Converted: patient0085_4CH_ES.nii
# Converted: patient0085_4CH_ED.nii
# Converted: patient0086_4CH_ES.nii
# Converted: patient0086_4CH_ED.nii
# Converted: patient0087_4CH_ES.nii
# Converted: patient0087_4CH_ED.nii
# Converted: patient0088_4CH_ES.nii
# Converted: patient0088_4CH_ED.nii
# Converted: patient0089_4CH_ES.nii
# Converted: patient0089_4CH_ED.nii
# Converted: patient0090_4CH_ES.nii
# Converted: patient0090_4CH_ED.nii
# Converted: patient0091_4CH_ES.nii
# Converted: patient0091_4CH_ED.nii
# Converted: patient0092_4CH_ES.nii
# Converted: patient0092_4CH_ED.nii
# Converted: patient0093_4CH_ES.nii
# Converted: patient0093_4CH_ED.nii
# Converted: patient0094_4CH_ES.nii
# Converted: patient0094_4CH_ED.nii
# Converted: patient0095_4CH_ES.nii
# Converted: patient0095_4CH_ED.nii
# Converted: patient0096_4CH_ES.nii
# Converted: patient0096_4CH_ED.nii
# Converted: patient0097_4CH_ES.nii
# Converted: patient0097_4CH_ED.nii
# Converted: patient0098_4CH_ES.nii
# Converted: patient0098_4CH_ED.nii
# Converted: patient0099_4CH_ES.nii
# Converted: patient0099_4CH_ED.nii
# Converted: patient0100_4CH_ES.nii
# Converted: patient0100_4CH_ED.nii
# Converted: patient0101_4CH_ES.nii
# Converted: patient0101_4CH_ED.nii
# Converted: patient0102_4CH_ES.nii
# Converted: patient0102_4CH_ED.nii
# Converted: patient0103_4CH_ES.nii
# Converted: patient0103_4CH_ED.nii
# Converted: patient0104_4CH_ES.nii
# Converted: patient0104_4CH_ED.nii
# Converted: patient0105_4CH_ES.nii
# Converted: patient0105_4CH_ED.nii
# Converted: patient0106_4CH_ES.nii
# Converted: patient0106_4CH_ED.nii
# Converted: patient0107_4CH_ES.nii
# Converted: patient0107_4CH_ED.nii
# Converted: patient0108_4CH_ES.nii
# Converted: patient0108_4CH_ED.nii
# Converted: patient0109_4CH_ES.nii
# Converted: patient0109_4CH_ED.nii
# Converted: patient0110_4CH_ES.nii
# Converted: patient0110_4CH_ED.nii
# Converted: patient0111_4CH_ES.nii
# Converted: patient0111_4CH_ED.nii
# Converted: patient0112_4CH_ES.nii
# Converted: patient0112_4CH_ED.nii
# Converted: patient0113_4CH_ES.nii
# Converted: patient0113_4CH_ED.nii
# Converted: patient0114_4CH_ES.nii
# Converted: patient0114_4CH_ED.nii
# Converted: patient0115_4CH_ES.nii
# Converted: patient0115_4CH_ED.nii
# Converted: patient0116_4CH_ES.nii
# Converted: patient0116_4CH_ED.nii
# Converted: patient0117_4CH_ES.nii
# Converted: patient0117_4CH_ED.nii
# Converted: patient0118_4CH_ES.nii
# Converted: patient0118_4CH_ED.nii
# Converted: patient0119_4CH_ES.nii
# Converted: patient0119_4CH_ED.nii
# Converted: patient0120_4CH_ES.nii
# Converted: patient0120_4CH_ED.nii
# Converted: patient0121_4CH_ES.nii
# Converted: patient0121_4CH_ED.nii
# Converted: patient0122_4CH_ES.nii
# Converted: patient0122_4CH_ED.nii
# Converted: patient0123_4CH_ES.nii
# Converted: patient0123_4CH_ED.nii
# Converted: patient0124_4CH_ES.nii
# Converted: patient0124_4CH_ED.nii
# Converted: patient0125_4CH_ES.nii
# Converted: patient0125_4CH_ED.nii
# Converted: patient0126_4CH_ES.nii
# Converted: patient0126_4CH_ED.nii
# Converted: patient0127_4CH_ES.nii
# Converted: patient0127_4CH_ED.nii
# Converted: patient0128_4CH_ES.nii
# Converted: patient0128_4CH_ED.nii
# Converted: patient0129_4CH_ES.nii
# Converted: patient0129_4CH_ED.nii
# Converted: patient0130_4CH_ES.nii
# Converted: patient0130_4CH_ED.nii
# Converted: patient0131_4CH_ES.nii
# Converted: patient0131_4CH_ED.nii
# Converted: patient0132_4CH_ES.nii
# Converted: patient0132_4CH_ED.nii
# Converted: patient0133_4CH_ES.nii
# Converted: patient0133_4CH_ED.nii
# Converted: patient0134_4CH_ES.nii
# Converted: patient0134_4CH_ED.nii
# Converted: patient0135_4CH_ES.nii
# Converted: patient0135_4CH_ED.nii
# Converted: patient0136_4CH_ES.nii
# Converted: patient0136_4CH_ED.nii
# Converted: patient0137_4CH_ES.nii
# Converted: patient0137_4CH_ED.nii
# Converted: patient0138_4CH_ES.nii
# Converted: patient0138_4CH_ED.nii
# Converted: patient0139_4CH_ES.nii
# Converted: patient0139_4CH_ED.nii
# Converted: patient0140_4CH_ES.nii
# Converted: patient0140_4CH_ED.nii
# Converted: patient0141_4CH_ES.nii
# Converted: patient0141_4CH_ED.nii
# Converted: patient0142_4CH_ES.nii
# Converted: patient0142_4CH_ED.nii
# Converted: patient0143_4CH_ES.nii
# Converted: patient0143_4CH_ED.nii
# Converted: patient0144_4CH_ES.nii
# Converted: patient0144_4CH_ED.nii
# Converted: patient0145_4CH_ES.nii
# Converted: patient0145_4CH_ED.nii
# Converted: patient0146_4CH_ES.nii
# Converted: patient0146_4CH_ED.nii
# Converted: patient0147_4CH_ES.nii
# Converted: patient0147_4CH_ED.nii
# Converted: patient0148_4CH_ES.nii
# Converted: patient0148_4CH_ED.nii
# Converted: patient0149_4CH_ES.nii
# Converted: patient0149_4CH_ED.nii
# Converted: patient0150_4CH_ES.nii
# Converted: patient0150_4CH_ED.nii
# Converted: patient0151_4CH_ES.nii
# Converted: patient0151_4CH_ED.nii
# Converted: patient0152_4CH_ES.nii
# Converted: patient0152_4CH_ED.nii
# Converted: patient0153_4CH_ES.nii
# Converted: patient0153_4CH_ED.nii
# Converted: patient0154_4CH_ES.nii
# Converted: patient0154_4CH_ED.nii
# Converted: patient0155_4CH_ES.nii
# Converted: patient0155_4CH_ED.nii
# Converted: patient0156_4CH_ES.nii
# Converted: patient0156_4CH_ED.nii
# Converted: patient0157_4CH_ES.nii
# Converted: patient0157_4CH_ED.nii
# Converted: patient0158_4CH_ES.nii
# Converted: patient0158_4CH_ED.nii
# Converted: patient0159_4CH_ES.nii
# Converted: patient0159_4CH_ED.nii
# Converted: patient0160_4CH_ES.nii
# Converted: patient0160_4CH_ED.nii
# Converted: patient0161_4CH_ES.nii
# Converted: patient0161_4CH_ED.nii
# Converted: patient0162_4CH_ES.nii
# Converted: patient0162_4CH_ED.nii
# Converted: patient0163_4CH_ES.nii
# Converted: patient0163_4CH_ED.nii
# Converted: patient0164_4CH_ES.nii
# Converted: patient0164_4CH_ED.nii
# Converted: patient0165_4CH_ES.nii
# Converted: patient0165_4CH_ED.nii
# Converted: patient0166_4CH_ES.nii
# Converted: patient0166_4CH_ED.nii
# Converted: patient0167_4CH_ES.nii
# Converted: patient0167_4CH_ED.nii
# Converted: patient0168_4CH_ES.nii
# Converted: patient0168_4CH_ED.nii
# Converted: patient0169_4CH_ES.nii
# Converted: patient0169_4CH_ED.nii
# Converted: patient0170_4CH_ES.nii
# Converted: patient0170_4CH_ED.nii
# Converted: patient0171_4CH_ES.nii
# Converted: patient0171_4CH_ED.nii
# Converted: patient0172_4CH_ES.nii
# Converted: patient0172_4CH_ED.nii
# Converted: patient0173_4CH_ES.nii
# Converted: patient0173_4CH_ED.nii
# Converted: patient0174_4CH_ES.nii
# Converted: patient0174_4CH_ED.nii
# Converted: patient0175_4CH_ES.nii
# Converted: patient0175_4CH_ED.nii
# Converted: patient0176_4CH_ES.nii
# Converted: patient0176_4CH_ED.nii
# Converted: patient0177_4CH_ES.nii
# Converted: patient0177_4CH_ED.nii
# Converted: patient0178_4CH_ES.nii
# Converted: patient0178_4CH_ED.nii
# Converted: patient0179_4CH_ES.nii
# Converted: patient0179_4CH_ED.nii
# Converted: patient0180_4CH_ES.nii
# Converted: patient0180_4CH_ED.nii
# Converted: patient0181_4CH_ES.nii
# Converted: patient0181_4CH_ED.nii
# Converted: patient0182_4CH_ES.nii
# Converted: patient0182_4CH_ED.nii
# Converted: patient0183_4CH_ES.nii
# Converted: patient0183_4CH_ED.nii
# Converted: patient0184_4CH_ES.nii
# Converted: patient0184_4CH_ED.nii
# Converted: patient0185_4CH_ES.nii
# Converted: patient0185_4CH_ED.nii
# Converted: patient0186_4CH_ES.nii
# Converted: patient0186_4CH_ED.nii
# Converted: patient0188_4CH_ES.nii
# Converted: patient0188_4CH_ED.nii
# Converted: patient0190_4CH_ES.nii
# Converted: patient0190_4CH_ED.nii
# Converted: patient0192_4CH_ES.nii
# Converted: patient0192_4CH_ED.nii
# Converted: patient0193_4CH_ES.nii
# Converted: patient0193_4CH_ED.nii
# Converted: patient0195_4CH_ES.nii
# Converted: patient0195_4CH_ED.nii
# Converted: patient0196_4CH_ES.nii
# Converted: patient0196_4CH_ED.nii
# Converted: patient0198_4CH_ES.nii
# Converted: patient0198_4CH_ED.nii
# Converted: patient0202_4CH_ES.nii
# Converted: patient0202_4CH_ED.nii
# Converted: patient0203_4CH_ES.nii
# Converted: patient0203_4CH_ED.nii
# Converted: patient0204_4CH_ES.nii
# Converted: patient0204_4CH_ED.nii
# Converted: patient0205_4CH_ES.nii
# Converted: patient0205_4CH_ED.nii
# Converted: patient0207_4CH_ES.nii
# Converted: patient0207_4CH_ED.nii
# Converted: patient0209_4CH_ES.nii
# Converted: patient0209_4CH_ED.nii
# Converted: patient0210_4CH_ES.nii
# Converted: patient0210_4CH_ED.nii
# Converted: patient0211_4CH_ES.nii
# Converted: patient0211_4CH_ED.nii
# Converted: patient0212_4CH_ES.nii
# Converted: patient0212_4CH_ED.nii
# Converted: patient0216_4CH_ES.nii
# Converted: patient0216_4CH_ED.nii
# Converted: patient0222_4CH_ES.nii
# Converted: patient0222_4CH_ED.nii
# Converted: patient0229_4CH_ES.nii
# Converted: patient0229_4CH_ED.nii
# Converted: patient0274_4CH_ES.nii
# Converted: patient0274_4CH_ED.nii
# Converted: patient0277_4CH_ES.nii
# Converted: patient0277_4CH_ED.nii
# Converted: patient0278_4CH_ES.nii
# Converted: patient0278_4CH_ED.nii
# Converted: patient0281_4CH_ES.nii
# Converted: patient0281_4CH_ED.nii
# Converted: patient0285_4CH_ES.nii
# Converted: patient0285_4CH_ED.nii
# Converted: patient0293_4CH_ES.nii
# Converted: patient0293_4CH_ED.nii
# Converted: patient0295_4CH_ES.nii
# Converted: patient0295_4CH_ED.nii
# Converted: patient0296_4CH_ES.nii
# Converted: patient0296_4CH_ED.nii
# Converted: patient0300_4CH_ES.nii
# Converted: patient0300_4CH_ED.nii
# Converted: patient0301_4CH_ES.nii
# Converted: patient0301_4CH_ED.nii
# Converted: patient0302_4CH_ES.nii
# Converted: patient0302_4CH_ED.nii
# Converted: patient0306_4CH_ES.nii
# Converted: patient0306_4CH_ED.nii
# Converted: patient0307_4CH_ES.nii
# Converted: patient0307_4CH_ED.nii
# Converted: patient0309_4CH_ES.nii
# Converted: patient0309_4CH_ED.nii
# Converted: patient0310_4CH_ES.nii
# Converted: patient0310_4CH_ED.nii
# Converted: patient0311_4CH_ES.nii
# Converted: patient0311_4CH_ED.nii
# Converted: patient0312_4CH_ES.nii
# Converted: patient0312_4CH_ED.nii
# Converted: patient0313_4CH_ES.nii
# Converted: patient0313_4CH_ED.nii
# Converted: patient0316_4CH_ES.nii
# Converted: patient0316_4CH_ED.nii
# Converted: patient0317_4CH_ES.nii
# Converted: patient0317_4CH_ED.nii
# Converted: patient0318_4CH_ES.nii
# Converted: patient0318_4CH_ED.nii
# Converted: patient0319_4CH_ES.nii
# Converted: patient0319_4CH_ED.nii
# Converted: patient0320_4CH_ES.nii
# Converted: patient0320_4CH_ED.nii
# Converted: patient0321_4CH_ES.nii
# Converted: patient0321_4CH_ED.nii
# Converted: patient0322_4CH_ES.nii
# Converted: patient0322_4CH_ED.nii
# Converted: patient0323_4CH_ES.nii
# Converted: patient0323_4CH_ED.nii
# Converted: patient0324_4CH_ES.nii
# Converted: patient0324_4CH_ED.nii
# Converted: patient0325_4CH_ES.nii
# Converted: patient0325_4CH_ED.nii
# Converted: patient0326_4CH_ES.nii
# Converted: patient0326_4CH_ED.nii
# Converted: patient0327_4CH_ES.nii
# Converted: patient0327_4CH_ED.nii
# Converted: patient0329_4CH_ES.nii
# Converted: patient0329_4CH_ED.nii
# Converted: patient0330_4CH_ES.nii
# Converted: patient0330_4CH_ED.nii
# Converted: patient0331_4CH_ES.nii
# Converted: patient0331_4CH_ED.nii
# Converted: patient0332_4CH_ES.nii
# Converted: patient0332_4CH_ED.nii
# Converted: patient0335_4CH_ES.nii
# Converted: patient0335_4CH_ED.nii
# Converted: patient0336_4CH_ES.nii
# Converted: patient0336_4CH_ED.nii
# Converted: patient0337_4CH_ES.nii
# Converted: patient0337_4CH_ED.nii
# Converted: patient0338_4CH_ES.nii
# Converted: patient0338_4CH_ED.nii
# Converted: patient0339_4CH_ES.nii
# Converted: patient0339_4CH_ED.nii
# Converted: patient0340_4CH_ES.nii
# Converted: patient0340_4CH_ED.nii
# Converted: patient0342_4CH_ES.nii
# Converted: patient0342_4CH_ED.nii
# Converted: patient0343_4CH_ES.nii
# Converted: patient0343_4CH_ED.nii
# Converted: patient0344_4CH_ES.nii
# Converted: patient0344_4CH_ED.nii
# Converted: patient0345_4CH_ES.nii
# Converted: patient0345_4CH_ED.nii
# Converted: patient0346_4CH_ES.nii
# Converted: patient0346_4CH_ED.nii
# Converted: patient0347_4CH_ES.nii
# Converted: patient0347_4CH_ED.nii
# Converted: patient0348_4CH_ES.nii
# Converted: patient0348_4CH_ED.nii
# Converted: patient0349_4CH_ES.nii
# Converted: patient0349_4CH_ED.nii
# Converted: patient0350_4CH_ES.nii
# Converted: patient0350_4CH_ED.nii
# Converted: patient0351_4CH_ES.nii
# Converted: patient0351_4CH_ED.nii
# Converted: patient0352_4CH_ES.nii
# Converted: patient0352_4CH_ED.nii
# Converted: patient0353_4CH_ES.nii
# Converted: patient0353_4CH_ED.nii
# Converted: patient0354_4CH_ES.nii
# Converted: patient0354_4CH_ED.nii
# Converted: patient0355_4CH_ES.nii
# Converted: patient0355_4CH_ED.nii
# Converted: patient0356_4CH_ES.nii
# Converted: patient0356_4CH_ED.nii
# Converted: patient0357_4CH_ES.nii
# Converted: patient0357_4CH_ED.nii
# Converted: patient0358_4CH_ES.nii
# Converted: patient0358_4CH_ED.nii
# Converted: patient0359_4CH_ES.nii
# Converted: patient0359_4CH_ED.nii
# Converted: patient0360_4CH_ES.nii
# Converted: patient0360_4CH_ED.nii
# Converted: patient0361_4CH_ES.nii
# Converted: patient0361_4CH_ED.nii
# Converted: patient0362_4CH_ES.nii
# Converted: patient0362_4CH_ED.nii
# Converted: patient0363_4CH_ES.nii
# Converted: patient0363_4CH_ED.nii
# Converted: patient0364_4CH_ES.nii
# Converted: patient0364_4CH_ED.nii
# Converted: patient0365_4CH_ES.nii
# Converted: patient0365_4CH_ED.nii
# Converted: patient0366_4CH_ES.nii
# Converted: patient0366_4CH_ED.nii
# Converted: patient0367_4CH_ES.nii
# Converted: patient0367_4CH_ED.nii
# Converted: patient0368_4CH_ES.nii
# Converted: patient0368_4CH_ED.nii
# Converted: patient0369_4CH_ES.nii
# Converted: patient0369_4CH_ED.nii
# Converted: patient0370_4CH_ES.nii
# Converted: patient0370_4CH_ED.nii
# Converted: patient0371_4CH_ES.nii
# Converted: patient0371_4CH_ED.nii
# Converted: patient0372_4CH_ES.nii
# Converted: patient0372_4CH_ED.nii
# Converted: patient0373_4CH_ES.nii
# Converted: patient0373_4CH_ED.nii
# Converted: patient0374_4CH_ES.nii
# Converted: patient0374_4CH_ED.nii
# Converted: patient0375_4CH_ES.nii
# Converted: patient0375_4CH_ED.nii
# Converted: patient0376_4CH_ES.nii
# Converted: patient0376_4CH_ED.nii
# Converted: patient0377_4CH_ES.nii
# Converted: patient0377_4CH_ED.nii
# Converted: patient0378_4CH_ES.nii
# Converted: patient0378_4CH_ED.nii
# Converted: patient0379_4CH_ES.nii
# Converted: patient0379_4CH_ED.nii
# Converted: patient0380_4CH_ES.nii
# Converted: patient0380_4CH_ED.nii
# Converted: patient0381_4CH_ES.nii
# Converted: patient0381_4CH_ED.nii
# Converted: patient0382_4CH_ES.nii
# Converted: patient0382_4CH_ED.nii
# Converted: patient0383_4CH_ES.nii
# Converted: patient0383_4CH_ED.nii
# Converted: patient0384_4CH_ES.nii
# Converted: patient0384_4CH_ED.nii
# Converted: patient0385_4CH_ES.nii
# Converted: patient0385_4CH_ED.nii
# Converted: patient0386_4CH_ES.nii
# Converted: patient0386_4CH_ED.nii
# Converted: patient0387_4CH_ES.nii
# Converted: patient0387_4CH_ED.nii
# Converted: patient0388_4CH_ES.nii
# Converted: patient0388_4CH_ED.nii
# Converted: patient0389_4CH_ES.nii
# Converted: patient0389_4CH_ED.nii
# Converted: patient0390_4CH_ES.nii
# Converted: patient0390_4CH_ED.nii
# Converted: patient0391_4CH_ES.nii
# Converted: patient0391_4CH_ED.nii
# Converted: patient0392_4CH_ES.nii
# Converted: patient0392_4CH_ED.nii
# Converted: patient0393_4CH_ES.nii
# Converted: patient0393_4CH_ED.nii
# Converted: patient0394_4CH_ES.nii
# Converted: patient0394_4CH_ED.nii
# Converted: patient0395_4CH_ES.nii
# Converted: patient0395_4CH_ED.nii
# Converted: patient0396_4CH_ES.nii
# Converted: patient0396_4CH_ED.nii
# Converted: patient0397_4CH_ES.nii
# Converted: patient0397_4CH_ED.nii
# Converted: patient0398_4CH_ES.nii
# Converted: patient0398_4CH_ED.nii
# Converted: patient0399_4CH_ES.nii
# Converted: patient0399_4CH_ED.nii
# Converted: patient0400_4CH_ES.nii
# Converted: patient0400_4CH_ED.nii
# Converted: patient0401_4CH_ES.nii
# Converted: patient0401_4CH_ED.nii
# Converted: patient0402_4CH_ES.nii
# Converted: patient0402_4CH_ED.nii
# Converted: patient0403_4CH_ES.nii
# Converted: patient0403_4CH_ED.nii
# Converted: patient0404_4CH_ES.nii
# Converted: patient0404_4CH_ED.nii
# Converted: patient0405_4CH_ES.nii
# Converted: patient0405_4CH_ED.nii
# Converted: patient0406_4CH_ES.nii
# Converted: patient0406_4CH_ED.nii
# Converted: patient0407_4CH_ES.nii
# Converted: patient0407_4CH_ED.nii
# Converted: patient0408_4CH_ES.nii
# Converted: patient0408_4CH_ED.nii
# Converted: patient0409_4CH_ES.nii
# Converted: patient0409_4CH_ED.nii
# Converted: patient0410_4CH_ES.nii
# Converted: patient0410_4CH_ED.nii
# Converted: patient0411_4CH_ES.nii
# Converted: patient0411_4CH_ED.nii
# Converted: patient0412_4CH_ES.nii
# Converted: patient0412_4CH_ED.nii
# Converted: patient0413_4CH_ES.nii
# Converted: patient0413_4CH_ED.nii
# Converted: patient0414_4CH_ES.nii
# Converted: patient0414_4CH_ED.nii
# Converted: patient0415_4CH_ES.nii
# Converted: patient0415_4CH_ED.nii
# Converted: patient0416_4CH_ES.nii
# Converted: patient0416_4CH_ED.nii
# Converted: patient0417_4CH_ES.nii
# Converted: patient0417_4CH_ED.nii
# Converted: patient0418_4CH_ES.nii
# Converted: patient0418_4CH_ED.nii
# Converted: patient0419_4CH_ES.nii
# Converted: patient0419_4CH_ED.nii
# Converted: patient0420_4CH_ES.nii
# Converted: patient0420_4CH_ED.nii
# Converted: patient0421_4CH_ES.nii
# Converted: patient0421_4CH_ED.nii
# Converted: patient0422_4CH_ES.nii
# Converted: patient0422_4CH_ED.nii
# Converted: patient0423_4CH_ES.nii
# Converted: patient0423_4CH_ED.nii
# Converted: patient0424_4CH_ES.nii
# Converted: patient0424_4CH_ED.nii
# Converted: patient0425_4CH_ES.nii
# Converted: patient0425_4CH_ED.nii
# Converted: patient0426_4CH_ES.nii
# Converted: patient0426_4CH_ED.nii
# Converted: patient0427_4CH_ES.nii
# Converted: patient0427_4CH_ED.nii
# Converted: patient0428_4CH_ES.nii
# Converted: patient0428_4CH_ED.nii
# Converted: patient0429_4CH_ES.nii
# Converted: patient0429_4CH_ED.nii
# Converted: patient0430_4CH_ES.nii
# Converted: patient0430_4CH_ED.nii
# Converted: patient0431_4CH_ES.nii
# Converted: patient0431_4CH_ED.nii
# Converted: patient0432_4CH_ES.nii
# Converted: patient0432_4CH_ED.nii
# Converted: patient0433_4CH_ES.nii
# Converted: patient0433_4CH_ED.nii
# Converted: patient0434_4CH_ES.nii
# Converted: patient0434_4CH_ED.nii
# Converted: patient0435_4CH_ES.nii
# Converted: patient0435_4CH_ED.nii
# Converted: patient0436_4CH_ES.nii
# Converted: patient0436_4CH_ED.nii
# Converted: patient0437_4CH_ES.nii
# Converted: patient0437_4CH_ED.nii
# Converted: patient0438_4CH_ES.nii
# Converted: patient0438_4CH_ED.nii
# Converted: patient0439_4CH_ES.nii
# Converted: patient0439_4CH_ED.nii
# Converted: patient0440_4CH_ES.nii
# Converted: patient0440_4CH_ED.nii
# Converted: patient0441_4CH_ES.nii
# Converted: patient0441_4CH_ED.nii
# Converted: patient0442_4CH_ES.nii
# Converted: patient0442_4CH_ED.nii
# Converted: patient0443_4CH_ES.nii
# Converted: patient0443_4CH_ED.nii
# Converted: patient0444_4CH_ES.nii
# Converted: patient0444_4CH_ED.nii
# Converted: patient0445_4CH_ES.nii
# Converted: patient0445_4CH_ED.nii
# Converted: patient0446_4CH_ES.nii
# Converted: patient0446_4CH_ED.nii
# Converted: patient0447_4CH_ES.nii
# Converted: patient0447_4CH_ED.nii
# Converted: patient0448_4CH_ES.nii
# Converted: patient0448_4CH_ED.nii
# Converted: patient0449_4CH_ES.nii
# Converted: patient0449_4CH_ED.nii
# Converted: patient0450_4CH_ES.nii
# Converted: patient0450_4CH_ED.nii
# Converted: patient0451_4CH_ES.nii
# Converted: patient0451_4CH_ED.nii
# Converted: patient0452_4CH_ES.nii
# Converted: patient0452_4CH_ED.nii
# Converted: patient0453_4CH_ES.nii
# Converted: patient0453_4CH_ED.nii
# Converted: patient0454_4CH_ES.nii
# Converted: patient0454_4CH_ED.nii
# Converted: patient0455_4CH_ES.nii
# Converted: patient0455_4CH_ED.nii
# Converted: patient0456_4CH_ES.nii
# Converted: patient0456_4CH_ED.nii
# Converted: patient0457_4CH_ES.nii
# Converted: patient0457_4CH_ED.nii
# Converted: patient0458_4CH_ES.nii
# Converted: patient0458_4CH_ED.nii
# Converted: patient0459_4CH_ES.nii
# Converted: patient0459_4CH_ED.nii
# Converted: patient0460_4CH_ES.nii
# Converted: patient0460_4CH_ED.nii
# Converted: patient0461_4CH_ES.nii
# Converted: patient0461_4CH_ED.nii
# Converted: patient0462_4CH_ES.nii
# Converted: patient0462_4CH_ED.nii
# Converted: patient0463_4CH_ES.nii
# Converted: patient0463_4CH_ED.nii
# Converted: patient0464_4CH_ES.nii
# Converted: patient0464_4CH_ED.nii
# Converted: patient0465_4CH_ES.nii
# Converted: patient0465_4CH_ED.nii
# Converted: patient0466_4CH_ES.nii
# Converted: patient0466_4CH_ED.nii
# Converted: patient0467_4CH_ES.nii
# Converted: patient0467_4CH_ED.nii
# Converted: patient0468_4CH_ES.nii
# Converted: patient0468_4CH_ED.nii
# Converted: patient0469_4CH_ES.nii
# Converted: patient0469_4CH_ED.nii
# Converted: patient0470_4CH_ES.nii
# Converted: patient0470_4CH_ED.nii
# Converted: patient0471_4CH_ES.nii
# Converted: patient0471_4CH_ED.nii
# Converted: patient0472_4CH_ES.nii
# Converted: patient0472_4CH_ED.nii
# Converted: patient0473_4CH_ES.nii
# Converted: patient0473_4CH_ED.nii
# Converted: patient0474_4CH_ES.nii
# Converted: patient0474_4CH_ED.nii
# Converted: patient0475_4CH_ES.nii
# Converted: patient0475_4CH_ED.nii
# Converted: patient0476_4CH_ES.nii
# Converted: patient0476_4CH_ED.nii
# Converted: patient0477_4CH_ES.nii
# Converted: patient0477_4CH_ED.nii
# Converted: patient0478_4CH_ES.nii
# Converted: patient0478_4CH_ED.nii
# Converted: patient0479_4CH_ES.nii
# Converted: patient0479_4CH_ED.nii
# Converted: patient0480_4CH_ES.nii
# Converted: patient0480_4CH_ED.nii
# Converted: patient0481_4CH_ES.nii
# Converted: patient0481_4CH_ED.nii
# Converted: patient0482_4CH_ES.nii
# Converted: patient0482_4CH_ED.nii
# Converted: patient0483_4CH_ES.nii
# Converted: patient0483_4CH_ED.nii
# Converted: patient0484_4CH_ES.nii
# Converted: patient0484_4CH_ED.nii
# Converted: patient0485_4CH_ES.nii
# Converted: patient0485_4CH_ED.nii
# Converted: patient0486_4CH_ES.nii
# Converted: patient0486_4CH_ED.nii
# Converted: patient0487_4CH_ES.nii
# Converted: patient0487_4CH_ED.nii
# Converted: patient0488_4CH_ES.nii
# Converted: patient0488_4CH_ED.nii
# Converted: patient0489_4CH_ES.nii
# Converted: patient0489_4CH_ED.nii
# Converted: patient0490_4CH_ES.nii
# Converted: patient0490_4CH_ED.nii
# Converted: patient0491_4CH_ES.nii
# Converted: patient0491_4CH_ED.nii
# Converted: patient0492_4CH_ES.nii
# Converted: patient0492_4CH_ED.nii
# Converted: patient0493_4CH_ES.nii
# Converted: patient0493_4CH_ED.nii
# Converted: patient0494_4CH_ES.nii
# Converted: patient0494_4CH_ED.nii
# Converted: patient0495_4CH_ES.nii
# Converted: patient0495_4CH_ED.nii
# Converted: patient0496_4CH_ES.nii
# Converted: patient0496_4CH_ED.nii
# Converted: patient0497_4CH_ES.nii
# Converted: patient0497_4CH_ED.nii
# Converted: patient0498_4CH_ES.nii
# Converted: patient0498_4CH_ED.nii
# Converted: patient0499_4CH_ES.nii
# Converted: patient0499_4CH_ED.nii
# Converted: patient0500_4CH_ES.nii
# Converted: patient0500_4CH_ED.nii
# Processing train/labels...
# Converted: patient0001_4CH_ES_gt.nii
# Converted: patient0001_4CH_ED_gt.nii
# Converted: patient0002_4CH_ES_gt.nii
# Converted: patient0002_4CH_ED_gt.nii
# Converted: patient0003_4CH_ES_gt.nii
# Converted: patient0003_4CH_ED_gt.nii
# Converted: patient0004_4CH_ES_gt.nii
# Converted: patient0004_4CH_ED_gt.nii
# Converted: patient0005_4CH_ES_gt.nii
# Converted: patient0005_4CH_ED_gt.nii
# Converted: patient0006_4CH_ES_gt.nii
# Converted: patient0006_4CH_ED_gt.nii
# Converted: patient0007_4CH_ES_gt.nii
# Converted: patient0007_4CH_ED_gt.nii
# Converted: patient0008_4CH_ES_gt.nii
# Converted: patient0008_4CH_ED_gt.nii
# Converted: patient0009_4CH_ES_gt.nii
# Converted: patient0009_4CH_ED_gt.nii
# Converted: patient0010_4CH_ES_gt.nii
# Converted: patient0010_4CH_ED_gt.nii
# Converted: patient0011_4CH_ES_gt.nii
# Converted: patient0011_4CH_ED_gt.nii
# Converted: patient0012_4CH_ES_gt.nii
# Converted: patient0012_4CH_ED_gt.nii
# Converted: patient0013_4CH_ES_gt.nii
# Converted: patient0013_4CH_ED_gt.nii
# Converted: patient0014_4CH_ES_gt.nii
# Converted: patient0014_4CH_ED_gt.nii
# Converted: patient0015_4CH_ES_gt.nii
# Converted: patient0015_4CH_ED_gt.nii
# Converted: patient0016_4CH_ES_gt.nii
# Converted: patient0016_4CH_ED_gt.nii
# Converted: patient0017_4CH_ES_gt.nii
# Converted: patient0017_4CH_ED_gt.nii
# Converted: patient0018_4CH_ES_gt.nii
# Converted: patient0018_4CH_ED_gt.nii
# Converted: patient0019_4CH_ES_gt.nii
# Converted: patient0019_4CH_ED_gt.nii
# Converted: patient0020_4CH_ES_gt.nii
# Converted: patient0020_4CH_ED_gt.nii
# Converted: patient0021_4CH_ES_gt.nii
# Converted: patient0021_4CH_ED_gt.nii
# Converted: patient0022_4CH_ES_gt.nii
# Converted: patient0022_4CH_ED_gt.nii
# Converted: patient0023_4CH_ES_gt.nii
# Converted: patient0023_4CH_ED_gt.nii
# Converted: patient0024_4CH_ES_gt.nii
# Converted: patient0024_4CH_ED_gt.nii
# Converted: patient0025_4CH_ES_gt.nii
# Converted: patient0025_4CH_ED_gt.nii
# Converted: patient0026_4CH_ES_gt.nii
# Converted: patient0026_4CH_ED_gt.nii
# Converted: patient0028_4CH_ES_gt.nii
# Converted: patient0028_4CH_ED_gt.nii
# Converted: patient0029_4CH_ES_gt.nii
# Converted: patient0029_4CH_ED_gt.nii
# Converted: patient0030_4CH_ES_gt.nii
# Converted: patient0030_4CH_ED_gt.nii
# Converted: patient0031_4CH_ES_gt.nii
# Converted: patient0031_4CH_ED_gt.nii
# Converted: patient0032_4CH_ES_gt.nii
# Converted: patient0032_4CH_ED_gt.nii
# Converted: patient0033_4CH_ES_gt.nii
# Converted: patient0033_4CH_ED_gt.nii
# Converted: patient0034_4CH_ES_gt.nii
# Converted: patient0034_4CH_ED_gt.nii
# Converted: patient0035_4CH_ES_gt.nii
# Converted: patient0035_4CH_ED_gt.nii
# Converted: patient0036_4CH_ES_gt.nii
# Converted: patient0036_4CH_ED_gt.nii
# Converted: patient0037_4CH_ES_gt.nii
# Converted: patient0037_4CH_ED_gt.nii
# Converted: patient0038_4CH_ES_gt.nii
# Converted: patient0038_4CH_ED_gt.nii
# Converted: patient0039_4CH_ES_gt.nii
# Converted: patient0039_4CH_ED_gt.nii
# Converted: patient0040_4CH_ES_gt.nii
# Converted: patient0040_4CH_ED_gt.nii
# Converted: patient0041_4CH_ES_gt.nii
# Converted: patient0041_4CH_ED_gt.nii
# Converted: patient0042_4CH_ES_gt.nii
# Converted: patient0042_4CH_ED_gt.nii
# Converted: patient0043_4CH_ES_gt.nii
# Converted: patient0043_4CH_ED_gt.nii
# Converted: patient0044_4CH_ES_gt.nii
# Converted: patient0044_4CH_ED_gt.nii
# Converted: patient0045_4CH_ES_gt.nii
# Converted: patient0045_4CH_ED_gt.nii
# Converted: patient0046_4CH_ES_gt.nii
# Converted: patient0046_4CH_ED_gt.nii
# Converted: patient0048_4CH_ES_gt.nii
# Converted: patient0048_4CH_ED_gt.nii
# Converted: patient0049_4CH_ES_gt.nii
# Converted: patient0049_4CH_ED_gt.nii
# Converted: patient0050_4CH_ES_gt.nii
# Converted: patient0050_4CH_ED_gt.nii
# Converted: patient0053_4CH_ES_gt.nii
# Converted: patient0053_4CH_ED_gt.nii
# Converted: patient0054_4CH_ES_gt.nii
# Converted: patient0054_4CH_ED_gt.nii
# Converted: patient0055_4CH_ES_gt.nii
# Converted: patient0055_4CH_ED_gt.nii
# Converted: patient0056_4CH_ES_gt.nii
# Converted: patient0056_4CH_ED_gt.nii
# Converted: patient0057_4CH_ES_gt.nii
# Converted: patient0057_4CH_ED_gt.nii
# Converted: patient0058_4CH_ES_gt.nii
# Converted: patient0058_4CH_ED_gt.nii
# Converted: patient0059_4CH_ES_gt.nii
# Converted: patient0059_4CH_ED_gt.nii
# Converted: patient0060_4CH_ES_gt.nii
# Converted: patient0060_4CH_ED_gt.nii
# Converted: patient0061_4CH_ES_gt.nii
# Converted: patient0061_4CH_ED_gt.nii
# Converted: patient0062_4CH_ES_gt.nii
# Converted: patient0062_4CH_ED_gt.nii
# Converted: patient0063_4CH_ES_gt.nii
# Converted: patient0063_4CH_ED_gt.nii
# Converted: patient0064_4CH_ES_gt.nii
# Converted: patient0064_4CH_ED_gt.nii
# Converted: patient0065_4CH_ES_gt.nii
# Converted: patient0065_4CH_ED_gt.nii
# Converted: patient0066_4CH_ES_gt.nii
# Converted: patient0066_4CH_ED_gt.nii
# Converted: patient0067_4CH_ES_gt.nii
# Converted: patient0067_4CH_ED_gt.nii
# Converted: patient0068_4CH_ES_gt.nii
# Converted: patient0068_4CH_ED_gt.nii
# Converted: patient0069_4CH_ES_gt.nii
# Converted: patient0069_4CH_ED_gt.nii
# Converted: patient0070_4CH_ES_gt.nii
# Converted: patient0070_4CH_ED_gt.nii
# Converted: patient0071_4CH_ES_gt.nii
# Converted: patient0071_4CH_ED_gt.nii
# Converted: patient0072_4CH_ES_gt.nii
# Converted: patient0072_4CH_ED_gt.nii
# Converted: patient0073_4CH_ES_gt.nii
# Converted: patient0073_4CH_ED_gt.nii
# Converted: patient0074_4CH_ES_gt.nii
# Converted: patient0074_4CH_ED_gt.nii
# Converted: patient0075_4CH_ES_gt.nii
# Converted: patient0075_4CH_ED_gt.nii
# Converted: patient0076_4CH_ES_gt.nii
# Converted: patient0076_4CH_ED_gt.nii
# Converted: patient0077_4CH_ES_gt.nii
# Converted: patient0077_4CH_ED_gt.nii
# Converted: patient0078_4CH_ES_gt.nii
# Converted: patient0078_4CH_ED_gt.nii
# Converted: patient0079_4CH_ES_gt.nii
# Converted: patient0079_4CH_ED_gt.nii
# Converted: patient0080_4CH_ES_gt.nii
# Converted: patient0080_4CH_ED_gt.nii
# Converted: patient0081_4CH_ES_gt.nii
# Converted: patient0081_4CH_ED_gt.nii
# Converted: patient0082_4CH_ES_gt.nii
# Converted: patient0082_4CH_ED_gt.nii
# Converted: patient0083_4CH_ES_gt.nii
# Converted: patient0083_4CH_ED_gt.nii
# Converted: patient0084_4CH_ES_gt.nii
# Converted: patient0084_4CH_ED_gt.nii
# Converted: patient0085_4CH_ES_gt.nii
# Converted: patient0085_4CH_ED_gt.nii
# Converted: patient0086_4CH_ES_gt.nii
# Converted: patient0086_4CH_ED_gt.nii
# Converted: patient0087_4CH_ES_gt.nii
# Converted: patient0087_4CH_ED_gt.nii
# Converted: patient0088_4CH_ES_gt.nii
# Converted: patient0088_4CH_ED_gt.nii
# Converted: patient0089_4CH_ES_gt.nii
# Converted: patient0089_4CH_ED_gt.nii
# Converted: patient0090_4CH_ES_gt.nii
# Converted: patient0090_4CH_ED_gt.nii
# Converted: patient0091_4CH_ES_gt.nii
# Converted: patient0091_4CH_ED_gt.nii
# Converted: patient0092_4CH_ES_gt.nii
# Converted: patient0092_4CH_ED_gt.nii
# Converted: patient0093_4CH_ES_gt.nii
# Converted: patient0093_4CH_ED_gt.nii
# Converted: patient0094_4CH_ES_gt.nii
# Converted: patient0094_4CH_ED_gt.nii
# Converted: patient0095_4CH_ES_gt.nii
# Converted: patient0095_4CH_ED_gt.nii
# Converted: patient0096_4CH_ES_gt.nii
# Converted: patient0096_4CH_ED_gt.nii
# Converted: patient0097_4CH_ES_gt.nii
# Converted: patient0097_4CH_ED_gt.nii
# Converted: patient0098_4CH_ES_gt.nii
# Converted: patient0098_4CH_ED_gt.nii
# Converted: patient0099_4CH_ES_gt.nii
# Converted: patient0099_4CH_ED_gt.nii
# Converted: patient0100_4CH_ES_gt.nii
# Converted: patient0100_4CH_ED_gt.nii
# Converted: patient0101_4CH_ES_gt.nii
# Converted: patient0101_4CH_ED_gt.nii
# Converted: patient0102_4CH_ES_gt.nii
# Converted: patient0102_4CH_ED_gt.nii
# Converted: patient0103_4CH_ES_gt.nii
# Converted: patient0103_4CH_ED_gt.nii
# Converted: patient0104_4CH_ES_gt.nii
# Converted: patient0104_4CH_ED_gt.nii
# Converted: patient0105_4CH_ES_gt.nii
# Converted: patient0105_4CH_ED_gt.nii
# Converted: patient0106_4CH_ES_gt.nii
# Converted: patient0106_4CH_ED_gt.nii
# Converted: patient0107_4CH_ES_gt.nii
# Converted: patient0107_4CH_ED_gt.nii
# Converted: patient0108_4CH_ES_gt.nii
# Converted: patient0108_4CH_ED_gt.nii
# Converted: patient0109_4CH_ES_gt.nii
# Converted: patient0109_4CH_ED_gt.nii
# Converted: patient0110_4CH_ES_gt.nii
# Converted: patient0110_4CH_ED_gt.nii
# Converted: patient0111_4CH_ES_gt.nii
# Converted: patient0111_4CH_ED_gt.nii
# Converted: patient0112_4CH_ES_gt.nii
# Converted: patient0112_4CH_ED_gt.nii
# Converted: patient0113_4CH_ES_gt.nii
# Converted: patient0113_4CH_ED_gt.nii
# Converted: patient0114_4CH_ES_gt.nii
# Converted: patient0114_4CH_ED_gt.nii
# Converted: patient0115_4CH_ES_gt.nii
# Converted: patient0115_4CH_ED_gt.nii
# Converted: patient0116_4CH_ES_gt.nii
# Converted: patient0116_4CH_ED_gt.nii
# Converted: patient0117_4CH_ES_gt.nii
# Converted: patient0117_4CH_ED_gt.nii
# Converted: patient0118_4CH_ES_gt.nii
# Converted: patient0118_4CH_ED_gt.nii
# Converted: patient0119_4CH_ES_gt.nii
# Converted: patient0119_4CH_ED_gt.nii
# Converted: patient0120_4CH_ES_gt.nii
# Converted: patient0120_4CH_ED_gt.nii
# Converted: patient0121_4CH_ES_gt.nii
# Converted: patient0121_4CH_ED_gt.nii
# Converted: patient0122_4CH_ES_gt.nii
# Converted: patient0122_4CH_ED_gt.nii
# Converted: patient0123_4CH_ES_gt.nii
# Converted: patient0123_4CH_ED_gt.nii
# Converted: patient0124_4CH_ES_gt.nii
# Converted: patient0124_4CH_ED_gt.nii
# Converted: patient0125_4CH_ES_gt.nii
# Converted: patient0125_4CH_ED_gt.nii
# Converted: patient0126_4CH_ES_gt.nii
# Converted: patient0126_4CH_ED_gt.nii
# Converted: patient0127_4CH_ES_gt.nii
# Converted: patient0127_4CH_ED_gt.nii
# Converted: patient0128_4CH_ES_gt.nii
# Converted: patient0128_4CH_ED_gt.nii
# Converted: patient0129_4CH_ES_gt.nii
# Converted: patient0129_4CH_ED_gt.nii
# Converted: patient0130_4CH_ES_gt.nii
# Converted: patient0130_4CH_ED_gt.nii
# Converted: patient0131_4CH_ES_gt.nii
# Converted: patient0131_4CH_ED_gt.nii
# Converted: patient0132_4CH_ES_gt.nii
# Converted: patient0132_4CH_ED_gt.nii
# Converted: patient0133_4CH_ES_gt.nii
# Converted: patient0133_4CH_ED_gt.nii
# Converted: patient0134_4CH_ES_gt.nii
# Converted: patient0134_4CH_ED_gt.nii
# Converted: patient0135_4CH_ES_gt.nii
# Converted: patient0135_4CH_ED_gt.nii
# Converted: patient0136_4CH_ES_gt.nii
# Converted: patient0136_4CH_ED_gt.nii
# Converted: patient0137_4CH_ES_gt.nii
# Converted: patient0137_4CH_ED_gt.nii
# Converted: patient0138_4CH_ES_gt.nii
# Converted: patient0138_4CH_ED_gt.nii
# Converted: patient0139_4CH_ES_gt.nii
# Converted: patient0139_4CH_ED_gt.nii
# Converted: patient0140_4CH_ES_gt.nii
# Converted: patient0140_4CH_ED_gt.nii
# Converted: patient0141_4CH_ES_gt.nii
# Converted: patient0141_4CH_ED_gt.nii
# Converted: patient0142_4CH_ES_gt.nii
# Converted: patient0142_4CH_ED_gt.nii
# Converted: patient0143_4CH_ES_gt.nii
# Converted: patient0143_4CH_ED_gt.nii
# Converted: patient0144_4CH_ES_gt.nii
# Converted: patient0144_4CH_ED_gt.nii
# Converted: patient0145_4CH_ES_gt.nii
# Converted: patient0145_4CH_ED_gt.nii
# Converted: patient0146_4CH_ES_gt.nii
# Converted: patient0146_4CH_ED_gt.nii
# Converted: patient0147_4CH_ES_gt.nii
# Converted: patient0147_4CH_ED_gt.nii
# Converted: patient0148_4CH_ES_gt.nii
# Converted: patient0148_4CH_ED_gt.nii
# Converted: patient0149_4CH_ES_gt.nii
# Converted: patient0149_4CH_ED_gt.nii
# Converted: patient0150_4CH_ES_gt.nii
# Converted: patient0150_4CH_ED_gt.nii
# Converted: patient0151_4CH_ES_gt.nii
# Converted: patient0151_4CH_ED_gt.nii
# Converted: patient0152_4CH_ES_gt.nii
# Converted: patient0152_4CH_ED_gt.nii
# Converted: patient0153_4CH_ES_gt.nii
# Converted: patient0153_4CH_ED_gt.nii
# Converted: patient0154_4CH_ES_gt.nii
# Converted: patient0154_4CH_ED_gt.nii
# Converted: patient0155_4CH_ES_gt.nii
# Converted: patient0155_4CH_ED_gt.nii
# Converted: patient0156_4CH_ES_gt.nii
# Converted: patient0156_4CH_ED_gt.nii
# Converted: patient0157_4CH_ES_gt.nii
# Converted: patient0157_4CH_ED_gt.nii
# Converted: patient0158_4CH_ES_gt.nii
# Converted: patient0158_4CH_ED_gt.nii
# Converted: patient0159_4CH_ES_gt.nii
# Converted: patient0159_4CH_ED_gt.nii
# Converted: patient0160_4CH_ES_gt.nii
# Converted: patient0160_4CH_ED_gt.nii
# Converted: patient0161_4CH_ES_gt.nii
# Converted: patient0161_4CH_ED_gt.nii
# Converted: patient0162_4CH_ES_gt.nii
# Converted: patient0162_4CH_ED_gt.nii
# Converted: patient0163_4CH_ES_gt.nii
# Converted: patient0163_4CH_ED_gt.nii
# Converted: patient0164_4CH_ES_gt.nii
# Converted: patient0164_4CH_ED_gt.nii
# Converted: patient0165_4CH_ES_gt.nii
# Converted: patient0165_4CH_ED_gt.nii
# Converted: patient0166_4CH_ES_gt.nii
# Converted: patient0166_4CH_ED_gt.nii
# Converted: patient0167_4CH_ES_gt.nii
# Converted: patient0167_4CH_ED_gt.nii
# Converted: patient0168_4CH_ES_gt.nii
# Converted: patient0168_4CH_ED_gt.nii
# Converted: patient0169_4CH_ES_gt.nii
# Converted: patient0169_4CH_ED_gt.nii
# Converted: patient0170_4CH_ES_gt.nii
# Converted: patient0170_4CH_ED_gt.nii
# Converted: patient0171_4CH_ES_gt.nii
# Converted: patient0171_4CH_ED_gt.nii
# Converted: patient0172_4CH_ES_gt.nii
# Converted: patient0172_4CH_ED_gt.nii
# Converted: patient0173_4CH_ES_gt.nii
# Converted: patient0173_4CH_ED_gt.nii
# Converted: patient0174_4CH_ES_gt.nii
# Converted: patient0174_4CH_ED_gt.nii
# Converted: patient0175_4CH_ES_gt.nii
# Converted: patient0175_4CH_ED_gt.nii
# Converted: patient0176_4CH_ES_gt.nii
# Converted: patient0176_4CH_ED_gt.nii
# Converted: patient0177_4CH_ES_gt.nii
# Converted: patient0177_4CH_ED_gt.nii
# Converted: patient0178_4CH_ES_gt.nii
# Converted: patient0178_4CH_ED_gt.nii
# Converted: patient0179_4CH_ES_gt.nii
# Converted: patient0179_4CH_ED_gt.nii
# Converted: patient0180_4CH_ES_gt.nii
# Converted: patient0180_4CH_ED_gt.nii
# Converted: patient0181_4CH_ES_gt.nii
# Converted: patient0181_4CH_ED_gt.nii
# Converted: patient0182_4CH_ES_gt.nii
# Converted: patient0182_4CH_ED_gt.nii
# Converted: patient0183_4CH_ES_gt.nii
# Converted: patient0183_4CH_ED_gt.nii
# Converted: patient0184_4CH_ES_gt.nii
# Converted: patient0184_4CH_ED_gt.nii
# Converted: patient0185_4CH_ES_gt.nii
# Converted: patient0185_4CH_ED_gt.nii
# Converted: patient0186_4CH_ES_gt.nii
# Converted: patient0186_4CH_ED_gt.nii
# Converted: patient0188_4CH_ES_gt.nii
# Converted: patient0188_4CH_ED_gt.nii
# Converted: patient0190_4CH_ES_gt.nii
# Converted: patient0190_4CH_ED_gt.nii
# Converted: patient0192_4CH_ES_gt.nii
# Converted: patient0192_4CH_ED_gt.nii
# Converted: patient0193_4CH_ES_gt.nii
# Converted: patient0193_4CH_ED_gt.nii
# Converted: patient0195_4CH_ES_gt.nii
# Converted: patient0195_4CH_ED_gt.nii
# Converted: patient0196_4CH_ES_gt.nii
# Converted: patient0196_4CH_ED_gt.nii
# Converted: patient0198_4CH_ES_gt.nii
# Converted: patient0198_4CH_ED_gt.nii
# Converted: patient0202_4CH_ES_gt.nii
# Converted: patient0202_4CH_ED_gt.nii
# Converted: patient0203_4CH_ES_gt.nii
# Converted: patient0203_4CH_ED_gt.nii
# Converted: patient0204_4CH_ES_gt.nii
# Converted: patient0204_4CH_ED_gt.nii
# Converted: patient0205_4CH_ES_gt.nii
# Converted: patient0205_4CH_ED_gt.nii
# Converted: patient0207_4CH_ES_gt.nii
# Converted: patient0207_4CH_ED_gt.nii
# Converted: patient0209_4CH_ES_gt.nii
# Converted: patient0209_4CH_ED_gt.nii
# Converted: patient0210_4CH_ES_gt.nii
# Converted: patient0210_4CH_ED_gt.nii
# Converted: patient0211_4CH_ES_gt.nii
# Converted: patient0211_4CH_ED_gt.nii
# Converted: patient0212_4CH_ES_gt.nii
# Converted: patient0212_4CH_ED_gt.nii
# Converted: patient0216_4CH_ES_gt.nii
# Converted: patient0216_4CH_ED_gt.nii
# Converted: patient0222_4CH_ES_gt.nii
# Converted: patient0222_4CH_ED_gt.nii
# Converted: patient0229_4CH_ES_gt.nii
# Converted: patient0229_4CH_ED_gt.nii
# Converted: patient0274_4CH_ES_gt.nii
# Converted: patient0274_4CH_ED_gt.nii
# Converted: patient0277_4CH_ES_gt.nii
# Converted: patient0277_4CH_ED_gt.nii
# Converted: patient0278_4CH_ES_gt.nii
# Converted: patient0278_4CH_ED_gt.nii
# Converted: patient0281_4CH_ES_gt.nii
# Converted: patient0281_4CH_ED_gt.nii
# Converted: patient0285_4CH_ES_gt.nii
# Converted: patient0285_4CH_ED_gt.nii
# Converted: patient0293_4CH_ES_gt.nii
# Converted: patient0293_4CH_ED_gt.nii
# Converted: patient0295_4CH_ES_gt.nii
# Converted: patient0295_4CH_ED_gt.nii
# Converted: patient0296_4CH_ES_gt.nii
# Converted: patient0296_4CH_ED_gt.nii
# Converted: patient0300_4CH_ES_gt.nii
# Converted: patient0300_4CH_ED_gt.nii
# Converted: patient0301_4CH_ES_gt.nii
# Converted: patient0301_4CH_ED_gt.nii
# Converted: patient0302_4CH_ES_gt.nii
# Converted: patient0302_4CH_ED_gt.nii
# Converted: patient0306_4CH_ES_gt.nii
# Converted: patient0306_4CH_ED_gt.nii
# Converted: patient0307_4CH_ES_gt.nii
# Converted: patient0307_4CH_ED_gt.nii
# Converted: patient0309_4CH_ES_gt.nii
# Converted: patient0309_4CH_ED_gt.nii
# Converted: patient0310_4CH_ES_gt.nii
# Converted: patient0310_4CH_ED_gt.nii
# Converted: patient0311_4CH_ES_gt.nii
# Converted: patient0311_4CH_ED_gt.nii
# Converted: patient0312_4CH_ES_gt.nii
# Converted: patient0312_4CH_ED_gt.nii
# Converted: patient0313_4CH_ES_gt.nii
# Converted: patient0313_4CH_ED_gt.nii
# Converted: patient0316_4CH_ES_gt.nii
# Converted: patient0316_4CH_ED_gt.nii
# Converted: patient0317_4CH_ES_gt.nii
# Converted: patient0317_4CH_ED_gt.nii
# Converted: patient0318_4CH_ES_gt.nii
# Converted: patient0318_4CH_ED_gt.nii
# Converted: patient0319_4CH_ES_gt.nii
# Converted: patient0319_4CH_ED_gt.nii
# Converted: patient0320_4CH_ES_gt.nii
# Converted: patient0320_4CH_ED_gt.nii
# Converted: patient0321_4CH_ES_gt.nii
# Converted: patient0321_4CH_ED_gt.nii
# Converted: patient0322_4CH_ES_gt.nii
# Converted: patient0322_4CH_ED_gt.nii
# Converted: patient0323_4CH_ES_gt.nii
# Converted: patient0323_4CH_ED_gt.nii
# Converted: patient0324_4CH_ES_gt.nii
# Converted: patient0324_4CH_ED_gt.nii
# Converted: patient0325_4CH_ES_gt.nii
# Converted: patient0325_4CH_ED_gt.nii
# Converted: patient0326_4CH_ES_gt.nii
# Converted: patient0326_4CH_ED_gt.nii
# Converted: patient0327_4CH_ES_gt.nii
# Converted: patient0327_4CH_ED_gt.nii
# Converted: patient0329_4CH_ES_gt.nii
# Converted: patient0329_4CH_ED_gt.nii
# Converted: patient0330_4CH_ES_gt.nii
# Converted: patient0330_4CH_ED_gt.nii
# Converted: patient0331_4CH_ES_gt.nii
# Converted: patient0331_4CH_ED_gt.nii
# Converted: patient0332_4CH_ES_gt.nii
# Converted: patient0332_4CH_ED_gt.nii
# Converted: patient0335_4CH_ES_gt.nii
# Converted: patient0335_4CH_ED_gt.nii
# Converted: patient0336_4CH_ES_gt.nii
# Converted: patient0336_4CH_ED_gt.nii
# Converted: patient0337_4CH_ES_gt.nii
# Converted: patient0337_4CH_ED_gt.nii
# Converted: patient0338_4CH_ES_gt.nii
# Converted: patient0338_4CH_ED_gt.nii
# Converted: patient0339_4CH_ES_gt.nii
# Converted: patient0339_4CH_ED_gt.nii
# Converted: patient0340_4CH_ES_gt.nii
# Converted: patient0340_4CH_ED_gt.nii
# Converted: patient0342_4CH_ES_gt.nii
# Converted: patient0342_4CH_ED_gt.nii
# Converted: patient0343_4CH_ES_gt.nii
# Converted: patient0343_4CH_ED_gt.nii
# Converted: patient0344_4CH_ES_gt.nii
# Converted: patient0344_4CH_ED_gt.nii
# Converted: patient0345_4CH_ES_gt.nii
# Converted: patient0345_4CH_ED_gt.nii
# Converted: patient0346_4CH_ES_gt.nii
# Converted: patient0346_4CH_ED_gt.nii
# Converted: patient0347_4CH_ES_gt.nii
# Converted: patient0347_4CH_ED_gt.nii
# Converted: patient0348_4CH_ES_gt.nii
# Converted: patient0348_4CH_ED_gt.nii
# Converted: patient0349_4CH_ES_gt.nii
# Converted: patient0349_4CH_ED_gt.nii
# Converted: patient0350_4CH_ES_gt.nii
# Converted: patient0350_4CH_ED_gt.nii
# Converted: patient0351_4CH_ES_gt.nii
# Converted: patient0351_4CH_ED_gt.nii
# Converted: patient0352_4CH_ES_gt.nii
# Converted: patient0352_4CH_ED_gt.nii
# Converted: patient0353_4CH_ES_gt.nii
# Converted: patient0353_4CH_ED_gt.nii
# Converted: patient0354_4CH_ES_gt.nii
# Converted: patient0354_4CH_ED_gt.nii
# Converted: patient0355_4CH_ES_gt.nii
# Converted: patient0355_4CH_ED_gt.nii
# Converted: patient0356_4CH_ES_gt.nii
# Converted: patient0356_4CH_ED_gt.nii
# Converted: patient0357_4CH_ES_gt.nii
# Converted: patient0357_4CH_ED_gt.nii
# Converted: patient0358_4CH_ES_gt.nii
# Converted: patient0358_4CH_ED_gt.nii
# Converted: patient0359_4CH_ES_gt.nii
# Converted: patient0359_4CH_ED_gt.nii
# Converted: patient0360_4CH_ES_gt.nii
# Converted: patient0360_4CH_ED_gt.nii
# Converted: patient0361_4CH_ES_gt.nii
# Converted: patient0361_4CH_ED_gt.nii
# Converted: patient0362_4CH_ES_gt.nii
# Converted: patient0362_4CH_ED_gt.nii
# Converted: patient0363_4CH_ES_gt.nii
# Converted: patient0363_4CH_ED_gt.nii
# Converted: patient0364_4CH_ES_gt.nii
# Converted: patient0364_4CH_ED_gt.nii
# Converted: patient0365_4CH_ES_gt.nii
# Converted: patient0365_4CH_ED_gt.nii
# Converted: patient0366_4CH_ES_gt.nii
# Converted: patient0366_4CH_ED_gt.nii
# Converted: patient0367_4CH_ES_gt.nii
# Converted: patient0367_4CH_ED_gt.nii
# Converted: patient0368_4CH_ES_gt.nii
# Converted: patient0368_4CH_ED_gt.nii
# Converted: patient0369_4CH_ES_gt.nii
# Converted: patient0369_4CH_ED_gt.nii
# Converted: patient0370_4CH_ES_gt.nii
# Converted: patient0370_4CH_ED_gt.nii
# Converted: patient0371_4CH_ES_gt.nii
# Converted: patient0371_4CH_ED_gt.nii
# Converted: patient0372_4CH_ES_gt.nii
# Converted: patient0372_4CH_ED_gt.nii
# Converted: patient0373_4CH_ES_gt.nii
# Converted: patient0373_4CH_ED_gt.nii
# Converted: patient0374_4CH_ES_gt.nii
# Converted: patient0374_4CH_ED_gt.nii
# Converted: patient0375_4CH_ES_gt.nii
# Converted: patient0375_4CH_ED_gt.nii
# Converted: patient0376_4CH_ES_gt.nii
# Converted: patient0376_4CH_ED_gt.nii
# Converted: patient0377_4CH_ES_gt.nii
# Converted: patient0377_4CH_ED_gt.nii
# Converted: patient0378_4CH_ES_gt.nii
# Converted: patient0378_4CH_ED_gt.nii
# Converted: patient0379_4CH_ES_gt.nii
# Converted: patient0379_4CH_ED_gt.nii
# Converted: patient0380_4CH_ES_gt.nii
# Converted: patient0380_4CH_ED_gt.nii
# ...
# Converted: patient0480_4CH_ED_gt.nii
# Converted: patient0481_4CH_ES_gt.nii
# Converted: patient0481_4CH_ED_gt.nii
# Converted: patient0482_4CH_ES_gt.nii
# Converted: patient0482_4CH_ED_gt.nii
# Converted: patient0483_4CH_ES_gt.nii
# Converted: patient0483_4CH_ED_gt.nii
# Converted: patient0484_4CH_ES_gt.nii
# Converted: patient0484_4CH_ED_gt.nii
# Converted: patient0485_4CH_ES_gt.nii
# Converted: patient0485_4CH_ED_gt.nii
# Converted: patient0486_4CH_ES_gt.nii
# Converted: patient0486_4CH_ED_gt.nii
# Converted: patient0487_4CH_ES_gt.nii
# Converted: patient0487_4CH_ED_gt.nii
# Converted: patient0488_4CH_ES_gt.nii
# Converted: patient0488_4CH_ED_gt.nii
# Converted: patient0489_4CH_ES_gt.nii
# Converted: patient0489_4CH_ED_gt.nii
# Converted: patient0490_4CH_ES_gt.nii
# Converted: patient0490_4CH_ED_gt.nii
# Converted: patient0491_4CH_ES_gt.nii
# Converted: patient0491_4CH_ED_gt.nii
# Converted: patient0492_4CH_ES_gt.nii
# Converted: patient0492_4CH_ED_gt.nii
# Converted: patient0493_4CH_ES_gt.nii
# Converted: patient0493_4CH_ED_gt.nii
# Converted: patient0494_4CH_ES_gt.nii
# Converted: patient0494_4CH_ED_gt.nii
# Converted: patient0495_4CH_ES_gt.nii
# Converted: patient0495_4CH_ED_gt.nii
# Converted: patient0496_4CH_ES_gt.nii
# Converted: patient0496_4CH_ED_gt.nii
# Converted: patient0497_4CH_ES_gt.nii
# Converted: patient0497_4CH_ED_gt.nii
# Converted: patient0498_4CH_ES_gt.nii
# Converted: patient0498_4CH_ED_gt.nii
# Converted: patient0499_4CH_ES_gt.nii
# Converted: patient0499_4CH_ED_gt.nii
# Converted: patient0500_4CH_ES_gt.nii
# Converted: patient0500_4CH_ED_gt.nii
# Processing valid/images...
# Converted: patient0200_4CH_ES.nii
# Converted: patient0200_4CH_ED.nii
# Converted: patient0206_4CH_ES.nii
# Converted: patient0206_4CH_ED.nii
# Converted: patient0230_4CH_ES.nii
# Converted: patient0230_4CH_ED.nii
# Converted: patient0232_4CH_ES.nii
# Converted: patient0232_4CH_ED.nii
# Converted: patient0233_4CH_ES.nii
# Converted: patient0233_4CH_ED.nii
# Converted: patient0235_4CH_ES.nii
# Converted: patient0235_4CH_ED.nii
# Converted: patient0236_4CH_ES.nii
# Converted: patient0236_4CH_ED.nii
# Converted: patient0244_4CH_ES.nii
# Converted: patient0244_4CH_ED.nii
# Converted: patient0245_4CH_ES.nii
# Converted: patient0245_4CH_ED.nii
# Converted: patient0247_4CH_ES.nii
# Converted: patient0247_4CH_ED.nii
# Converted: patient0249_4CH_ES.nii
# Converted: patient0249_4CH_ED.nii
# Converted: patient0250_4CH_ES.nii
# Converted: patient0250_4CH_ED.nii
# Converted: patient0253_4CH_ES.nii
# Converted: patient0253_4CH_ED.nii
# Converted: patient0255_4CH_ES.nii
# Converted: patient0255_4CH_ED.nii
# Converted: patient0256_4CH_ES.nii
# Converted: patient0256_4CH_ED.nii
# Converted: patient0257_4CH_ES.nii
# Converted: patient0257_4CH_ED.nii
# Converted: patient0259_4CH_ES.nii
# Converted: patient0259_4CH_ED.nii
# Converted: patient0264_4CH_ES.nii
# Converted: patient0264_4CH_ED.nii
# Converted: patient0265_4CH_ES.nii
# Converted: patient0265_4CH_ED.nii
# Converted: patient0267_4CH_ES.nii
# Converted: patient0267_4CH_ED.nii
# Converted: patient0268_4CH_ES.nii
# Converted: patient0268_4CH_ED.nii
# Converted: patient0270_4CH_ES.nii
# Converted: patient0270_4CH_ED.nii
# Converted: patient0271_4CH_ES.nii
# Converted: patient0271_4CH_ED.nii
# Converted: patient0272_4CH_ES.nii
# Converted: patient0272_4CH_ED.nii
# Converted: patient0279_4CH_ES.nii
# Converted: patient0279_4CH_ED.nii
# Converted: patient0280_4CH_ES.nii
# Converted: patient0280_4CH_ED.nii
# Converted: patient0282_4CH_ES.nii
# Converted: patient0282_4CH_ED.nii
# Converted: patient0283_4CH_ES.nii
# Converted: patient0283_4CH_ED.nii
# Converted: patient0284_4CH_ES.nii
# Converted: patient0284_4CH_ED.nii
# Converted: patient0286_4CH_ES.nii
# Converted: patient0286_4CH_ED.nii
# Converted: patient0287_4CH_ES.nii
# Converted: patient0287_4CH_ED.nii
# Converted: patient0288_4CH_ES.nii
# Converted: patient0288_4CH_ED.nii
# Converted: patient0289_4CH_ES.nii
# Converted: patient0289_4CH_ED.nii
# Converted: patient0290_4CH_ES.nii
# Converted: patient0290_4CH_ED.nii
# Converted: patient0291_4CH_ES.nii
# Converted: patient0291_4CH_ED.nii
# Converted: patient0292_4CH_ES.nii
# Converted: patient0292_4CH_ED.nii
# Converted: patient0294_4CH_ES.nii
# Converted: patient0294_4CH_ED.nii
# Converted: patient0297_4CH_ES.nii
# Converted: patient0297_4CH_ED.nii
# Converted: patient0298_4CH_ES.nii
# Converted: patient0298_4CH_ED.nii
# Converted: patient0299_4CH_ES.nii
# Converted: patient0299_4CH_ED.nii
# Converted: patient0303_4CH_ES.nii
# Converted: patient0303_4CH_ED.nii
# Converted: patient0304_4CH_ES.nii
# Converted: patient0304_4CH_ED.nii
# Converted: patient0305_4CH_ES.nii
# Converted: patient0305_4CH_ED.nii
# Converted: patient0308_4CH_ES.nii
# Converted: patient0308_4CH_ED.nii
# Converted: patient0314_4CH_ES.nii
# Converted: patient0314_4CH_ED.nii
# Converted: patient0315_4CH_ES.nii
# Converted: patient0315_4CH_ED.nii
# Converted: patient0328_4CH_ES.nii
# Converted: patient0328_4CH_ED.nii
# Converted: patient0333_4CH_ES.nii
# Converted: patient0333_4CH_ED.nii
# Converted: patient0334_4CH_ES.nii
# Converted: patient0334_4CH_ED.nii
# Converted: patient0341_4CH_ES.nii
# Converted: patient0341_4CH_ED.nii
# Processing valid/labels...
# Converted: patient0200_4CH_ES_gt.nii
# Converted: patient0200_4CH_ED_gt.nii
# Converted: patient0206_4CH_ES_gt.nii
# Converted: patient0206_4CH_ED_gt.nii
# Converted: patient0230_4CH_ES_gt.nii
# Converted: patient0230_4CH_ED_gt.nii
# Converted: patient0232_4CH_ES_gt.nii
# Converted: patient0232_4CH_ED_gt.nii
# Converted: patient0233_4CH_ES_gt.nii
# Converted: patient0233_4CH_ED_gt.nii
# Converted: patient0235_4CH_ES_gt.nii
# Converted: patient0235_4CH_ED_gt.nii
# Converted: patient0236_4CH_ES_gt.nii
# Converted: patient0236_4CH_ED_gt.nii
# Converted: patient0244_4CH_ES_gt.nii
# Converted: patient0244_4CH_ED_gt.nii
# Converted: patient0245_4CH_ES_gt.nii
# Converted: patient0245_4CH_ED_gt.nii
# Converted: patient0247_4CH_ES_gt.nii
# Converted: patient0247_4CH_ED_gt.nii
# Converted: patient0249_4CH_ES_gt.nii
# Converted: patient0249_4CH_ED_gt.nii
# Converted: patient0250_4CH_ES_gt.nii
# Converted: patient0250_4CH_ED_gt.nii
# Converted: patient0253_4CH_ES_gt.nii
# Converted: patient0253_4CH_ED_gt.nii
# Converted: patient0255_4CH_ES_gt.nii
# Converted: patient0255_4CH_ED_gt.nii
# Converted: patient0256_4CH_ES_gt.nii
# Converted: patient0256_4CH_ED_gt.nii
# Converted: patient0257_4CH_ES_gt.nii
# Converted: patient0257_4CH_ED_gt.nii
# Converted: patient0259_4CH_ES_gt.nii
# Converted: patient0259_4CH_ED_gt.nii
# Converted: patient0264_4CH_ES_gt.nii
# Converted: patient0264_4CH_ED_gt.nii
# Converted: patient0265_4CH_ES_gt.nii
# Converted: patient0265_4CH_ED_gt.nii
# Converted: patient0267_4CH_ES_gt.nii
# Converted: patient0267_4CH_ED_gt.nii
# Converted: patient0268_4CH_ES_gt.nii
# Converted: patient0268_4CH_ED_gt.nii
# Converted: patient0270_4CH_ES_gt.nii
# Converted: patient0270_4CH_ED_gt.nii
# Converted: patient0271_4CH_ES_gt.nii
# Converted: patient0271_4CH_ED_gt.nii
# Converted: patient0272_4CH_ES_gt.nii
# Converted: patient0272_4CH_ED_gt.nii
# Converted: patient0279_4CH_ES_gt.nii
# Converted: patient0279_4CH_ED_gt.nii
# Converted: patient0280_4CH_ES_gt.nii
# Converted: patient0280_4CH_ED_gt.nii
# Converted: patient0282_4CH_ES_gt.nii
# Converted: patient0282_4CH_ED_gt.nii
# Converted: patient0283_4CH_ES_gt.nii
# Converted: patient0283_4CH_ED_gt.nii
# Converted: patient0284_4CH_ES_gt.nii
# Converted: patient0284_4CH_ED_gt.nii
# Converted: patient0286_4CH_ES_gt.nii
# Converted: patient0286_4CH_ED_gt.nii
# Converted: patient0287_4CH_ES_gt.nii
# Converted: patient0287_4CH_ED_gt.nii
# Converted: patient0288_4CH_ES_gt.nii
# Converted: patient0288_4CH_ED_gt.nii
# Converted: patient0289_4CH_ES_gt.nii
# Converted: patient0289_4CH_ED_gt.nii
# Converted: patient0290_4CH_ES_gt.nii
# Converted: patient0290_4CH_ED_gt.nii
# Converted: patient0291_4CH_ES_gt.nii
# Converted: patient0291_4CH_ED_gt.nii
# Converted: patient0292_4CH_ES_gt.nii
# Converted: patient0292_4CH_ED_gt.nii
# Converted: patient0294_4CH_ES_gt.nii
# Converted: patient0294_4CH_ED_gt.nii
# Converted: patient0297_4CH_ES_gt.nii
# Converted: patient0297_4CH_ED_gt.nii
# Converted: patient0298_4CH_ES_gt.nii
# Converted: patient0298_4CH_ED_gt.nii
# Converted: patient0299_4CH_ES_gt.nii
# Converted: patient0299_4CH_ED_gt.nii
# Converted: patient0303_4CH_ES_gt.nii
# Converted: patient0303_4CH_ED_gt.nii
# Converted: patient0304_4CH_ES_gt.nii
# Converted: patient0304_4CH_ED_gt.nii
# Converted: patient0305_4CH_ES_gt.nii
# Converted: patient0305_4CH_ED_gt.nii
# Converted: patient0308_4CH_ES_gt.nii
# Converted: patient0308_4CH_ED_gt.nii
# Converted: patient0314_4CH_ES_gt.nii
# Converted: patient0314_4CH_ED_gt.nii
# Converted: patient0315_4CH_ES_gt.nii
# Converted: patient0315_4CH_ED_gt.nii
# Converted: patient0328_4CH_ES_gt.nii
# Converted: patient0328_4CH_ED_gt.nii
# Converted: patient0333_4CH_ES_gt.nii
# Converted: patient0333_4CH_ED_gt.nii
# Converted: patient0334_4CH_ES_gt.nii
# Converted: patient0334_4CH_ED_gt.nii
# Converted: patient0341_4CH_ES_gt.nii
# Converted: patient0341_4CH_ED_gt.nii
# Processing test/images...
# Converted: patient0027_4CH_ES.nii
# Converted: patient0027_4CH_ED.nii
# Converted: patient0047_4CH_ES.nii
# Converted: patient0047_4CH_ED.nii
# Converted: patient0051_4CH_ES.nii
# Converted: patient0051_4CH_ED.nii
# Converted: patient0052_4CH_ES.nii
# Converted: patient0052_4CH_ED.nii
# Converted: patient0187_4CH_ES.nii
# Converted: patient0187_4CH_ED.nii
# Converted: patient0189_4CH_ES.nii
# Converted: patient0189_4CH_ED.nii
# Converted: patient0191_4CH_ES.nii
# Converted: patient0191_4CH_ED.nii
# Converted: patient0194_4CH_ES.nii
# Converted: patient0194_4CH_ED.nii
# Converted: patient0197_4CH_ES.nii
# Converted: patient0197_4CH_ED.nii
# Converted: patient0199_4CH_ES.nii
# Converted: patient0199_4CH_ED.nii
# Converted: patient0201_4CH_ES.nii
# Converted: patient0201_4CH_ED.nii
# Converted: patient0208_4CH_ES.nii
# Converted: patient0208_4CH_ED.nii
# Converted: patient0213_4CH_ES.nii
# Converted: patient0213_4CH_ED.nii
# Converted: patient0214_4CH_ES.nii
# Converted: patient0214_4CH_ED.nii
# Converted: patient0215_4CH_ES.nii
# Converted: patient0215_4CH_ED.nii
# Converted: patient0217_4CH_ES.nii
# Converted: patient0217_4CH_ED.nii
# Converted: patient0218_4CH_ES.nii
# Converted: patient0218_4CH_ED.nii
# Converted: patient0219_4CH_ES.nii
# Converted: patient0219_4CH_ED.nii
# Converted: patient0220_4CH_ES.nii
# Converted: patient0220_4CH_ED.nii
# Converted: patient0221_4CH_ES.nii
# Converted: patient0221_4CH_ED.nii
# Converted: patient0223_4CH_ES.nii
# Converted: patient0223_4CH_ED.nii
# Converted: patient0224_4CH_ES.nii
# Converted: patient0224_4CH_ED.nii
# Converted: patient0225_4CH_ES.nii
# Converted: patient0225_4CH_ED.nii
# Converted: patient0226_4CH_ES.nii
# Converted: patient0226_4CH_ED.nii
# Converted: patient0227_4CH_ES.nii
# Converted: patient0227_4CH_ED.nii
# Converted: patient0228_4CH_ES.nii
# Converted: patient0228_4CH_ED.nii
# Converted: patient0231_4CH_ES.nii
# Converted: patient0231_4CH_ED.nii
# Converted: patient0234_4CH_ES.nii
# Converted: patient0234_4CH_ED.nii
# Converted: patient0237_4CH_ES.nii
# Converted: patient0237_4CH_ED.nii
# Converted: patient0238_4CH_ES.nii
# Converted: patient0238_4CH_ED.nii
# Converted: patient0239_4CH_ES.nii
# Converted: patient0239_4CH_ED.nii
# Converted: patient0240_4CH_ES.nii
# Converted: patient0240_4CH_ED.nii
# Converted: patient0241_4CH_ES.nii
# Converted: patient0241_4CH_ED.nii
# Converted: patient0242_4CH_ES.nii
# Converted: patient0242_4CH_ED.nii
# Converted: patient0243_4CH_ES.nii
# Converted: patient0243_4CH_ED.nii
# Converted: patient0246_4CH_ES.nii
# Converted: patient0246_4CH_ED.nii
# Converted: patient0248_4CH_ES.nii
# Converted: patient0248_4CH_ED.nii
# Converted: patient0251_4CH_ES.nii
# Converted: patient0251_4CH_ED.nii
# Converted: patient0252_4CH_ES.nii
# Converted: patient0252_4CH_ED.nii
# Converted: patient0254_4CH_ES.nii
# Converted: patient0254_4CH_ED.nii
# Converted: patient0258_4CH_ES.nii
# Converted: patient0258_4CH_ED.nii
# Converted: patient0260_4CH_ES.nii
# Converted: patient0260_4CH_ED.nii
# Converted: patient0261_4CH_ES.nii
# Converted: patient0261_4CH_ED.nii
# Converted: patient0262_4CH_ES.nii
# Converted: patient0262_4CH_ED.nii
# Converted: patient0263_4CH_ES.nii
# Converted: patient0263_4CH_ED.nii
# Converted: patient0266_4CH_ES.nii
# Converted: patient0266_4CH_ED.nii
# Converted: patient0269_4CH_ES.nii
# Converted: patient0269_4CH_ED.nii
# Converted: patient0273_4CH_ES.nii
# Converted: patient0273_4CH_ED.nii
# Converted: patient0275_4CH_ES.nii
# Converted: patient0275_4CH_ED.nii
# Converted: patient0276_4CH_ES.nii
# Converted: patient0276_4CH_ED.nii
# Processing test/labels...
# Converted: patient0027_4CH_ES_gt.nii
# Converted: patient0027_4CH_ED_gt.nii
# Converted: patient0047_4CH_ES_gt.nii
# Converted: patient0047_4CH_ED_gt.nii
# Converted: patient0051_4CH_ES_gt.nii
# Converted: patient0051_4CH_ED_gt.nii
# Converted: patient0052_4CH_ES_gt.nii
# Converted: patient0052_4CH_ED_gt.nii
# Converted: patient0187_4CH_ES_gt.nii
# Converted: patient0187_4CH_ED_gt.nii
# Converted: patient0189_4CH_ES_gt.nii
# Converted: patient0189_4CH_ED_gt.nii
# Converted: patient0191_4CH_ES_gt.nii
# Converted: patient0191_4CH_ED_gt.nii
# Converted: patient0194_4CH_ES_gt.nii
# Converted: patient0194_4CH_ED_gt.nii
# Converted: patient0197_4CH_ES_gt.nii
# Converted: patient0197_4CH_ED_gt.nii
# Converted: patient0199_4CH_ES_gt.nii
# Converted: patient0199_4CH_ED_gt.nii
# Converted: patient0201_4CH_ES_gt.nii
# Converted: patient0201_4CH_ED_gt.nii
# Converted: patient0208_4CH_ES_gt.nii
# Converted: patient0208_4CH_ED_gt.nii
# Converted: patient0213_4CH_ES_gt.nii
# Converted: patient0213_4CH_ED_gt.nii
# Converted: patient0214_4CH_ES_gt.nii
# Converted: patient0214_4CH_ED_gt.nii
# Converted: patient0215_4CH_ES_gt.nii
# Converted: patient0215_4CH_ED_gt.nii
# Converted: patient0217_4CH_ES_gt.nii
# Converted: patient0217_4CH_ED_gt.nii
# Converted: patient0218_4CH_ES_gt.nii
# Converted: patient0218_4CH_ED_gt.nii
# Converted: patient0219_4CH_ES_gt.nii
# Converted: patient0219_4CH_ED_gt.nii
# Converted: patient0220_4CH_ES_gt.nii
# Converted: patient0220_4CH_ED_gt.nii
# Converted: patient0221_4CH_ES_gt.nii
# Converted: patient0221_4CH_ED_gt.nii
# Converted: patient0223_4CH_ES_gt.nii
# Converted: patient0223_4CH_ED_gt.nii
# Converted: patient0224_4CH_ES_gt.nii
# Converted: patient0224_4CH_ED_gt.nii
# Converted: patient0225_4CH_ES_gt.nii
# Converted: patient0225_4CH_ED_gt.nii
# Converted: patient0226_4CH_ES_gt.nii
# Converted: patient0226_4CH_ED_gt.nii
# Converted: patient0227_4CH_ES_gt.nii
# Converted: patient0227_4CH_ED_gt.nii
# Converted: patient0228_4CH_ES_gt.nii
# Converted: patient0228_4CH_ED_gt.nii
# Converted: patient0231_4CH_ES_gt.nii
# Converted: patient0231_4CH_ED_gt.nii
# Converted: patient0234_4CH_ES_gt.nii
# Converted: patient0234_4CH_ED_gt.nii
# Converted: patient0237_4CH_ES_gt.nii
# Converted: patient0237_4CH_ED_gt.nii
# Converted: patient0238_4CH_ES_gt.nii
# Converted: patient0238_4CH_ED_gt.nii
# Converted: patient0239_4CH_ES_gt.nii
# Converted: patient0239_4CH_ED_gt.nii
# Converted: patient0240_4CH_ES_gt.nii
# Converted: patient0240_4CH_ED_gt.nii
# Converted: patient0241_4CH_ES_gt.nii
# Converted: patient0241_4CH_ED_gt.nii
# Converted: patient0242_4CH_ES_gt.nii
# Converted: patient0242_4CH_ED_gt.nii
# Converted: patient0243_4CH_ES_gt.nii
# Converted: patient0243_4CH_ED_gt.nii
# Converted: patient0246_4CH_ES_gt.nii
# Converted: patient0246_4CH_ED_gt.nii
# Converted: patient0248_4CH_ES_gt.nii
# Converted: patient0248_4CH_ED_gt.nii
# Converted: patient0251_4CH_ES_gt.nii
# Converted: patient0251_4CH_ED_gt.nii
# Converted: patient0252_4CH_ES_gt.nii
# Converted: patient0252_4CH_ED_gt.nii
# Converted: patient0254_4CH_ES_gt.nii
# Converted: patient0254_4CH_ED_gt.nii
# Converted: patient0258_4CH_ES_gt.nii
# Converted: patient0258_4CH_ED_gt.nii
# Converted: patient0260_4CH_ES_gt.nii
# Converted: patient0260_4CH_ED_gt.nii
# Converted: patient0261_4CH_ES_gt.nii
# Converted: patient0261_4CH_ED_gt.nii
# Converted: patient0262_4CH_ES_gt.nii
# Converted: patient0262_4CH_ED_gt.nii
# Converted: patient0263_4CH_ES_gt.nii
# Converted: patient0263_4CH_ED_gt.nii
# Converted: patient0266_4CH_ES_gt.nii
# Converted: patient0266_4CH_ED_gt.nii
# Converted: patient0269_4CH_ES_gt.nii
# Converted: patient0269_4CH_ED_gt.nii
# Converted: patient0273_4CH_ES_gt.nii
# Converted: patient0273_4CH_ED_gt.nii
# Converted: patient0275_4CH_ES_gt.nii
# Converted: patient0275_4CH_ED_gt.nii
# Converted: patient0276_4CH_ES_gt.nii
# Converted: patient0276_4CH_ED_gt.nii
#
# Conversion Summary:
# Train set: 800 images, 800 labels converted to PNG
# Valid set: 100 images, 100 labels converted to PNG
# Test set: 100 images, 100 labels converted to PNG
