# %% [markdown]
# <a href="https://colab.research.google.com/github/sarah1ibrahim/End-to-End-Echocardiographic-Analysis-Pipeline/blob/main/EchoNet_Dynamic_Tracings_Masks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Masks Creation

# %%
from google.colab import drive
import os
import cv2
import numpy as np
import pandas as pd
import logging
from datetime import datetime
import signal
import time
import shutil

# Set up logging
log_dir = "/content/drive/MyDrive/✨ GP ✨/EchoNet_Dataset/EchoNet-Dynamic"
try:
    os.makedirs(log_dir, exist_ok=True)
except Exception as e:
    log_dir = "/content"
    print(f"Could not create log directory on Google Drive yet: {e}. Logging to /content temporarily.")

log_file = os.path.join(log_dir, f"create_all_filled_masks_log_{datetime.now().strftime('%Y%m%d_%H%M%S')}.txt")

logger = logging.getLogger()
logger.setLevel(logging.INFO)

file_handler = logging.FileHandler(log_file)
file_handler.setLevel(logging.INFO)
file_formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
file_handler.setFormatter(file_formatter)
logger.addHandler(file_handler)

console_handler = logging.StreamHandler()
console_handler.setLevel(logging.INFO)
console_formatter = logging.Formatter('%(message)s')
console_handler.setFormatter(console_formatter)
logger.addHandler(console_handler)

# Function to timeout an operation
def timeout_handler(signum, frame):
    raise TimeoutError("Operation timed out")

# Function to mount Google Drive with retries
def mount_google_drive(max_retries=3, retry_delay=10):
    for attempt in range(max_retries):
        logger.info(f"Mounting Google Drive (Attempt {attempt + 1}/{max_retries})...")
        signal.signal(signal.SIGALRM, timeout_handler)
        signal.alarm(60)
        try:
            drive.mount('/content/drive', force_remount=True)
            signal.alarm(0)
            logger.info("Google Drive mounted successfully.")
            return True
        except TimeoutError:
            logger.warning("Timeout while mounting Google Drive.")
        except Exception as e:
            logger.warning(f"Failed to mount Google Drive: {e}")
        signal.alarm(0)
        if attempt < max_retries - 1:
            logger.info(f"Retrying in {retry_delay} seconds...")
            time.sleep(retry_delay)
    logger.error("Failed to mount Google Drive after all retries. Aborting...")
    raise Exception("Could not mount Google Drive")

# Unmount the drive if it's already mounted
if os.path.exists('/content/drive'):
    logger.info("Unmounting existing drive mount at /content/drive...")
    try:
        drive.flush_and_unmount()
        time.sleep(5)
        if os.path.exists('/content/drive'):
            shutil.rmtree('/content/drive', ignore_errors=True)
            logger.info("Removed /content/drive directory.")
    except Exception as e:
        logger.warning(f"Failed to unmount cleanly: {e}. Proceeding anyway...")

# Mount Google Drive
mount_google_drive()

# Update log directory now that Drive is mounted
log_dir = "/content/drive/MyDrive/✨ GP ✨/EchoNet_Dataset/EchoNet-Dynamic"
os.makedirs(log_dir, exist_ok=True)
new_log_file = os.path.join(log_dir, os.path.basename(log_file))
shutil.move(log_file, new_log_file)
log_file = new_log_file
logger.removeHandler(file_handler)
file_handler = logging.FileHandler(log_file)
file_handler.setLevel(logging.INFO)
file_handler.setFormatter(file_formatter)
logger.addHandler(file_handler)

# Define paths
csv_path = "/content/drive/MyDrive/✨ GP ✨/EchoNet_Dataset/EchoNet-Dynamic/VolumeTracings.csv"
output_path = "/content/drive/MyDrive/✨ GP ✨/EchoNet_Dataset/EchoNet-Dynamic/MaskTracings"

# Create the output directory
if os.path.exists(output_path):
    logger.info(f"Deleting existing MaskTracings directory at {output_path}...")
    shutil.rmtree(output_path)
os.makedirs(output_path, exist_ok=True)
logger.info(f"Created MaskTracings directory at {output_path}")

# Load the CSV file
logger.info(f"Loading CSV file from {csv_path}...")
try:
    df = pd.read_csv(csv_path)
    logger.info("Successfully loaded CSV file.")
except Exception as e:
    logger.error(f"Failed to load CSV file: {e}")
    raise

# Clean video names by removing .avi extension
df['FileName'] = df['FileName'].str.replace('.avi', '')

# Group data by FileName to process all videos
grouped = df.groupby("FileName")
total_videos = len(grouped)
logger.info(f"Total number of videos to process: {total_videos}")

# Function to create a filled binary mask using polygon filling
def create_filled_polygon_mask(tracings, frame_shape=(112, 112), video_name="", frame_number=""):
    # Step 1: Create an initial mask
    mask = np.zeros(frame_shape, dtype=np.uint8)
    if tracings.empty:
        return mask

    # Step 2: Collect all points from the line segments
    points = []
    for _, row in tracings.iterrows():
        start = (int(row['X1']), int(row['Y1']))
        end = (int(row['X2']), int(row['Y2']))
        # Clamp coordinates to image bounds
        start = (max(0, min(111, start[0])), max(0, min(111, start[1])))
        end = (max(0, min(111, end[0])), max(0, min(111, end[1])))
        points.append(start)
        points.append(end)

    # Step 3: Remove duplicates while preserving order
    seen = set()
    unique_points = []
    for pt in points:
        if pt not in seen:
            seen.add(pt)
            unique_points.append(pt)

    if len(unique_points) < 3:
        logger.warning(f"Not enough unique points to form a polygon for {video_name}_frame_{frame_number}. Returning empty mask.")
        return np.zeros(frame_shape, dtype=np.uint8)

    # Step 4: Sort points to form a closed loop
    # Compute centroid
    centroid_x = sum(pt[0] for pt in unique_points) / len(unique_points)
    centroid_y = sum(pt[1] for pt in unique_points) / len(unique_points)
    centroid = (centroid_x, centroid_y)

    # Sort points by angle from centroid
    def angle_from_centroid(pt):
        import math
        dx = pt[0] - centroid[0]
        dy = pt[1] - centroid[1]
        return math.atan2(dy, dx)

    sorted_points = sorted(unique_points, key=angle_from_centroid)

    # Convert to numpy array for cv2.fillPoly
    polygon_points = np.array(sorted_points, dtype=np.int32)

    # Step 5: Fill the polygon
    filled_mask = np.zeros(frame_shape, dtype=np.uint8)
    cv2.fillPoly(filled_mask, [polygon_points], 255)

    # Step 6: Ensure binary values (0 and 255)
    _, filled_mask = cv2.threshold(filled_mask, 127, 255, cv2.THRESH_BINARY)

    # Debug: Log unique values
    logger.info(f"Unique values in filled mask for {video_name}_frame_{frame_number}: {np.unique(filled_mask)}")

    return filled_mask

# Process each video
for video_idx, (video_name, group) in enumerate(grouped, 1):
    logger.info(f"Processing video {video_idx}/{total_videos}: {video_name}")

    # Create output subdirectory for this video
    video_output_path = os.path.join(output_path, video_name)
    os.makedirs(video_output_path, exist_ok=True)

    # Get unique frame numbers for this video
    unique_frames = group["Frame"].unique()
    if len(unique_frames) != 2:
        logger.warning(f"Video {video_name} does not have exactly 2 unique frames (found {len(unique_frames)}). Skipping...")
        continue

    # Process each frame
    for frame_number in unique_frames:
        logger.info(f"  Processing frame {frame_number} for {video_name}")
        frame_tracings = group[group['Frame'] == frame_number]
        if frame_tracings.empty:
            logger.warning(f"No tracings found for {video_name}_frame_{frame_number}. Skipping...")
            continue

        # Create the filled mask
        filled_mask = create_filled_polygon_mask(
            frame_tracings,
            video_name=video_name,
            frame_number=str(frame_number)
        )

        # Save the filled mask
        frame_filename = f"{video_name}_frame_{str(frame_number).zfill(4)}_segments.jpg"
        output_file_path = os.path.join(video_output_path, frame_filename)
        success = cv2.imwrite(output_file_path, filled_mask)
        if success:
            logger.info(f"Saved filled mask: {output_file_path}")
        else:
            logger.error(f"Failed to save filled mask: {output_file_path}")
            continue

# Summary
logger.info("\n[Summary]")
logger.info(f"Processed {total_videos} videos")
logger.info(f"Output saved in: {output_path}")
logger.info(f"Log file saved at: {log_file}")

# Force sync to ensure changes are visible
try:
    drive.flush_and_unmount()
    logger.info("Google Drive unmounted successfully.")
    drive.mount('/content/drive', force_remount=True)
    logger.info("Google Drive remounted successfully.")
except Exception as e:
    logger.error(f"Failed to sync Google Drive: {e}")
# Out:
# INFO:root:Unmounting existing drive mount at /content/drive...
# Unmounting existing drive mount at /content/drive...
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/logging/__init__.py", line 1114, in emit
#     self.flush()
#   File "/usr/lib/python3.11/logging/__init__.py", line 1094, in flush
#     self.stream.flush()
# OSError: [Errno 107] Transport endpoint is not connected
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/usr/local/lib/python3.11/dist-packages/colab_kernel_launcher.py", line 37, in <module>
#     ColabKernelApp.launch_instance()
#   File "/usr/local/lib/python3.11/dist-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelapp.py", line 712, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.11/dist-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 608, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 1936, in _run_once
#     handle._run()
#   File "/usr/lib/python3.11/asyncio/events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 730, in execute_request
#     reply_content = await reply_content
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py", line 383, in do_execute
#     res = shell.run_cell(
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2975, in run_cell
#     result = self._run_cell(
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-8e812cc3f6b3>", line 65, in <cell line: 0>
#     logger.info("Unmounting existing drive mount at /content/drive...")
# Message: 'Unmounting existing drive mount at /content/drive...'
# Arguments: ()
# Unmounting existing drive mount at /content/drive...
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/logging/__init__.py", line 1114, in emit
#     self.flush()
#   File "/usr/lib/python3.11/logging/__init__.py", line 1094, in flush
#     self.stream.flush()
# OSError: [Errno 107] Transport endpoint is not connected
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/usr/local/lib/python3.11/dist-packages/colab_kernel_launcher.py", line 37, in <module>
#     ColabKernelApp.launch_instance()
#   File "/usr/local/lib/python3.11/dist-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelapp.py", line 712, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.11/dist-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 608, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 1936, in _run_once
#     handle._run()
#   File "/usr/lib/python3.11/asyncio/events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 730, in execute_request
#     reply_content = await reply_content
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py", line 383, in do_execute
#     res = shell.run_cell(
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2975, in run_cell
#     result = self._run_cell(
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-8e812cc3f6b3>", line 65, in <cell line: 0>
#     logger.info("Unmounting existing drive mount at /content/drive...")
# Message: 'Unmounting existing drive mount at /content/drive...'
# Arguments: ()
# Unmounting existing drive mount at /content/drive...
# INFO:root:Mounting Google Drive (Attempt 1/3)...
# Mounting Google Drive (Attempt 1/3)...
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/logging/__init__.py", line 1114, in emit
#     self.flush()
#   File "/usr/lib/python3.11/logging/__init__.py", line 1094, in flush
#     self.stream.flush()
# OSError: [Errno 107] Transport endpoint is not connected
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/usr/local/lib/python3.11/dist-packages/colab_kernel_launcher.py", line 37, in <module>
#     ColabKernelApp.launch_instance()
#   File "/usr/local/lib/python3.11/dist-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelapp.py", line 712, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.11/dist-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 608, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 1936, in _run_once
#     handle._run()
#   File "/usr/lib/python3.11/asyncio/events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 730, in execute_request
#     reply_content = await reply_content
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py", line 383, in do_execute
#     res = shell.run_cell(
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2975, in run_cell
#     result = self._run_cell(
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-8e812cc3f6b3>", line 76, in <cell line: 0>
#     mount_google_drive()
#   File "<ipython-input-3-8e812cc3f6b3>", line 44, in mount_google_drive
#     logger.info(f"Mounting Google Drive (Attempt {attempt + 1}/{max_retries})...")
# Message: 'Mounting Google Drive (Attempt 1/3)...'
# Arguments: ()
# Mounting Google Drive (Attempt 1/3)...
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/logging/__init__.py", line 1114, in emit
#     self.flush()
#   File "/usr/lib/python3.11/logging/__init__.py", line 1094, in flush
#     self.stream.flush()
# OSError: [Errno 107] Transport endpoint is not connected
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/usr/local/lib/python3.11/dist-packages/colab_kernel_launcher.py", line 37, in <module>
#     ColabKernelApp.launch_instance()
#   File "/usr/local/lib/python3.11/dist-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelapp.py", line 712, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.11/dist-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 608, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 1936, in _run_once
#     handle._run()
#   File "/usr/lib/python3.11/asyncio/events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 730, in execute_request
#     reply_content = await reply_content
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py", line 383, in do_execute
#     res = shell.run_cell(
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2975, in run_cell
#     result = self._run_cell(
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-8e812cc3f6b3>", line 76, in <cell line: 0>
#     mount_google_drive()
#   File "<ipython-input-3-8e812cc3f6b3>", line 44, in mount_google_drive
#     logger.info(f"Mounting Google Drive (Attempt {attempt + 1}/{max_retries})...")
# Message: 'Mounting Google Drive (Attempt 1/3)...'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/logging/__init__.py", line 1114, in emit
#     self.flush()
#   File "/usr/lib/python3.11/logging/__init__.py", line 1094, in flush
#     self.stream.flush()
# OSError: [Errno 107] Transport endpoint is not connected
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/usr/local/lib/python3.11/dist-packages/colab_kernel_launcher.py", line 37, in <module>
#     ColabKernelApp.launch_instance()
#   File "/usr/local/lib/python3.11/dist-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelapp.py", line 712, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.11/dist-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 608, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 1936, in _run_once
#     handle._run()
#   File "/usr/lib/python3.11/asyncio/events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 730, in execute_request
#     reply_content = await reply_content
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py", line 383, in do_execute
#     res = shell.run_cell(
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2975, in run_cell
#     result = self._run_cell(
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-8e812cc3f6b3>", line 76, in <cell line: 0>
#     mount_google_drive()
#   File "<ipython-input-3-8e812cc3f6b3>", line 44, in mount_google_drive
#     logger.info(f"Mounting Google Drive (Attempt {attempt + 1}/{max_retries})...")
# Message: 'Mounting Google Drive (Attempt 1/3)...'
# Arguments: ()
# Mounting Google Drive (Attempt 1/3)...
# INFO:root:Google Drive mounted successfully.
# Google Drive mounted successfully.
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/logging/__init__.py", line 1114, in emit
#     self.flush()
#   File "/usr/lib/python3.11/logging/__init__.py", line 1094, in flush
#     self.stream.flush()
# OSError: [Errno 107] Transport endpoint is not connected
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/usr/local/lib/python3.11/dist-packages/colab_kernel_launcher.py", line 37, in <module>
#     ColabKernelApp.launch_instance()
#   File "/usr/local/lib/python3.11/dist-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelapp.py", line 712, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.11/dist-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 608, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 1936, in _run_once
#     handle._run()
#   File "/usr/lib/python3.11/asyncio/events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 730, in execute_request
#     reply_content = await reply_content
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py", line 383, in do_execute
#     res = shell.run_cell(
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2975, in run_cell
#     result = self._run_cell(
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-8e812cc3f6b3>", line 76, in <cell line: 0>
#     mount_google_drive()
#   File "<ipython-input-3-8e812cc3f6b3>", line 50, in mount_google_drive
#     logger.info("Google Drive mounted successfully.")
# Message: 'Google Drive mounted successfully.'
# Arguments: ()
# Google Drive mounted successfully.
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/logging/__init__.py", line 1114, in emit
#     self.flush()
#   File "/usr/lib/python3.11/logging/__init__.py", line 1094, in flush
#     self.stream.flush()
# OSError: [Errno 107] Transport endpoint is not connected
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/usr/local/lib/python3.11/dist-packages/colab_kernel_launcher.py", line 37, in <module>
#     ColabKernelApp.launch_instance()
#   File "/usr/local/lib/python3.11/dist-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelapp.py", line 712, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.11/dist-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 608, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 1936, in _run_once
#     handle._run()
#   File "/usr/lib/python3.11/asyncio/events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 730, in execute_request
#     reply_content = await reply_content
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py", line 383, in do_execute
#     res = shell.run_cell(
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2975, in run_cell
#     result = self._run_cell(
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-8e812cc3f6b3>", line 76, in <cell line: 0>
#     mount_google_drive()
#   File "<ipython-input-3-8e812cc3f6b3>", line 50, in mount_google_drive
#     logger.info("Google Drive mounted successfully.")
# Message: 'Google Drive mounted successfully.'
# Arguments: ()
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/logging/__init__.py", line 1114, in emit
#     self.flush()
#   File "/usr/lib/python3.11/logging/__init__.py", line 1094, in flush
#     self.stream.flush()
# OSError: [Errno 107] Transport endpoint is not connected
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/usr/local/lib/python3.11/dist-packages/colab_kernel_launcher.py", line 37, in <module>
#     ColabKernelApp.launch_instance()
#   File "/usr/local/lib/python3.11/dist-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelapp.py", line 712, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.11/dist-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 608, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 1936, in _run_once
#     handle._run()
#   File "/usr/lib/python3.11/asyncio/events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 730, in execute_request
#     reply_content = await reply_content
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py", line 383, in do_execute
#     res = shell.run_cell(
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2975, in run_cell
#     result = self._run_cell(
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-8e812cc3f6b3>", line 76, in <cell line: 0>
#     mount_google_drive()
#   File "<ipython-input-3-8e812cc3f6b3>", line 50, in mount_google_drive
#     logger.info("Google Drive mounted successfully.")
# Message: 'Google Drive mounted successfully.'
# Arguments: ()
# Google Drive mounted successfully.
# INFO:root:Created MaskTracings directory at /content/drive/MyDrive/✨ GP ✨/EchoNet_Dataset/EchoNet-Dynamic/MaskTracings
# Created MaskTracings directory at /content/drive/MyDrive/✨ GP ✨/EchoNet_Dataset/EchoNet-Dynamic/MaskTracings
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/logging/__init__.py", line 1114, in emit
#     self.flush()
#   File "/usr/lib/python3.11/logging/__init__.py", line 1094, in flush
#     self.stream.flush()
# OSError: [Errno 107] Transport endpoint is not connected
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/usr/local/lib/python3.11/dist-packages/colab_kernel_launcher.py", line 37, in <module>
#     ColabKernelApp.launch_instance()
#   File "/usr/local/lib/python3.11/dist-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelapp.py", line 712, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.11/dist-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 608, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 1936, in _run_once
#     handle._run()
#   File "/usr/lib/python3.11/asyncio/events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 730, in execute_request
#     reply_content = await reply_content
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py", line 383, in do_execute
#     res = shell.run_cell(
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2975, in run_cell
#     result = self._run_cell(
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-8e812cc3f6b3>", line 99, in <cell line: 0>
#     logger.info(f"Created MaskTracings directory at {output_path}")
# Message: 'Created MaskTracings directory at /content/drive/MyDrive/✨ GP ✨/EchoNet_Dataset/EchoNet-Dynamic/MaskTracings'
# Arguments: ()
# Created MaskTracings directory at /content/drive/MyDrive/✨ GP ✨/EchoNet_Dataset/EchoNet-Dynamic/MaskTracings
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/logging/__init__.py", line 1114, in emit
#     self.flush()
#   File "/usr/lib/python3.11/logging/__init__.py", line 1094, in flush
#     self.stream.flush()
# OSError: [Errno 107] Transport endpoint is not connected
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/usr/local/lib/python3.11/dist-packages/colab_kernel_launcher.py", line 37, in <module>
#     ColabKernelApp.launch_instance()
#   File "/usr/local/lib/python3.11/dist-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelapp.py", line 712, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.11/dist-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 608, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 1936, in _run_once
#     handle._run()
#   File "/usr/lib/python3.11/asyncio/events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 730, in execute_request
#     reply_content = await reply_content
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py", line 383, in do_execute
#     res = shell.run_cell(
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2975, in run_cell
#     result = self._run_cell(
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-8e812cc3f6b3>", line 99, in <cell line: 0>
#     logger.info(f"Created MaskTracings directory at {output_path}")
# Message: 'Created MaskTracings directory at /content/drive/MyDrive/✨ GP ✨/EchoNet_Dataset/EchoNet-Dynamic/MaskTracings'
# Arguments: ()
# Created MaskTracings directory at /content/drive/MyDrive/✨ GP ✨/EchoNet_Dataset/EchoNet-Dynamic/MaskTracings
# INFO:root:Loading CSV file from /content/drive/MyDrive/✨ GP ✨/EchoNet_Dataset/EchoNet-Dynamic/VolumeTracings.csv...
# Loading CSV file from /content/drive/MyDrive/✨ GP ✨/EchoNet_Dataset/EchoNet-Dynamic/VolumeTracings.csv...
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/logging/__init__.py", line 1114, in emit
#     self.flush()
#   File "/usr/lib/python3.11/logging/__init__.py", line 1094, in flush
#     self.stream.flush()
# OSError: [Errno 107] Transport endpoint is not connected
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/usr/local/lib/python3.11/dist-packages/colab_kernel_launcher.py", line 37, in <module>
#     ColabKernelApp.launch_instance()
#   File "/usr/local/lib/python3.11/dist-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelapp.py", line 712, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.11/dist-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 608, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 1936, in _run_once
#     handle._run()
#   File "/usr/lib/python3.11/asyncio/events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 730, in execute_request
#     reply_content = await reply_content
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py", line 383, in do_execute
#     res = shell.run_cell(
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2975, in run_cell
#     result = self._run_cell(
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-8e812cc3f6b3>", line 102, in <cell line: 0>
#     logger.info(f"Loading CSV file from {csv_path}...")
# Message: 'Loading CSV file from /content/drive/MyDrive/✨ GP ✨/EchoNet_Dataset/EchoNet-Dynamic/VolumeTracings.csv...'
# Arguments: ()
# Loading CSV file from /content/drive/MyDrive/✨ GP ✨/EchoNet_Dataset/EchoNet-Dynamic/VolumeTracings.csv...
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/logging/__init__.py", line 1114, in emit
#     self.flush()
#   File "/usr/lib/python3.11/logging/__init__.py", line 1094, in flush
#     self.stream.flush()
# OSError: [Errno 107] Transport endpoint is not connected
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/usr/local/lib/python3.11/dist-packages/colab_kernel_launcher.py", line 37, in <module>
#     ColabKernelApp.launch_instance()
#   File "/usr/local/lib/python3.11/dist-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelapp.py", line 712, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.11/dist-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 608, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 1936, in _run_once
#     handle._run()
#   File "/usr/lib/python3.11/asyncio/events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 730, in execute_request
#     reply_content = await reply_content
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py", line 383, in do_execute
#     res = shell.run_cell(
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2975, in run_cell
#     result = self._run_cell(
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-8e812cc3f6b3>", line 102, in <cell line: 0>
#     logger.info(f"Loading CSV file from {csv_path}...")
# Message: 'Loading CSV file from /content/drive/MyDrive/✨ GP ✨/EchoNet_Dataset/EchoNet-Dynamic/VolumeTracings.csv...'
# Arguments: ()
# Loading CSV file from /content/drive/MyDrive/✨ GP ✨/EchoNet_Dataset/EchoNet-Dynamic/VolumeTracings.csv...
# Mounted at /content/drive
# Streaming output truncated to the last 5000 lines.
#     self.io_loop.start()
#   File "/usr/local/lib/python3.11/dist-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 608, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 1936, in _run_once
#     handle._run()
#   File "/usr/lib/python3.11/asyncio/events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 730, in execute_request
#     reply_content = await reply_content
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py", line 383, in do_execute
#     res = shell.run_cell(
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2975, in run_cell
#     result = self._run_cell(
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-8e812cc3f6b3>", line 201, in <cell line: 0>
#     filled_mask = create_filled_polygon_mask(
#   File "<ipython-input-3-8e812cc3f6b3>", line 174, in create_filled_polygon_mask
#     logger.info(f"Unique values in filled mask for {video_name}_frame_{frame_number}: {np.unique(filled_mask)}")
# Message: 'Unique values in filled mask for 0XFDC39A88895DE1E_frame_42: [  0 255]'
# Arguments: ()
# Unique values in filled mask for 0XFDC39A88895DE1E_frame_42: [  0 255]
# INFO:root:Saved filled mask: /content/drive/MyDrive/✨ GP ✨/EchoNet_Dataset/EchoNet-Dynamic/MaskTracings/0XFDC39A88895DE1E/0XFDC39A88895DE1E_frame_0042_segments.jpg
# Saved filled mask: /content/drive/MyDrive/✨ GP ✨/EchoNet_Dataset/EchoNet-Dynamic/MaskTracings/0XFDC39A88895DE1E/0XFDC39A88895DE1E_frame_0042_segments.jpg
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/logging/__init__.py", line 1114, in emit
#     self.flush()
#   File "/usr/lib/python3.11/logging/__init__.py", line 1094, in flush
#     self.stream.flush()
# OSError: [Errno 107] Transport endpoint is not connected
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/usr/local/lib/python3.11/dist-packages/colab_kernel_launcher.py", line 37, in <module>
#     ColabKernelApp.launch_instance()
#   File "/usr/local/lib/python3.11/dist-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelapp.py", line 712, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.11/dist-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 608, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 1936, in _run_once
#     handle._run()
#   File "/usr/lib/python3.11/asyncio/events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 730, in execute_request
#     reply_content = await reply_content
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py", line 383, in do_execute
#     res = shell.run_cell(
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2975, in run_cell
#     result = self._run_cell(
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-8e812cc3f6b3>", line 212, in <cell line: 0>
#     logger.info(f"Saved filled mask: {output_file_path}")
# Message: 'Saved filled mask: /content/drive/MyDrive/✨ GP ✨/EchoNet_Dataset/EchoNet-Dynamic/MaskTracings/0XFDC39A88895DE1E/0XFDC39A88895DE1E_frame_0042_segments.jpg'
# Arguments: ()
# Saved filled mask: /content/drive/MyDrive/✨ GP ✨/EchoNet_Dataset/EchoNet-Dynamic/MaskTracings/0XFDC39A88895DE1E/0XFDC39A88895DE1E_frame_0042_segments.jpg
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/logging/__init__.py", line 1114, in emit
#     self.flush()
#   File "/usr/lib/python3.11/logging/__init__.py", line 1094, in flush
#     self.stream.flush()
# OSError: [Errno 107] Transport endpoint is not connected
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/usr/local/lib/python3.11/dist-packages/colab_kernel_launcher.py", line 37, in <module>
#     ColabKernelApp.launch_instance()
#   File "/usr/local/lib/python3.11/dist-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelapp.py", line 712, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.11/dist-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 608, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 1936, in _run_once
#     handle._run()
#   File "/usr/lib/python3.11/asyncio/events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 730, in execute_request
#     reply_content = await reply_content
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py", line 383, in do_execute
#     res = shell.run_cell(
# ...
#   File "<ipython-input-3-8e812cc3f6b3>", line 226, in <cell line: 0>
#     logger.info("Google Drive unmounted successfully.")
# Message: 'Google Drive unmounted successfully.'
# Arguments: ()
# Google Drive unmounted successfully.
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/logging/__init__.py", line 1114, in emit
#     self.flush()
#   File "/usr/lib/python3.11/logging/__init__.py", line 1094, in flush
#     self.stream.flush()
# OSError: [Errno 107] Transport endpoint is not connected
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/usr/local/lib/python3.11/dist-packages/colab_kernel_launcher.py", line 37, in <module>
#     ColabKernelApp.launch_instance()
#   File "/usr/local/lib/python3.11/dist-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelapp.py", line 712, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.11/dist-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 608, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 1936, in _run_once
#     handle._run()
#   File "/usr/lib/python3.11/asyncio/events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 730, in execute_request
#     reply_content = await reply_content
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py", line 383, in do_execute
#     res = shell.run_cell(
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2975, in run_cell
#     result = self._run_cell(
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-8e812cc3f6b3>", line 226, in <cell line: 0>
#     logger.info("Google Drive unmounted successfully.")
# Message: 'Google Drive unmounted successfully.'
# Arguments: ()
# Google Drive unmounted successfully.
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/logging/__init__.py", line 1114, in emit
#     self.flush()
#   File "/usr/lib/python3.11/logging/__init__.py", line 1094, in flush
#     self.stream.flush()
# OSError: [Errno 107] Transport endpoint is not connected
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/usr/local/lib/python3.11/dist-packages/colab_kernel_launcher.py", line 37, in <module>
#     ColabKernelApp.launch_instance()
#   File "/usr/local/lib/python3.11/dist-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelapp.py", line 712, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.11/dist-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 608, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 1936, in _run_once
#     handle._run()
#   File "/usr/lib/python3.11/asyncio/events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 730, in execute_request
#     reply_content = await reply_content
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py", line 383, in do_execute
#     res = shell.run_cell(
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2975, in run_cell
#     result = self._run_cell(
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-8e812cc3f6b3>", line 226, in <cell line: 0>
#     logger.info("Google Drive unmounted successfully.")
# Message: 'Google Drive unmounted successfully.'
# Arguments: ()
# INFO:root:Google Drive remounted successfully.
# Google Drive remounted successfully.
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/logging/__init__.py", line 1114, in emit
#     self.flush()
#   File "/usr/lib/python3.11/logging/__init__.py", line 1094, in flush
#     self.stream.flush()
# OSError: [Errno 107] Transport endpoint is not connected
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/usr/local/lib/python3.11/dist-packages/colab_kernel_launcher.py", line 37, in <module>
#     ColabKernelApp.launch_instance()
#   File "/usr/local/lib/python3.11/dist-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelapp.py", line 712, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.11/dist-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 608, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 1936, in _run_once
#     handle._run()
#   File "/usr/lib/python3.11/asyncio/events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 730, in execute_request
#     reply_content = await reply_content
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py", line 383, in do_execute
#     res = shell.run_cell(
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2975, in run_cell
#     result = self._run_cell(
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-8e812cc3f6b3>", line 228, in <cell line: 0>
#     logger.info("Google Drive remounted successfully.")
# Message: 'Google Drive remounted successfully.'
# Arguments: ()
# Google Drive remounted successfully.
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/logging/__init__.py", line 1114, in emit
#     self.flush()
#   File "/usr/lib/python3.11/logging/__init__.py", line 1094, in flush
#     self.stream.flush()
# OSError: [Errno 107] Transport endpoint is not connected
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/usr/local/lib/python3.11/dist-packages/colab_kernel_launcher.py", line 37, in <module>
#     ColabKernelApp.launch_instance()
#   File "/usr/local/lib/python3.11/dist-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelapp.py", line 712, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.11/dist-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 608, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 1936, in _run_once
#     handle._run()
#   File "/usr/lib/python3.11/asyncio/events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 730, in execute_request
#     reply_content = await reply_content
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py", line 383, in do_execute
#     res = shell.run_cell(
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2975, in run_cell
#     result = self._run_cell(
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-8e812cc3f6b3>", line 228, in <cell line: 0>
#     logger.info("Google Drive remounted successfully.")
# Message: 'Google Drive remounted successfully.'
# Arguments: ()
# Google Drive remounted successfully.
# Mounted at /content/drive
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/logging/__init__.py", line 1114, in emit
#     self.flush()
#   File "/usr/lib/python3.11/logging/__init__.py", line 1094, in flush
#     self.stream.flush()
# OSError: [Errno 107] Transport endpoint is not connected
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/usr/local/lib/python3.11/dist-packages/colab_kernel_launcher.py", line 37, in <module>
#     ColabKernelApp.launch_instance()
#   File "/usr/local/lib/python3.11/dist-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelapp.py", line 712, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.11/dist-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 608, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 1936, in _run_once
#     handle._run()
#   File "/usr/lib/python3.11/asyncio/events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 730, in execute_request
#     reply_content = await reply_content
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py", line 383, in do_execute
#     res = shell.run_cell(
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2975, in run_cell
#     result = self._run_cell(
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-8e812cc3f6b3>", line 228, in <cell line: 0>
#     logger.info("Google Drive remounted successfully.")
# Message: 'Google Drive remounted successfully.'
# Arguments: ()

# %% [markdown]
# # Masks Count Verification

# %%
import os
import pandas as pd
import logging
import shutil
import time
from datetime import datetime
from google.colab import drive

# Set up logging
log_dir = "/content/drive/MyDrive/✨ GP ✨/EchoNet_Dataset/EchoNet-Dynamic"
try:
    os.makedirs(log_dir, exist_ok=True)
except Exception as e:
    log_dir = "/content"
    print(f"Could not create log directory on Google Drive yet: {e}. Logging to /content temporarily.")

log_file = os.path.join(log_dir, f"verify_masktracings_log_{datetime.now().strftime('%Y%m%d_%H%M%S')}.txt")

logger = logging.getLogger()
logger.setLevel(logging.INFO)

file_handler = logging.FileHandler(log_file)
file_handler.setLevel(logging.INFO)
file_formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
file_handler.setFormatter(file_formatter)
logger.addHandler(file_handler)

console_handler = logging.StreamHandler()
console_handler.setLevel(logging.INFO)
console_formatter = logging.Formatter('%(message)s')
console_handler.setFormatter(console_formatter)
logger.addHandler(console_handler)

# Unmount the drive if it's already mounted
if os.path.exists('/content/drive'):
    logger.info("Unmounting existing drive mount at /content/drive...")
    try:
        drive.flush_and_unmount()
        time.sleep(5)
        if os.path.exists('/content/drive'):
            shutil.rmtree('/content/drive', ignore_errors=True)
            logger.info("Removed /content/drive directory.")
    except Exception as e:
        logger.warning(f"Failed to unmount cleanly: {e}. Proceeding anyway...")

# Mount Google Drive
logger.info("Mounting Google Drive...")
try:
    drive.mount('/content/drive', force_remount=True)
    logger.info("Google Drive mounted successfully.")
except Exception as e:
    logger.error(f"Failed to mount Google Drive: {e}")
    raise

# Update log directory now that Drive is mounted
log_dir = "/content/drive/MyDrive/✨ GP ✨/EchoNet_Dataset/EchoNet-Dynamic"
os.makedirs(log_dir, exist_ok=True)
new_log_file = os.path.join(log_dir, os.path.basename(log_file))
shutil.move(log_file, new_log_file)
log_file = new_log_file
logger.removeHandler(file_handler)
file_handler = logging.FileHandler(log_file)
file_handler.setLevel(logging.INFO)
file_handler.setFormatter(file_formatter)
logger.addHandler(file_handler)

# Constants
EXPECTED_VIDEOS = 10025
MASK_TRACINGS_PATH = "/content/drive/MyDrive/✨ GP ✨/EchoNet_Dataset/EchoNet-Dynamic/MaskTracings"
CSV_PATH = "/content/drive/MyDrive/✨ GP ✨/EchoNet_Dataset/EchoNet-Dynamic/VolumeTracings.csv"

# Load the CSV file
logger.info(f"Loading CSV file from {CSV_PATH}...")
try:
    df = pd.read_csv(CSV_PATH)
    logger.info("Successfully loaded CSV file.")
except Exception as e:
    logger.error(f"Failed to load CSV file: {e}")
    raise

# Clean video names by removing .avi extension
df['FileName'] = df['FileName'].str.replace('.avi', '')

# Group data by FileName to get frame numbers
grouped = df.groupby("FileName")

# Verify number of folders
video_dirs = [d for d in os.listdir(MASK_TRACINGS_PATH) if os.path.isdir(os.path.join(MASK_TRACINGS_PATH, d))]
num_folders = len(video_dirs)
logger.info(f"Found {num_folders} folders in {MASK_TRACINGS_PATH}. Expected: {EXPECTED_VIDEOS}")
if num_folders != EXPECTED_VIDEOS:
    logger.warning(f"Mismatch: Expected {EXPECTED_VIDEOS} folders, but found {num_folders}.")
else:
    logger.info("Number of folders matches the expected count.")

# Verify each folder has the correct 2 frames
mismatches = 0
for video_idx, video_name in enumerate(sorted(video_dirs), 1):
    video_path = os.path.join(MASK_TRACINGS_PATH, video_name)
    logger.info(f"Checking video {video_idx}/{num_folders}: {video_name}")

    # Get mask files
    mask_files = [f for f in os.listdir(video_path) if f.endswith('.jpg')]
    if len(mask_files) != 2:
        logger.error(f"Video {video_name} has {len(mask_files)} frames instead of 2. Files: {mask_files}")
        mismatches += 1
        continue

    # Extract frame numbers from filenames
    frame_numbers = [int(f.split('_frame_')[1].split('_segments')[0]) for f in mask_files]

    # Get expected frame numbers from CSV
    video_data = grouped.get_group(video_name) if video_name in grouped.groups else None
    if video_data is None:
        logger.error(f"No data found in CSV for video: {video_name}")
        mismatches += 1
        continue

    expected_frames = sorted(video_data["Frame"].unique())
    if len(expected_frames) != 2:
        logger.error(f"CSV data for {video_name} has {len(expected_frames)} unique frames instead of 2: {expected_frames}")
        mismatches += 1
        continue

    # Compare frame numbers
    if sorted(frame_numbers) != expected_frames:
        logger.error(f"Frame number mismatch for {video_name}. Expected: {expected_frames}, Found: {frame_numbers}")
        mismatches += 1
    else:
        logger.info(f"Video {video_name} has correct frames: {frame_numbers}")

# Summary
logger.info("\n[Summary]")
logger.info(f"Total folders checked: {num_folders}")
logger.info(f"Expected folders: {EXPECTED_VIDEOS}")
logger.info(f"Mismatches found: {mismatches}")
if mismatches == 0:
    logger.info("All folders contain the correct 2 frames matching the CSV.")
else:
    logger.warning(f"{mismatches} folders have issues (incorrect frame count or mismatch).")

print(f"Verification complete. Check {log_file} for details.")
# Out:
# INFO:root:Unmounting existing drive mount at /content/drive...
# Unmounting existing drive mount at /content/drive...
# Unmounting existing drive mount at /content/drive...
# Unmounting existing drive mount at /content/drive...
# Unmounting existing drive mount at /content/drive...
# INFO:root:Mounting Google Drive...
# Mounting Google Drive...
# Mounting Google Drive...
# Mounting Google Drive...
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/logging/__init__.py", line 1114, in emit
#     self.flush()
#   File "/usr/lib/python3.11/logging/__init__.py", line 1094, in flush
#     self.stream.flush()
# OSError: [Errno 107] Transport endpoint is not connected
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/usr/local/lib/python3.11/dist-packages/colab_kernel_launcher.py", line 37, in <module>
#     ColabKernelApp.launch_instance()
#   File "/usr/local/lib/python3.11/dist-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelapp.py", line 712, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.11/dist-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 608, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 1936, in _run_once
#     handle._run()
#   File "/usr/lib/python3.11/asyncio/events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 730, in execute_request
#     reply_content = await reply_content
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py", line 383, in do_execute
#     res = shell.run_cell(
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2975, in run_cell
#     result = self._run_cell(
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-4-b9a8151966c8>", line 47, in <cell line: 0>
#     logger.info("Mounting Google Drive...")
# Message: 'Mounting Google Drive...'
# Arguments: ()
# Mounting Google Drive...
# INFO:root:Google Drive mounted successfully.
# Google Drive mounted successfully.
# Google Drive mounted successfully.
# Google Drive mounted successfully.
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/logging/__init__.py", line 1114, in emit
#     self.flush()
#   File "/usr/lib/python3.11/logging/__init__.py", line 1094, in flush
#     self.stream.flush()
# OSError: [Errno 107] Transport endpoint is not connected
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/usr/local/lib/python3.11/dist-packages/colab_kernel_launcher.py", line 37, in <module>
#     ColabKernelApp.launch_instance()
#   File "/usr/local/lib/python3.11/dist-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelapp.py", line 712, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.11/dist-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 608, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 1936, in _run_once
#     handle._run()
#   File "/usr/lib/python3.11/asyncio/events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 730, in execute_request
#     reply_content = await reply_content
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py", line 383, in do_execute
#     res = shell.run_cell(
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2975, in run_cell
#     result = self._run_cell(
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-4-b9a8151966c8>", line 50, in <cell line: 0>
#     logger.info("Google Drive mounted successfully.")
# Message: 'Google Drive mounted successfully.'
# Arguments: ()
# Google Drive mounted successfully.
# INFO:root:Loading CSV file from /content/drive/MyDrive/✨ GP ✨/EchoNet_Dataset/EchoNet-Dynamic/VolumeTracings.csv...
# Loading CSV file from /content/drive/MyDrive/✨ GP ✨/EchoNet_Dataset/EchoNet-Dynamic/VolumeTracings.csv...
# Loading CSV file from /content/drive/MyDrive/✨ GP ✨/EchoNet_Dataset/EchoNet-Dynamic/VolumeTracings.csv...
# Loading CSV file from /content/drive/MyDrive/✨ GP ✨/EchoNet_Dataset/EchoNet-Dynamic/VolumeTracings.csv...
# Loading CSV file from /content/drive/MyDrive/✨ GP ✨/EchoNet_Dataset/EchoNet-Dynamic/VolumeTracings.csv...
# Mounted at /content/drive
# Streaming output truncated to the last 5000 lines.
# INFO:root:Checking video 9529/10025: 0X9E181B942CACADF
# Checking video 9529/10025: 0X9E181B942CACADF
# Checking video 9529/10025: 0X9E181B942CACADF
# Checking video 9529/10025: 0X9E181B942CACADF
# Checking video 9529/10025: 0X9E181B942CACADF
# INFO:root:Video 0X9E181B942CACADF has correct frames: [0, 18]
# Video 0X9E181B942CACADF has correct frames: [0, 18]
# Video 0X9E181B942CACADF has correct frames: [0, 18]
# Video 0X9E181B942CACADF has correct frames: [0, 18]
# Video 0X9E181B942CACADF has correct frames: [0, 18]
# INFO:root:Checking video 9530/10025: 0X9E37320F33E7ED
# Checking video 9530/10025: 0X9E37320F33E7ED
# Checking video 9530/10025: 0X9E37320F33E7ED
# Checking video 9530/10025: 0X9E37320F33E7ED
# Checking video 9530/10025: 0X9E37320F33E7ED
# INFO:root:Video 0X9E37320F33E7ED has correct frames: [187, 212]
# Video 0X9E37320F33E7ED has correct frames: [187, 212]
# Video 0X9E37320F33E7ED has correct frames: [187, 212]
# Video 0X9E37320F33E7ED has correct frames: [187, 212]
# Video 0X9E37320F33E7ED has correct frames: [187, 212]
# INFO:root:Checking video 9531/10025: 0X9E3B3B6B928DA58
# Checking video 9531/10025: 0X9E3B3B6B928DA58
# Checking video 9531/10025: 0X9E3B3B6B928DA58
# Checking video 9531/10025: 0X9E3B3B6B928DA58
# Checking video 9531/10025: 0X9E3B3B6B928DA58
# INFO:root:Video 0X9E3B3B6B928DA58 has correct frames: [262, 291]
# Video 0X9E3B3B6B928DA58 has correct frames: [262, 291]
# Video 0X9E3B3B6B928DA58 has correct frames: [262, 291]
# Video 0X9E3B3B6B928DA58 has correct frames: [262, 291]
# Video 0X9E3B3B6B928DA58 has correct frames: [262, 291]
# INFO:root:Checking video 9532/10025: 0X9E3D09429F6B852
# Checking video 9532/10025: 0X9E3D09429F6B852
# Checking video 9532/10025: 0X9E3D09429F6B852
# Checking video 9532/10025: 0X9E3D09429F6B852
# Checking video 9532/10025: 0X9E3D09429F6B852
# INFO:root:Video 0X9E3D09429F6B852 has correct frames: [128, 142]
# Video 0X9E3D09429F6B852 has correct frames: [128, 142]
# Video 0X9E3D09429F6B852 has correct frames: [128, 142]
# Video 0X9E3D09429F6B852 has correct frames: [128, 142]
# Video 0X9E3D09429F6B852 has correct frames: [128, 142]
# INFO:root:Checking video 9533/10025: 0X9E6E997496C87CC
# Checking video 9533/10025: 0X9E6E997496C87CC
# Checking video 9533/10025: 0X9E6E997496C87CC
# Checking video 9533/10025: 0X9E6E997496C87CC
# Checking video 9533/10025: 0X9E6E997496C87CC
# INFO:root:Video 0X9E6E997496C87CC has correct frames: [44, 59]
# Video 0X9E6E997496C87CC has correct frames: [44, 59]
# Video 0X9E6E997496C87CC has correct frames: [44, 59]
# Video 0X9E6E997496C87CC has correct frames: [44, 59]
# Video 0X9E6E997496C87CC has correct frames: [44, 59]
# INFO:root:Checking video 9534/10025: 0X9E72E2C8A9536F6
# Checking video 9534/10025: 0X9E72E2C8A9536F6
# Checking video 9534/10025: 0X9E72E2C8A9536F6
# Checking video 9534/10025: 0X9E72E2C8A9536F6
# Checking video 9534/10025: 0X9E72E2C8A9536F6
# INFO:root:Video 0X9E72E2C8A9536F6 has correct frames: [2, 12]
# Video 0X9E72E2C8A9536F6 has correct frames: [2, 12]
# Video 0X9E72E2C8A9536F6 has correct frames: [2, 12]
# Video 0X9E72E2C8A9536F6 has correct frames: [2, 12]
# Video 0X9E72E2C8A9536F6 has correct frames: [2, 12]
# INFO:root:Checking video 9535/10025: 0X9F2D61012CC7FCA
# Checking video 9535/10025: 0X9F2D61012CC7FCA
# Checking video 9535/10025: 0X9F2D61012CC7FCA
# Checking video 9535/10025: 0X9F2D61012CC7FCA
# Checking video 9535/10025: 0X9F2D61012CC7FCA
# INFO:root:Video 0X9F2D61012CC7FCA has correct frames: [41, 59]
# Video 0X9F2D61012CC7FCA has correct frames: [41, 59]
# Video 0X9F2D61012CC7FCA has correct frames: [41, 59]
# Video 0X9F2D61012CC7FCA has correct frames: [41, 59]
# Video 0X9F2D61012CC7FCA has correct frames: [41, 59]
# INFO:root:Checking video 9536/10025: 0X9F2E7A05C3B994C
# Checking video 9536/10025: 0X9F2E7A05C3B994C
# Checking video 9536/10025: 0X9F2E7A05C3B994C
# Checking video 9536/10025: 0X9F2E7A05C3B994C
# Checking video 9536/10025: 0X9F2E7A05C3B994C
# INFO:root:Video 0X9F2E7A05C3B994C has correct frames: [122, 140]
# Video 0X9F2E7A05C3B994C has correct frames: [122, 140]
# Video 0X9F2E7A05C3B994C has correct frames: [122, 140]
# Video 0X9F2E7A05C3B994C has correct frames: [122, 140]
# Video 0X9F2E7A05C3B994C has correct frames: [122, 140]
# INFO:root:Checking video 9537/10025: 0X9F47D732822A695
# Checking video 9537/10025: 0X9F47D732822A695
# Checking video 9537/10025: 0X9F47D732822A695
# Checking video 9537/10025: 0X9F47D732822A695
# Checking video 9537/10025: 0X9F47D732822A695
# INFO:root:Video 0X9F47D732822A695 has correct frames: [47, 69]
# Video 0X9F47D732822A695 has correct frames: [47, 69]
# Video 0X9F47D732822A695 has correct frames: [47, 69]
# Video 0X9F47D732822A695 has correct frames: [47, 69]
# Video 0X9F47D732822A695 has correct frames: [47, 69]
# INFO:root:Checking video 9538/10025: 0X9FB2E15488737AA
# Checking video 9538/10025: 0X9FB2E15488737AA
# Checking video 9538/10025: 0X9FB2E15488737AA
# Checking video 9538/10025: 0X9FB2E15488737AA
# Checking video 9538/10025: 0X9FB2E15488737AA
# INFO:root:Video 0X9FB2E15488737AA has correct frames: [157, 173]
# Video 0X9FB2E15488737AA has correct frames: [157, 173]
# Video 0X9FB2E15488737AA has correct frames: [157, 173]
# Video 0X9FB2E15488737AA has correct frames: [157, 173]
# Video 0X9FB2E15488737AA has correct frames: [157, 173]
# INFO:root:Checking video 9539/10025: 0X9FBEB56D70FA0B7
# Checking video 9539/10025: 0X9FBEB56D70FA0B7
# Checking video 9539/10025: 0X9FBEB56D70FA0B7
# Checking video 9539/10025: 0X9FBEB56D70FA0B7
# Checking video 9539/10025: 0X9FBEB56D70FA0B7
# INFO:root:Video 0X9FBEB56D70FA0B7 has correct frames: [65, 80]
# Video 0X9FBEB56D70FA0B7 has correct frames: [65, 80]
# Video 0X9FBEB56D70FA0B7 has correct frames: [65, 80]
# Video 0X9FBEB56D70FA0B7 has correct frames: [65, 80]
# Video 0X9FBEB56D70FA0B7 has correct frames: [65, 80]
# INFO:root:Checking video 9540/10025: 0XA05202904A89EAD
# Checking video 9540/10025: 0XA05202904A89EAD
# Checking video 9540/10025: 0XA05202904A89EAD
# Checking video 9540/10025: 0XA05202904A89EAD
# Checking video 9540/10025: 0XA05202904A89EAD
# INFO:root:Video 0XA05202904A89EAD has correct frames: [0, 21]
# Video 0XA05202904A89EAD has correct frames: [0, 21]
# Video 0XA05202904A89EAD has correct frames: [0, 21]
# Video 0XA05202904A89EAD has correct frames: [0, 21]
# Video 0XA05202904A89EAD has correct frames: [0, 21]
# INFO:root:Checking video 9541/10025: 0XA0FF3E0630F3902
# Checking video 9541/10025: 0XA0FF3E0630F3902
# Checking video 9541/10025: 0XA0FF3E0630F3902
# Checking video 9541/10025: 0XA0FF3E0630F3902
# Checking video 9541/10025: 0XA0FF3E0630F3902
# INFO:root:Video 0XA0FF3E0630F3902 has correct frames: [33, 43]
# Video 0XA0FF3E0630F3902 has correct frames: [33, 43]
# Video 0XA0FF3E0630F3902 has correct frames: [33, 43]
# Video 0XA0FF3E0630F3902 has correct frames: [33, 43]
# Video 0XA0FF3E0630F3902 has correct frames: [33, 43]
# INFO:root:Checking video 9542/10025: 0XA14DEADA0918C0C
# Checking video 9542/10025: 0XA14DEADA0918C0C
# Checking video 9542/10025: 0XA14DEADA0918C0C
# Checking video 9542/10025: 0XA14DEADA0918C0C
# Checking video 9542/10025: 0XA14DEADA0918C0C
# INFO:root:Video 0XA14DEADA0918C0C has correct frames: [0, 21]
# Video 0XA14DEADA0918C0C has correct frames: [0, 21]
# Video 0XA14DEADA0918C0C has correct frames: [0, 21]
# Video 0XA14DEADA0918C0C has correct frames: [0, 21]
# Video 0XA14DEADA0918C0C has correct frames: [0, 21]
# INFO:root:Checking video 9543/10025: 0XA1EC54A2895788E
# Checking video 9543/10025: 0XA1EC54A2895788E
# Checking video 9543/10025: 0XA1EC54A2895788E
# Checking video 9543/10025: 0XA1EC54A2895788E
# Checking video 9543/10025: 0XA1EC54A2895788E
# INFO:root:Video 0XA1EC54A2895788E has correct frames: [82, 95]
# Video 0XA1EC54A2895788E has correct frames: [82, 95]
# Video 0XA1EC54A2895788E has correct frames: [82, 95]
# Video 0XA1EC54A2895788E has correct frames: [82, 95]
# Video 0XA1EC54A2895788E has correct frames: [82, 95]
# INFO:root:Checking video 9544/10025: 0XA2092DD4255657B
# Checking video 9544/10025: 0XA2092DD4255657B
# Checking video 9544/10025: 0XA2092DD4255657B
# Checking video 9544/10025: 0XA2092DD4255657B
# Checking video 9544/10025: 0XA2092DD4255657B
# INFO:root:Video 0XA2092DD4255657B has correct frames: [105, 121]
# Video 0XA2092DD4255657B has correct frames: [105, 121]
# Video 0XA2092DD4255657B has correct frames: [105, 121]
# Video 0XA2092DD4255657B has correct frames: [105, 121]
# Video 0XA2092DD4255657B has correct frames: [105, 121]
# INFO:root:Checking video 9545/10025: 0XA20E92517726A99
# Checking video 9545/10025: 0XA20E92517726A99
# Checking video 9545/10025: 0XA20E92517726A99
# Checking video 9545/10025: 0XA20E92517726A99
# Checking video 9545/10025: 0XA20E92517726A99
# INFO:root:Video 0XA20E92517726A99 has correct frames: [55, 72]
# Video 0XA20E92517726A99 has correct frames: [55, 72]
# Video 0XA20E92517726A99 has correct frames: [55, 72]
# Video 0XA20E92517726A99 has correct frames: [55, 72]
# Video 0XA20E92517726A99 has correct frames: [55, 72]
# INFO:root:Checking video 9546/10025: 0XA20EE6C5B1F48CB
# Checking video 9546/10025: 0XA20EE6C5B1F48CB
# Checking video 9546/10025: 0XA20EE6C5B1F48CB
# Checking video 9546/10025: 0XA20EE6C5B1F48CB
# Checking video 9546/10025: 0XA20EE6C5B1F48CB
# INFO:root:Video 0XA20EE6C5B1F48CB has correct frames: [95, 116]
# Video 0XA20EE6C5B1F48CB has correct frames: [95, 116]
# Video 0XA20EE6C5B1F48CB has correct frames: [95, 116]
# Video 0XA20EE6C5B1F48CB has correct frames: [95, 116]
# Video 0XA20EE6C5B1F48CB has correct frames: [95, 116]
# INFO:root:Checking video 9547/10025: 0XA238B0B664FDCFE
# Checking video 9547/10025: 0XA238B0B664FDCFE
# Checking video 9547/10025: 0XA238B0B664FDCFE
# Checking video 9547/10025: 0XA238B0B664FDCFE
# Checking video 9547/10025: 0XA238B0B664FDCFE
# INFO:root:Video 0XA238B0B664FDCFE has correct frames: [51, 69]
# Video 0XA238B0B664FDCFE has correct frames: [51, 69]
# Video 0XA238B0B664FDCFE has correct frames: [51, 69]
# Video 0XA238B0B664FDCFE has correct frames: [51, 69]
# Video 0XA238B0B664FDCFE has correct frames: [51, 69]
# INFO:root:Checking video 9548/10025: 0XA23DF6B3D64C5A1
# Checking video 9548/10025: 0XA23DF6B3D64C5A1
# Checking video 9548/10025: 0XA23DF6B3D64C5A1
# Checking video 9548/10025: 0XA23DF6B3D64C5A1
# Checking video 9548/10025: 0XA23DF6B3D64C5A1
# INFO:root:Video 0XA23DF6B3D64C5A1 has correct frames: [88, 106]
# Video 0XA23DF6B3D64C5A1 has correct frames: [88, 106]
# Video 0XA23DF6B3D64C5A1 has correct frames: [88, 106]
# Video 0XA23DF6B3D64C5A1 has correct frames: [88, 106]
# Video 0XA23DF6B3D64C5A1 has correct frames: [88, 106]
# INFO:root:Checking video 9549/10025: 0XA27FDD7A35C6779
# Checking video 9549/10025: 0XA27FDD7A35C6779
# Checking video 9549/10025: 0XA27FDD7A35C6779
# Checking video 9549/10025: 0XA27FDD7A35C6779
# Checking video 9549/10025: 0XA27FDD7A35C6779
# INFO:root:Video 0XA27FDD7A35C6779 has correct frames: [116, 134]
# Video 0XA27FDD7A35C6779 has correct frames: [116, 134]
# Video 0XA27FDD7A35C6779 has correct frames: [116, 134]
# Video 0XA27FDD7A35C6779 has correct frames: [116, 134]
# Video 0XA27FDD7A35C6779 has correct frames: [116, 134]
# INFO:root:Checking video 9550/10025: 0XA28369AAB872CF2
# Checking video 9550/10025: 0XA28369AAB872CF2
# Checking video 9550/10025: 0XA28369AAB872CF2
# Checking video 9550/10025: 0XA28369AAB872CF2
# Checking video 9550/10025: 0XA28369AAB872CF2
# INFO:root:Video 0XA28369AAB872CF2 has correct frames: [39, 50]
# Video 0XA28369AAB872CF2 has correct frames: [39, 50]
# Video 0XA28369AAB872CF2 has correct frames: [39, 50]
# Video 0XA28369AAB872CF2 has correct frames: [39, 50]
# Video 0XA28369AAB872CF2 has correct frames: [39, 50]
# INFO:root:Checking video 9551/10025: 0XA29BAB8A42F22B5
# Checking video 9551/10025: 0XA29BAB8A42F22B5
# Checking video 9551/10025: 0XA29BAB8A42F22B5
# Checking video 9551/10025: 0XA29BAB8A42F22B5
# Checking video 9551/10025: 0XA29BAB8A42F22B5
# INFO:root:Video 0XA29BAB8A42F22B5 has correct frames: [77, 55]
# Video 0XA29BAB8A42F22B5 has correct frames: [77, 55]
# Video 0XA29BAB8A42F22B5 has correct frames: [77, 55]
# Video 0XA29BAB8A42F22B5 has correct frames: [77, 55]
# Video 0XA29BAB8A42F22B5 has correct frames: [77, 55]
# INFO:root:Checking video 9552/10025: 0XA2CE53842FD45BE
# Checking video 9552/10025: 0XA2CE53842FD45BE
# Checking video 9552/10025: 0XA2CE53842FD45BE
# Checking video 9552/10025: 0XA2CE53842FD45BE
# Checking video 9552/10025: 0XA2CE53842FD45BE
# INFO:root:Video 0XA2CE53842FD45BE has correct frames: [68, 81]
# Video 0XA2CE53842FD45BE has correct frames: [68, 81]
# Video 0XA2CE53842FD45BE has correct frames: [68, 81]
# Video 0XA2CE53842FD45BE has correct frames: [68, 81]
# Video 0XA2CE53842FD45BE has correct frames: [68, 81]
# INFO:root:Checking video 9553/10025: 0XA31E5D703BAE77A
# Checking video 9553/10025: 0XA31E5D703BAE77A
# Checking video 9553/10025: 0XA31E5D703BAE77A
# Checking video 9553/10025: 0XA31E5D703BAE77A
# Checking video 9553/10025: 0XA31E5D703BAE77A
# INFO:root:Video 0XA31E5D703BAE77A has correct frames: [81, 95]
# Video 0XA31E5D703BAE77A has correct frames: [81, 95]
# Video 0XA31E5D703BAE77A has correct frames: [81, 95]
# Video 0XA31E5D703BAE77A has correct frames: [81, 95]
# Video 0XA31E5D703BAE77A has correct frames: [81, 95]
# INFO:root:Checking video 9554/10025: 0XA3372C20EFD8726
# Checking video 9554/10025: 0XA3372C20EFD8726
# Checking video 9554/10025: 0XA3372C20EFD8726
# Checking video 9554/10025: 0XA3372C20EFD8726
# Checking video 9554/10025: 0XA3372C20EFD8726
# INFO:root:Video 0XA3372C20EFD8726 has correct frames: [188, 207]
# Video 0XA3372C20EFD8726 has correct frames: [188, 207]
# Video 0XA3372C20EFD8726 has correct frames: [188, 207]
# Video 0XA3372C20EFD8726 has correct frames: [188, 207]
# Video 0XA3372C20EFD8726 has correct frames: [188, 207]
# INFO:root:Checking video 9555/10025: 0XA3617C5EFEDD2E5
# Checking video 9555/10025: 0XA3617C5EFEDD2E5
# Checking video 9555/10025: 0XA3617C5EFEDD2E5
# Checking video 9555/10025: 0XA3617C5EFEDD2E5
# Checking video 9555/10025: 0XA3617C5EFEDD2E5
# INFO:root:Video 0XA3617C5EFEDD2E5 has correct frames: [103, 121]
# Video 0XA3617C5EFEDD2E5 has correct frames: [103, 121]
# Video 0XA3617C5EFEDD2E5 has correct frames: [103, 121]
# Video 0XA3617C5EFEDD2E5 has correct frames: [103, 121]
# Video 0XA3617C5EFEDD2E5 has correct frames: [103, 121]
# INFO:root:Checking video 9556/10025: 0XA3D91865EC953D9
# Checking video 9556/10025: 0XA3D91865EC953D9
# Checking video 9556/10025: 0XA3D91865EC953D9
# Checking video 9556/10025: 0XA3D91865EC953D9
# Checking video 9556/10025: 0XA3D91865EC953D9
# INFO:root:Video 0XA3D91865EC953D9 has correct frames: [88, 103]
# Video 0XA3D91865EC953D9 has correct frames: [88, 103]
# Video 0XA3D91865EC953D9 has correct frames: [88, 103]
# Video 0XA3D91865EC953D9 has correct frames: [88, 103]
# Video 0XA3D91865EC953D9 has correct frames: [88, 103]
# INFO:root:Checking video 9557/10025: 0XA3DC9C69839F5FA
# Checking video 9557/10025: 0XA3DC9C69839F5FA
# Checking video 9557/10025: 0XA3DC9C69839F5FA
# Checking video 9557/10025: 0XA3DC9C69839F5FA
# Checking video 9557/10025: 0XA3DC9C69839F5FA
# INFO:root:Video 0XA3DC9C69839F5FA has correct frames: [53, 71]
# Video 0XA3DC9C69839F5FA has correct frames: [53, 71]
# Video 0XA3DC9C69839F5FA has correct frames: [53, 71]
# Video 0XA3DC9C69839F5FA has correct frames: [53, 71]
# Video 0XA3DC9C69839F5FA has correct frames: [53, 71]
# INFO:root:Checking video 9558/10025: 0XA40AEF2A1787260
# Checking video 9558/10025: 0XA40AEF2A1787260
# Checking video 9558/10025: 0XA40AEF2A1787260
# Checking video 9558/10025: 0XA40AEF2A1787260
# Checking video 9558/10025: 0XA40AEF2A1787260
# INFO:root:Video 0XA40AEF2A1787260 has correct frames: [44, 63]
# Video 0XA40AEF2A1787260 has correct frames: [44, 63]
# Video 0XA40AEF2A1787260 has correct frames: [44, 63]
# Video 0XA40AEF2A1787260 has correct frames: [44, 63]
# Video 0XA40AEF2A1787260 has correct frames: [44, 63]
# INFO:root:Checking video 9559/10025: 0XA42F2AFCCCD336D
# Checking video 9559/10025: 0XA42F2AFCCCD336D
# Checking video 9559/10025: 0XA42F2AFCCCD336D
# Checking video 9559/10025: 0XA42F2AFCCCD336D
# Checking video 9559/10025: 0XA42F2AFCCCD336D
# INFO:root:Video 0XA42F2AFCCCD336D has correct frames: [64, 79]
# Video 0XA42F2AFCCCD336D has correct frames: [64, 79]
# Video 0XA42F2AFCCCD336D has correct frames: [64, 79]
# Video 0XA42F2AFCCCD336D has correct frames: [64, 79]
# Video 0XA42F2AFCCCD336D has correct frames: [64, 79]
# INFO:root:Checking video 9560/10025: 0XA43117B34833F33
# Checking video 9560/10025: 0XA43117B34833F33
# Checking video 9560/10025: 0XA43117B34833F33
# Checking video 9560/10025: 0XA43117B34833F33
# Checking video 9560/10025: 0XA43117B34833F33
# INFO:root:Video 0XA43117B34833F33 has correct frames: [48, 66]
# Video 0XA43117B34833F33 has correct frames: [48, 66]
# Video 0XA43117B34833F33 has correct frames: [48, 66]
# Video 0XA43117B34833F33 has correct frames: [48, 66]
# Video 0XA43117B34833F33 has correct frames: [48, 66]
# INFO:root:Checking video 9561/10025: 0XA45E4E31AD288AB
# Checking video 9561/10025: 0XA45E4E31AD288AB
# Checking video 9561/10025: 0XA45E4E31AD288AB
# Checking video 9561/10025: 0XA45E4E31AD288AB
# Checking video 9561/10025: 0XA45E4E31AD288AB
# INFO:root:Video 0XA45E4E31AD288AB has correct frames: [36, 50]
# Video 0XA45E4E31AD288AB has correct frames: [36, 50]
# Video 0XA45E4E31AD288AB has correct frames: [36, 50]
# Video 0XA45E4E31AD288AB has correct frames: [36, 50]
# Video 0XA45E4E31AD288AB has correct frames: [36, 50]
# INFO:root:Checking video 9562/10025: 0XA490B5C1BABF770
# Checking video 9562/10025: 0XA490B5C1BABF770
# Checking video 9562/10025: 0XA490B5C1BABF770
# Checking video 9562/10025: 0XA490B5C1BABF770
# Checking video 9562/10025: 0XA490B5C1BABF770
# INFO:root:Video 0XA490B5C1BABF770 has correct frames: [43, 61]
# Video 0XA490B5C1BABF770 has correct frames: [43, 61]
# Video 0XA490B5C1BABF770 has correct frames: [43, 61]
# Video 0XA490B5C1BABF770 has correct frames: [43, 61]
# Video 0XA490B5C1BABF770 has correct frames: [43, 61]
# INFO:root:Checking video 9563/10025: 0XA5323DD59E0A869
# Checking video 9563/10025: 0XA5323DD59E0A869
# Checking video 9563/10025: 0XA5323DD59E0A869
# Checking video 9563/10025: 0XA5323DD59E0A869
# Checking video 9563/10025: 0XA5323DD59E0A869
# INFO:root:Video 0XA5323DD59E0A869 has correct frames: [112, 132]
# Video 0XA5323DD59E0A869 has correct frames: [112, 132]
# Video 0XA5323DD59E0A869 has correct frames: [112, 132]
# Video 0XA5323DD59E0A869 has correct frames: [112, 132]
# Video 0XA5323DD59E0A869 has correct frames: [112, 132]
# INFO:root:Checking video 9564/10025: 0XA5BE050BEE27DE1
# Checking video 9564/10025: 0XA5BE050BEE27DE1
# Checking video 9564/10025: 0XA5BE050BEE27DE1
# Checking video 9564/10025: 0XA5BE050BEE27DE1
# Checking video 9564/10025: 0XA5BE050BEE27DE1
# INFO:root:Video 0XA5BE050BEE27DE1 has correct frames: [67, 83]
# Video 0XA5BE050BEE27DE1 has correct frames: [67, 83]
# Video 0XA5BE050BEE27DE1 has correct frames: [67, 83]
# Video 0XA5BE050BEE27DE1 has correct frames: [67, 83]
# Video 0XA5BE050BEE27DE1 has correct frames: [67, 83]
# INFO:root:Checking video 9565/10025: 0XA5C31C5A0108C30
# Checking video 9565/10025: 0XA5C31C5A0108C30
# Checking video 9565/10025: 0XA5C31C5A0108C30
# Checking video 9565/10025: 0XA5C31C5A0108C30
# Checking video 9565/10025: 0XA5C31C5A0108C30
# INFO:root:Video 0XA5C31C5A0108C30 has correct frames: [44, 59]
# Video 0XA5C31C5A0108C30 has correct frames: [44, 59]
# Video 0XA5C31C5A0108C30 has correct frames: [44, 59]
# Video 0XA5C31C5A0108C30 has correct frames: [44, 59]
# Video 0XA5C31C5A0108C30 has correct frames: [44, 59]
# INFO:root:Checking video 9566/10025: 0XA6098BB06A8586A
# Checking video 9566/10025: 0XA6098BB06A8586A
# Checking video 9566/10025: 0XA6098BB06A8586A
# Checking video 9566/10025: 0XA6098BB06A8586A
# Checking video 9566/10025: 0XA6098BB06A8586A
# INFO:root:Video 0XA6098BB06A8586A has correct frames: [97, 113]
# Video 0XA6098BB06A8586A has correct frames: [97, 113]
# Video 0XA6098BB06A8586A has correct frames: [97, 113]
# Video 0XA6098BB06A8586A has correct frames: [97, 113]
# Video 0XA6098BB06A8586A has correct frames: [97, 113]
# INFO:root:Checking video 9567/10025: 0XA61A892741BB67A
# Checking video 9567/10025: 0XA61A892741BB67A
# Checking video 9567/10025: 0XA61A892741BB67A
# Checking video 9567/10025: 0XA61A892741BB67A
# Checking video 9567/10025: 0XA61A892741BB67A
# INFO:root:Video 0XA61A892741BB67A has correct frames: [56, 66]
# Video 0XA61A892741BB67A has correct frames: [56, 66]
# Video 0XA61A892741BB67A has correct frames: [56, 66]
# Video 0XA61A892741BB67A has correct frames: [56, 66]
# Video 0XA61A892741BB67A has correct frames: [56, 66]
# INFO:root:Checking video 9568/10025: 0XA64090D4741F0BD
# Checking video 9568/10025: 0XA64090D4741F0BD
# Checking video 9568/10025: 0XA64090D4741F0BD
# Checking video 9568/10025: 0XA64090D4741F0BD
# Checking video 9568/10025: 0XA64090D4741F0BD
# INFO:root:Video 0XA64090D4741F0BD has correct frames: [46, 62]
# Video 0XA64090D4741F0BD has correct frames: [46, 62]
# Video 0XA64090D4741F0BD has correct frames: [46, 62]
# Video 0XA64090D4741F0BD has correct frames: [46, 62]
# Video 0XA64090D4741F0BD has correct frames: [46, 62]
# INFO:root:Checking video 9569/10025: 0XA684E725FD761B6
# Checking video 9569/10025: 0XA684E725FD761B6
# Checking video 9569/10025: 0XA684E725FD761B6
# Checking video 9569/10025: 0XA684E725FD761B6
# Checking video 9569/10025: 0XA684E725FD761B6
# INFO:root:Video 0XA684E725FD761B6 has correct frames: [144, 171]
# Video 0XA684E725FD761B6 has correct frames: [144, 171]
# Video 0XA684E725FD761B6 has correct frames: [144, 171]
# Video 0XA684E725FD761B6 has correct frames: [144, 171]
# Video 0XA684E725FD761B6 has correct frames: [144, 171]
# INFO:root:Checking video 9570/10025: 0XA69CDEAD15F2E1A
# Checking video 9570/10025: 0XA69CDEAD15F2E1A
# Checking video 9570/10025: 0XA69CDEAD15F2E1A
# Checking video 9570/10025: 0XA69CDEAD15F2E1A
# Checking video 9570/10025: 0XA69CDEAD15F2E1A
# INFO:root:Video 0XA69CDEAD15F2E1A has correct frames: [95, 111]
# Video 0XA69CDEAD15F2E1A has correct frames: [95, 111]
# Video 0XA69CDEAD15F2E1A has correct frames: [95, 111]
# Video 0XA69CDEAD15F2E1A has correct frames: [95, 111]
# Video 0XA69CDEAD15F2E1A has correct frames: [95, 111]
# INFO:root:Checking video 9571/10025: 0XA6A8F7E7AA0F98E
# Checking video 9571/10025: 0XA6A8F7E7AA0F98E
# Checking video 9571/10025: 0XA6A8F7E7AA0F98E
# Checking video 9571/10025: 0XA6A8F7E7AA0F98E
# Checking video 9571/10025: 0XA6A8F7E7AA0F98E
# INFO:root:Video 0XA6A8F7E7AA0F98E has correct frames: [75, 90]
# Video 0XA6A8F7E7AA0F98E has correct frames: [75, 90]
# Video 0XA6A8F7E7AA0F98E has correct frames: [75, 90]
# Video 0XA6A8F7E7AA0F98E has correct frames: [75, 90]
# Video 0XA6A8F7E7AA0F98E has correct frames: [75, 90]
# INFO:root:Checking video 9572/10025: 0XA6BD3BA9AAB064D
# Checking video 9572/10025: 0XA6BD3BA9AAB064D
# Checking video 9572/10025: 0XA6BD3BA9AAB064D
# Checking video 9572/10025: 0XA6BD3BA9AAB064D
# Checking video 9572/10025: 0XA6BD3BA9AAB064D
# INFO:root:Video 0XA6BD3BA9AAB064D has correct frames: [36, 51]
# Video 0XA6BD3BA9AAB064D has correct frames: [36, 51]
# Video 0XA6BD3BA9AAB064D has correct frames: [36, 51]
# Video 0XA6BD3BA9AAB064D has correct frames: [36, 51]
# Video 0XA6BD3BA9AAB064D has correct frames: [36, 51]
# INFO:root:Checking video 9573/10025: 0XA6D71323002CF21
# Checking video 9573/10025: 0XA6D71323002CF21
# Checking video 9573/10025: 0XA6D71323002CF21
# Checking video 9573/10025: 0XA6D71323002CF21
# Checking video 9573/10025: 0XA6D71323002CF21
# INFO:root:Video 0XA6D71323002CF21 has correct frames: [42, 61]
# Video 0XA6D71323002CF21 has correct frames: [42, 61]
# Video 0XA6D71323002CF21 has correct frames: [42, 61]
# Video 0XA6D71323002CF21 has correct frames: [42, 61]
# Video 0XA6D71323002CF21 has correct frames: [42, 61]
# INFO:root:Checking video 9574/10025: 0XA6D84E19F2DA13D
# Checking video 9574/10025: 0XA6D84E19F2DA13D
# Checking video 9574/10025: 0XA6D84E19F2DA13D
# Checking video 9574/10025: 0XA6D84E19F2DA13D
# Checking video 9574/10025: 0XA6D84E19F2DA13D
# INFO:root:Video 0XA6D84E19F2DA13D has correct frames: [36, 52]
# Video 0XA6D84E19F2DA13D has correct frames: [36, 52]
# Video 0XA6D84E19F2DA13D has correct frames: [36, 52]
# Video 0XA6D84E19F2DA13D has correct frames: [36, 52]
# Video 0XA6D84E19F2DA13D has correct frames: [36, 52]
# INFO:root:Checking video 9575/10025: 0XA6E09CACE38DD02
# Checking video 9575/10025: 0XA6E09CACE38DD02
# Checking video 9575/10025: 0XA6E09CACE38DD02
# Checking video 9575/10025: 0XA6E09CACE38DD02
# Checking video 9575/10025: 0XA6E09CACE38DD02
# INFO:root:Video 0XA6E09CACE38DD02 has correct frames: [48, 64]
# Video 0XA6E09CACE38DD02 has correct frames: [48, 64]
# Video 0XA6E09CACE38DD02 has correct frames: [48, 64]
# Video 0XA6E09CACE38DD02 has correct frames: [48, 64]
# Video 0XA6E09CACE38DD02 has correct frames: [48, 64]
# INFO:root:Checking video 9576/10025: 0XA72DE0C1F32EA64
# Checking video 9576/10025: 0XA72DE0C1F32EA64
# Checking video 9576/10025: 0XA72DE0C1F32EA64
# Checking video 9576/10025: 0XA72DE0C1F32EA64
# Checking video 9576/10025: 0XA72DE0C1F32EA64
# INFO:root:Video 0XA72DE0C1F32EA64 has correct frames: [8, 22]
# Video 0XA72DE0C1F32EA64 has correct frames: [8, 22]
# Video 0XA72DE0C1F32EA64 has correct frames: [8, 22]
# Video 0XA72DE0C1F32EA64 has correct frames: [8, 22]
# Video 0XA72DE0C1F32EA64 has correct frames: [8, 22]
# INFO:root:Checking video 9577/10025: 0XA72F656E23C7F53
# Checking video 9577/10025: 0XA72F656E23C7F53
# Checking video 9577/10025: 0XA72F656E23C7F53
# Checking video 9577/10025: 0XA72F656E23C7F53
# Checking video 9577/10025: 0XA72F656E23C7F53
# INFO:root:Video 0XA72F656E23C7F53 has correct frames: [3, 17]
# Video 0XA72F656E23C7F53 has correct frames: [3, 17]
# Video 0XA72F656E23C7F53 has correct frames: [3, 17]
# Video 0XA72F656E23C7F53 has correct frames: [3, 17]
# Video 0XA72F656E23C7F53 has correct frames: [3, 17]
# INFO:root:Checking video 9578/10025: 0XA789C0D93B1DF7A
# Checking video 9578/10025: 0XA789C0D93B1DF7A
# Checking video 9578/10025: 0XA789C0D93B1DF7A
# Checking video 9578/10025: 0XA789C0D93B1DF7A
# Checking video 9578/10025: 0XA789C0D93B1DF7A
# INFO:root:Video 0XA789C0D93B1DF7A has correct frames: [49, 63]
# Video 0XA789C0D93B1DF7A has correct frames: [49, 63]
# Video 0XA789C0D93B1DF7A has correct frames: [49, 63]
# Video 0XA789C0D93B1DF7A has correct frames: [49, 63]
# Video 0XA789C0D93B1DF7A has correct frames: [49, 63]
# INFO:root:Checking video 9579/10025: 0XA7F4EE9647DF974
# Checking video 9579/10025: 0XA7F4EE9647DF974
# Checking video 9579/10025: 0XA7F4EE9647DF974
# Checking video 9579/10025: 0XA7F4EE9647DF974
# Checking video 9579/10025: 0XA7F4EE9647DF974
# INFO:root:Video 0XA7F4EE9647DF974 has correct frames: [5, 26]
# Video 0XA7F4EE9647DF974 has correct frames: [5, 26]
# Video 0XA7F4EE9647DF974 has correct frames: [5, 26]
# Video 0XA7F4EE9647DF974 has correct frames: [5, 26]
# Video 0XA7F4EE9647DF974 has correct frames: [5, 26]
# INFO:root:Checking video 9580/10025: 0XA8324479A861D01
# Checking video 9580/10025: 0XA8324479A861D01
# Checking video 9580/10025: 0XA8324479A861D01
# Checking video 9580/10025: 0XA8324479A861D01
# Checking video 9580/10025: 0XA8324479A861D01
# INFO:root:Video 0XA8324479A861D01 has correct frames: [118, 131]
# Video 0XA8324479A861D01 has correct frames: [118, 131]
# Video 0XA8324479A861D01 has correct frames: [118, 131]
# Video 0XA8324479A861D01 has correct frames: [118, 131]
# Video 0XA8324479A861D01 has correct frames: [118, 131]
# INFO:root:Checking video 9581/10025: 0XA837A17982E7335
# Checking video 9581/10025: 0XA837A17982E7335
# Checking video 9581/10025: 0XA837A17982E7335
# Checking video 9581/10025: 0XA837A17982E7335
# Checking video 9581/10025: 0XA837A17982E7335
# INFO:root:Video 0XA837A17982E7335 has correct frames: [84, 101]
# Video 0XA837A17982E7335 has correct frames: [84, 101]
# Video 0XA837A17982E7335 has correct frames: [84, 101]
# Video 0XA837A17982E7335 has correct frames: [84, 101]
# Video 0XA837A17982E7335 has correct frames: [84, 101]
# INFO:root:Checking video 9582/10025: 0XA84957F45657A67
# Checking video 9582/10025: 0XA84957F45657A67
# Checking video 9582/10025: 0XA84957F45657A67
# Checking video 9582/10025: 0XA84957F45657A67
# Checking video 9582/10025: 0XA84957F45657A67
# INFO:root:Video 0XA84957F45657A67 has correct frames: [84, 97]
# Video 0XA84957F45657A67 has correct frames: [84, 97]
# Video 0XA84957F45657A67 has correct frames: [84, 97]
# Video 0XA84957F45657A67 has correct frames: [84, 97]
# Video 0XA84957F45657A67 has correct frames: [84, 97]
# INFO:root:Checking video 9583/10025: 0XA86485C87693449
# Checking video 9583/10025: 0XA86485C87693449
# Checking video 9583/10025: 0XA86485C87693449
# Checking video 9583/10025: 0XA86485C87693449
# Checking video 9583/10025: 0XA86485C87693449
# INFO:root:Video 0XA86485C87693449 has correct frames: [31, 44]
# Video 0XA86485C87693449 has correct frames: [31, 44]
# Video 0XA86485C87693449 has correct frames: [31, 44]
# Video 0XA86485C87693449 has correct frames: [31, 44]
# Video 0XA86485C87693449 has correct frames: [31, 44]
# INFO:root:Checking video 9584/10025: 0XA8C2902A686BF34
# Checking video 9584/10025: 0XA8C2902A686BF34
# Checking video 9584/10025: 0XA8C2902A686BF34
# Checking video 9584/10025: 0XA8C2902A686BF34
# Checking video 9584/10025: 0XA8C2902A686BF34
# INFO:root:Video 0XA8C2902A686BF34 has correct frames: [48, 67]
# Video 0XA8C2902A686BF34 has correct frames: [48, 67]
# Video 0XA8C2902A686BF34 has correct frames: [48, 67]
# Video 0XA8C2902A686BF34 has correct frames: [48, 67]
# Video 0XA8C2902A686BF34 has correct frames: [48, 67]
# INFO:root:Checking video 9585/10025: 0XA8EB154B86EAEE7
# Checking video 9585/10025: 0XA8EB154B86EAEE7
# Checking video 9585/10025: 0XA8EB154B86EAEE7
# Checking video 9585/10025: 0XA8EB154B86EAEE7
# Checking video 9585/10025: 0XA8EB154B86EAEE7
# INFO:root:Video 0XA8EB154B86EAEE7 has correct frames: [60, 73]
# Video 0XA8EB154B86EAEE7 has correct frames: [60, 73]
# Video 0XA8EB154B86EAEE7 has correct frames: [60, 73]
# Video 0XA8EB154B86EAEE7 has correct frames: [60, 73]
# Video 0XA8EB154B86EAEE7 has correct frames: [60, 73]
# INFO:root:Checking video 9586/10025: 0XA94EE36D10C4D70
# Checking video 9586/10025: 0XA94EE36D10C4D70
# Checking video 9586/10025: 0XA94EE36D10C4D70
# Checking video 9586/10025: 0XA94EE36D10C4D70
# Checking video 9586/10025: 0XA94EE36D10C4D70
# INFO:root:Video 0XA94EE36D10C4D70 has correct frames: [42, 57]
# Video 0XA94EE36D10C4D70 has correct frames: [42, 57]
# Video 0XA94EE36D10C4D70 has correct frames: [42, 57]
# Video 0XA94EE36D10C4D70 has correct frames: [42, 57]
# Video 0XA94EE36D10C4D70 has correct frames: [42, 57]
# INFO:root:Checking video 9587/10025: 0XA951AB7646161AE
# Checking video 9587/10025: 0XA951AB7646161AE
# Checking video 9587/10025: 0XA951AB7646161AE
# Checking video 9587/10025: 0XA951AB7646161AE
# Checking video 9587/10025: 0XA951AB7646161AE
# INFO:root:Video 0XA951AB7646161AE has correct frames: [79, 97]
# Video 0XA951AB7646161AE has correct frames: [79, 97]
# Video 0XA951AB7646161AE has correct frames: [79, 97]
# Video 0XA951AB7646161AE has correct frames: [79, 97]
# Video 0XA951AB7646161AE has correct frames: [79, 97]
# INFO:root:Checking video 9588/10025: 0XA97434292889BC4
# Checking video 9588/10025: 0XA97434292889BC4
# Checking video 9588/10025: 0XA97434292889BC4
# Checking video 9588/10025: 0XA97434292889BC4
# Checking video 9588/10025: 0XA97434292889BC4
# INFO:root:Video 0XA97434292889BC4 has correct frames: [61, 84]
# Video 0XA97434292889BC4 has correct frames: [61, 84]
# Video 0XA97434292889BC4 has correct frames: [61, 84]
# Video 0XA97434292889BC4 has correct frames: [61, 84]
# Video 0XA97434292889BC4 has correct frames: [61, 84]
# INFO:root:Checking video 9589/10025: 0XA989DD619F4AB85
# Checking video 9589/10025: 0XA989DD619F4AB85
# Checking video 9589/10025: 0XA989DD619F4AB85
# Checking video 9589/10025: 0XA989DD619F4AB85
# Checking video 9589/10025: 0XA989DD619F4AB85
# INFO:root:Video 0XA989DD619F4AB85 has correct frames: [38, 52]
# Video 0XA989DD619F4AB85 has correct frames: [38, 52]
# Video 0XA989DD619F4AB85 has correct frames: [38, 52]
# Video 0XA989DD619F4AB85 has correct frames: [38, 52]
# Video 0XA989DD619F4AB85 has correct frames: [38, 52]
# INFO:root:Checking video 9590/10025: 0XAA023992D00F604
# Checking video 9590/10025: 0XAA023992D00F604
# Checking video 9590/10025: 0XAA023992D00F604
# Checking video 9590/10025: 0XAA023992D00F604
# Checking video 9590/10025: 0XAA023992D00F604
# INFO:root:Video 0XAA023992D00F604 has correct frames: [4, 16]
# Video 0XAA023992D00F604 has correct frames: [4, 16]
# Video 0XAA023992D00F604 has correct frames: [4, 16]
# Video 0XAA023992D00F604 has correct frames: [4, 16]
# Video 0XAA023992D00F604 has correct frames: [4, 16]
# INFO:root:Checking video 9591/10025: 0XAA304E75C4EE3E9
# Checking video 9591/10025: 0XAA304E75C4EE3E9
# Checking video 9591/10025: 0XAA304E75C4EE3E9
# Checking video 9591/10025: 0XAA304E75C4EE3E9
# Checking video 9591/10025: 0XAA304E75C4EE3E9
# INFO:root:Video 0XAA304E75C4EE3E9 has correct frames: [91, 99]
# Video 0XAA304E75C4EE3E9 has correct frames: [91, 99]
# Video 0XAA304E75C4EE3E9 has correct frames: [91, 99]
# Video 0XAA304E75C4EE3E9 has correct frames: [91, 99]
# Video 0XAA304E75C4EE3E9 has correct frames: [91, 99]
# INFO:root:Checking video 9592/10025: 0XAA3A306D4EC8B69
# Checking video 9592/10025: 0XAA3A306D4EC8B69
# Checking video 9592/10025: 0XAA3A306D4EC8B69
# Checking video 9592/10025: 0XAA3A306D4EC8B69
# Checking video 9592/10025: 0XAA3A306D4EC8B69
# INFO:root:Video 0XAA3A306D4EC8B69 has correct frames: [137, 162]
# Video 0XAA3A306D4EC8B69 has correct frames: [137, 162]
# Video 0XAA3A306D4EC8B69 has correct frames: [137, 162]
# Video 0XAA3A306D4EC8B69 has correct frames: [137, 162]
# Video 0XAA3A306D4EC8B69 has correct frames: [137, 162]
# INFO:root:Checking video 9593/10025: 0XAA3E06425E1A23E
# Checking video 9593/10025: 0XAA3E06425E1A23E
# Checking video 9593/10025: 0XAA3E06425E1A23E
# Checking video 9593/10025: 0XAA3E06425E1A23E
# Checking video 9593/10025: 0XAA3E06425E1A23E
# INFO:root:Video 0XAA3E06425E1A23E has correct frames: [73, 86]
# Video 0XAA3E06425E1A23E has correct frames: [73, 86]
# Video 0XAA3E06425E1A23E has correct frames: [73, 86]
# Video 0XAA3E06425E1A23E has correct frames: [73, 86]
# Video 0XAA3E06425E1A23E has correct frames: [73, 86]
# INFO:root:Checking video 9594/10025: 0XAA4741B7E7194A2
# Checking video 9594/10025: 0XAA4741B7E7194A2
# Checking video 9594/10025: 0XAA4741B7E7194A2
# Checking video 9594/10025: 0XAA4741B7E7194A2
# Checking video 9594/10025: 0XAA4741B7E7194A2
# INFO:root:Video 0XAA4741B7E7194A2 has correct frames: [51, 69]
# Video 0XAA4741B7E7194A2 has correct frames: [51, 69]
# Video 0XAA4741B7E7194A2 has correct frames: [51, 69]
# Video 0XAA4741B7E7194A2 has correct frames: [51, 69]
# Video 0XAA4741B7E7194A2 has correct frames: [51, 69]
# INFO:root:Checking video 9595/10025: 0XAA68800871BD1FD
# Checking video 9595/10025: 0XAA68800871BD1FD
# Checking video 9595/10025: 0XAA68800871BD1FD
# Checking video 9595/10025: 0XAA68800871BD1FD
# Checking video 9595/10025: 0XAA68800871BD1FD
# INFO:root:Video 0XAA68800871BD1FD has correct frames: [72, 88]
# Video 0XAA68800871BD1FD has correct frames: [72, 88]
# Video 0XAA68800871BD1FD has correct frames: [72, 88]
# Video 0XAA68800871BD1FD has correct frames: [72, 88]
# Video 0XAA68800871BD1FD has correct frames: [72, 88]
# INFO:root:Checking video 9596/10025: 0XAAB25926214E746
# Checking video 9596/10025: 0XAAB25926214E746
# Checking video 9596/10025: 0XAAB25926214E746
# Checking video 9596/10025: 0XAAB25926214E746
# Checking video 9596/10025: 0XAAB25926214E746
# INFO:root:Video 0XAAB25926214E746 has correct frames: [93, 112]
# Video 0XAAB25926214E746 has correct frames: [93, 112]
# Video 0XAAB25926214E746 has correct frames: [93, 112]
# Video 0XAAB25926214E746 has correct frames: [93, 112]
# Video 0XAAB25926214E746 has correct frames: [93, 112]
# INFO:root:Checking video 9597/10025: 0XAABEF7BA895A967
# Checking video 9597/10025: 0XAABEF7BA895A967
# Checking video 9597/10025: 0XAABEF7BA895A967
# Checking video 9597/10025: 0XAABEF7BA895A967
# Checking video 9597/10025: 0XAABEF7BA895A967
# INFO:root:Video 0XAABEF7BA895A967 has correct frames: [80, 96]
# Video 0XAABEF7BA895A967 has correct frames: [80, 96]
# Video 0XAABEF7BA895A967 has correct frames: [80, 96]
# Video 0XAABEF7BA895A967 has correct frames: [80, 96]
# Video 0XAABEF7BA895A967 has correct frames: [80, 96]
# INFO:root:Checking video 9598/10025: 0XAAFC07869635B00
# Checking video 9598/10025: 0XAAFC07869635B00
# Checking video 9598/10025: 0XAAFC07869635B00
# Checking video 9598/10025: 0XAAFC07869635B00
# Checking video 9598/10025: 0XAAFC07869635B00
# INFO:root:Video 0XAAFC07869635B00 has correct frames: [76, 92]
# Video 0XAAFC07869635B00 has correct frames: [76, 92]
# Video 0XAAFC07869635B00 has correct frames: [76, 92]
# Video 0XAAFC07869635B00 has correct frames: [76, 92]
# Video 0XAAFC07869635B00 has correct frames: [76, 92]
# INFO:root:Checking video 9599/10025: 0XAB497CBE6A93DA1
# Checking video 9599/10025: 0XAB497CBE6A93DA1
# Checking video 9599/10025: 0XAB497CBE6A93DA1
# Checking video 9599/10025: 0XAB497CBE6A93DA1
# Checking video 9599/10025: 0XAB497CBE6A93DA1
# INFO:root:Video 0XAB497CBE6A93DA1 has correct frames: [66, 85]
# Video 0XAB497CBE6A93DA1 has correct frames: [66, 85]
# Video 0XAB497CBE6A93DA1 has correct frames: [66, 85]
# Video 0XAB497CBE6A93DA1 has correct frames: [66, 85]
# Video 0XAB497CBE6A93DA1 has correct frames: [66, 85]
# INFO:root:Checking video 9600/10025: 0XAB701373CBCF5FC
# Checking video 9600/10025: 0XAB701373CBCF5FC
# Checking video 9600/10025: 0XAB701373CBCF5FC
# Checking video 9600/10025: 0XAB701373CBCF5FC
# Checking video 9600/10025: 0XAB701373CBCF5FC
# INFO:root:Video 0XAB701373CBCF5FC has correct frames: [51, 66]
# Video 0XAB701373CBCF5FC has correct frames: [51, 66]
# Video 0XAB701373CBCF5FC has correct frames: [51, 66]
# Video 0XAB701373CBCF5FC has correct frames: [51, 66]
# Video 0XAB701373CBCF5FC has correct frames: [51, 66]
# INFO:root:Checking video 9601/10025: 0XAB7D06D7A122D44
# Checking video 9601/10025: 0XAB7D06D7A122D44
# Checking video 9601/10025: 0XAB7D06D7A122D44
# Checking video 9601/10025: 0XAB7D06D7A122D44
# Checking video 9601/10025: 0XAB7D06D7A122D44
# INFO:root:Video 0XAB7D06D7A122D44 has correct frames: [81, 93]
# Video 0XAB7D06D7A122D44 has correct frames: [81, 93]
# Video 0XAB7D06D7A122D44 has correct frames: [81, 93]
# Video 0XAB7D06D7A122D44 has correct frames: [81, 93]
# Video 0XAB7D06D7A122D44 has correct frames: [81, 93]
# INFO:root:Checking video 9602/10025: 0XAB8C29BE4841CB0
# Checking video 9602/10025: 0XAB8C29BE4841CB0
# Checking video 9602/10025: 0XAB8C29BE4841CB0
# Checking video 9602/10025: 0XAB8C29BE4841CB0
# Checking video 9602/10025: 0XAB8C29BE4841CB0
# INFO:root:Video 0XAB8C29BE4841CB0 has correct frames: [61, 82]
# Video 0XAB8C29BE4841CB0 has correct frames: [61, 82]
# Video 0XAB8C29BE4841CB0 has correct frames: [61, 82]
# Video 0XAB8C29BE4841CB0 has correct frames: [61, 82]
# Video 0XAB8C29BE4841CB0 has correct frames: [61, 82]
# INFO:root:Checking video 9603/10025: 0XABA4614974D17D9
# Checking video 9603/10025: 0XABA4614974D17D9
# Checking video 9603/10025: 0XABA4614974D17D9
# Checking video 9603/10025: 0XABA4614974D17D9
# Checking video 9603/10025: 0XABA4614974D17D9
# INFO:root:Video 0XABA4614974D17D9 has correct frames: [54, 71]
# Video 0XABA4614974D17D9 has correct frames: [54, 71]
# Video 0XABA4614974D17D9 has correct frames: [54, 71]
# Video 0XABA4614974D17D9 has correct frames: [54, 71]
# Video 0XABA4614974D17D9 has correct frames: [54, 71]
# INFO:root:Checking video 9604/10025: 0XABB712C1939FBC5
# Checking video 9604/10025: 0XABB712C1939FBC5
# Checking video 9604/10025: 0XABB712C1939FBC5
# Checking video 9604/10025: 0XABB712C1939FBC5
# Checking video 9604/10025: 0XABB712C1939FBC5
# INFO:root:Video 0XABB712C1939FBC5 has correct frames: [0, 17]
# Video 0XABB712C1939FBC5 has correct frames: [0, 17]
# Video 0XABB712C1939FBC5 has correct frames: [0, 17]
# Video 0XABB712C1939FBC5 has correct frames: [0, 17]
# Video 0XABB712C1939FBC5 has correct frames: [0, 17]
# INFO:root:Checking video 9605/10025: 0XABB9008CDCF5A14
# Checking video 9605/10025: 0XABB9008CDCF5A14
# Checking video 9605/10025: 0XABB9008CDCF5A14
# Checking video 9605/10025: 0XABB9008CDCF5A14
# Checking video 9605/10025: 0XABB9008CDCF5A14
# INFO:root:Video 0XABB9008CDCF5A14 has correct frames: [46, 62]
# Video 0XABB9008CDCF5A14 has correct frames: [46, 62]
# Video 0XABB9008CDCF5A14 has correct frames: [46, 62]
# Video 0XABB9008CDCF5A14 has correct frames: [46, 62]
# Video 0XABB9008CDCF5A14 has correct frames: [46, 62]
# INFO:root:Checking video 9606/10025: 0XABBDDF3F072EB3F
# Checking video 9606/10025: 0XABBDDF3F072EB3F
# Checking video 9606/10025: 0XABBDDF3F072EB3F
# Checking video 9606/10025: 0XABBDDF3F072EB3F
# Checking video 9606/10025: 0XABBDDF3F072EB3F
# INFO:root:Video 0XABBDDF3F072EB3F has correct frames: [87, 100]
# Video 0XABBDDF3F072EB3F has correct frames: [87, 100]
# Video 0XABBDDF3F072EB3F has correct frames: [87, 100]
# Video 0XABBDDF3F072EB3F has correct frames: [87, 100]
# Video 0XABBDDF3F072EB3F has correct frames: [87, 100]
# INFO:root:Checking video 9607/10025: 0XAC0EAEC877E4011
# Checking video 9607/10025: 0XAC0EAEC877E4011
# Checking video 9607/10025: 0XAC0EAEC877E4011
# Checking video 9607/10025: 0XAC0EAEC877E4011
# Checking video 9607/10025: 0XAC0EAEC877E4011
# INFO:root:Video 0XAC0EAEC877E4011 has correct frames: [78, 94]
# Video 0XAC0EAEC877E4011 has correct frames: [78, 94]
# Video 0XAC0EAEC877E4011 has correct frames: [78, 94]
# Video 0XAC0EAEC877E4011 has correct frames: [78, 94]
# Video 0XAC0EAEC877E4011 has correct frames: [78, 94]
# INFO:root:Checking video 9608/10025: 0XAC7C3A56AF70470
# Checking video 9608/10025: 0XAC7C3A56AF70470
# Checking video 9608/10025: 0XAC7C3A56AF70470
# Checking video 9608/10025: 0XAC7C3A56AF70470
# ...
# Video 0XF9A94878A64F70B has correct frames: [78, 100]
# Video 0XF9A94878A64F70B has correct frames: [78, 100]
# INFO:root:Checking video 9997/10025: 0XF9B19F076482852
# Checking video 9997/10025: 0XF9B19F076482852
# Checking video 9997/10025: 0XF9B19F076482852
# Checking video 9997/10025: 0XF9B19F076482852
# Checking video 9997/10025: 0XF9B19F076482852
# INFO:root:Video 0XF9B19F076482852 has correct frames: [51, 73]
# Video 0XF9B19F076482852 has correct frames: [51, 73]
# Video 0XF9B19F076482852 has correct frames: [51, 73]
# Video 0XF9B19F076482852 has correct frames: [51, 73]
# Video 0XF9B19F076482852 has correct frames: [51, 73]
# INFO:root:Checking video 9998/10025: 0XF9CA1C6A7687A8D
# Checking video 9998/10025: 0XF9CA1C6A7687A8D
# Checking video 9998/10025: 0XF9CA1C6A7687A8D
# Checking video 9998/10025: 0XF9CA1C6A7687A8D
# Checking video 9998/10025: 0XF9CA1C6A7687A8D
# INFO:root:Video 0XF9CA1C6A7687A8D has correct frames: [155, 170]
# Video 0XF9CA1C6A7687A8D has correct frames: [155, 170]
# Video 0XF9CA1C6A7687A8D has correct frames: [155, 170]
# Video 0XF9CA1C6A7687A8D has correct frames: [155, 170]
# Video 0XF9CA1C6A7687A8D has correct frames: [155, 170]
# INFO:root:Checking video 9999/10025: 0XF9E698E7CE7FEB1
# Checking video 9999/10025: 0XF9E698E7CE7FEB1
# Checking video 9999/10025: 0XF9E698E7CE7FEB1
# Checking video 9999/10025: 0XF9E698E7CE7FEB1
# Checking video 9999/10025: 0XF9E698E7CE7FEB1
# INFO:root:Video 0XF9E698E7CE7FEB1 has correct frames: [29, 43]
# Video 0XF9E698E7CE7FEB1 has correct frames: [29, 43]
# Video 0XF9E698E7CE7FEB1 has correct frames: [29, 43]
# Video 0XF9E698E7CE7FEB1 has correct frames: [29, 43]
# Video 0XF9E698E7CE7FEB1 has correct frames: [29, 43]
# INFO:root:Checking video 10000/10025: 0XF9E859F93775E1F
# Checking video 10000/10025: 0XF9E859F93775E1F
# Checking video 10000/10025: 0XF9E859F93775E1F
# Checking video 10000/10025: 0XF9E859F93775E1F
# Checking video 10000/10025: 0XF9E859F93775E1F
# INFO:root:Video 0XF9E859F93775E1F has correct frames: [2, 17]
# Video 0XF9E859F93775E1F has correct frames: [2, 17]
# Video 0XF9E859F93775E1F has correct frames: [2, 17]
# Video 0XF9E859F93775E1F has correct frames: [2, 17]
# Video 0XF9E859F93775E1F has correct frames: [2, 17]
# INFO:root:Checking video 10001/10025: 0XFA2F04D15D5D222
# Checking video 10001/10025: 0XFA2F04D15D5D222
# Checking video 10001/10025: 0XFA2F04D15D5D222
# Checking video 10001/10025: 0XFA2F04D15D5D222
# Checking video 10001/10025: 0XFA2F04D15D5D222
# INFO:root:Video 0XFA2F04D15D5D222 has correct frames: [51, 64]
# Video 0XFA2F04D15D5D222 has correct frames: [51, 64]
# Video 0XFA2F04D15D5D222 has correct frames: [51, 64]
# Video 0XFA2F04D15D5D222 has correct frames: [51, 64]
# Video 0XFA2F04D15D5D222 has correct frames: [51, 64]
# INFO:root:Checking video 10002/10025: 0XFA9EA2F22209920
# Checking video 10002/10025: 0XFA9EA2F22209920
# Checking video 10002/10025: 0XFA9EA2F22209920
# Checking video 10002/10025: 0XFA9EA2F22209920
# Checking video 10002/10025: 0XFA9EA2F22209920
# INFO:root:Video 0XFA9EA2F22209920 has correct frames: [76, 94]
# Video 0XFA9EA2F22209920 has correct frames: [76, 94]
# Video 0XFA9EA2F22209920 has correct frames: [76, 94]
# Video 0XFA9EA2F22209920 has correct frames: [76, 94]
# Video 0XFA9EA2F22209920 has correct frames: [76, 94]
# INFO:root:Checking video 10003/10025: 0XFAE70080273B8AD
# Checking video 10003/10025: 0XFAE70080273B8AD
# Checking video 10003/10025: 0XFAE70080273B8AD
# Checking video 10003/10025: 0XFAE70080273B8AD
# Checking video 10003/10025: 0XFAE70080273B8AD
# INFO:root:Video 0XFAE70080273B8AD has correct frames: [88, 103]
# Video 0XFAE70080273B8AD has correct frames: [88, 103]
# Video 0XFAE70080273B8AD has correct frames: [88, 103]
# Video 0XFAE70080273B8AD has correct frames: [88, 103]
# Video 0XFAE70080273B8AD has correct frames: [88, 103]
# INFO:root:Checking video 10004/10025: 0XFB550573BDD938A
# Checking video 10004/10025: 0XFB550573BDD938A
# Checking video 10004/10025: 0XFB550573BDD938A
# Checking video 10004/10025: 0XFB550573BDD938A
# Checking video 10004/10025: 0XFB550573BDD938A
# INFO:root:Video 0XFB550573BDD938A has correct frames: [54, 65]
# Video 0XFB550573BDD938A has correct frames: [54, 65]
# Video 0XFB550573BDD938A has correct frames: [54, 65]
# Video 0XFB550573BDD938A has correct frames: [54, 65]
# Video 0XFB550573BDD938A has correct frames: [54, 65]
# INFO:root:Checking video 10005/10025: 0XFBA686750D879E6
# Checking video 10005/10025: 0XFBA686750D879E6
# Checking video 10005/10025: 0XFBA686750D879E6
# Checking video 10005/10025: 0XFBA686750D879E6
# Checking video 10005/10025: 0XFBA686750D879E6
# INFO:root:Video 0XFBA686750D879E6 has correct frames: [54, 72]
# Video 0XFBA686750D879E6 has correct frames: [54, 72]
# Video 0XFBA686750D879E6 has correct frames: [54, 72]
# Video 0XFBA686750D879E6 has correct frames: [54, 72]
# Video 0XFBA686750D879E6 has correct frames: [54, 72]
# INFO:root:Checking video 10006/10025: 0XFBAA07C60AF61C2
# Checking video 10006/10025: 0XFBAA07C60AF61C2
# Checking video 10006/10025: 0XFBAA07C60AF61C2
# Checking video 10006/10025: 0XFBAA07C60AF61C2
# Checking video 10006/10025: 0XFBAA07C60AF61C2
# INFO:root:Video 0XFBAA07C60AF61C2 has correct frames: [41, 59]
# Video 0XFBAA07C60AF61C2 has correct frames: [41, 59]
# Video 0XFBAA07C60AF61C2 has correct frames: [41, 59]
# Video 0XFBAA07C60AF61C2 has correct frames: [41, 59]
# Video 0XFBAA07C60AF61C2 has correct frames: [41, 59]
# INFO:root:Checking video 10007/10025: 0XFBC3E8226CE1D25
# Checking video 10007/10025: 0XFBC3E8226CE1D25
# Checking video 10007/10025: 0XFBC3E8226CE1D25
# Checking video 10007/10025: 0XFBC3E8226CE1D25
# Checking video 10007/10025: 0XFBC3E8226CE1D25
# INFO:root:Video 0XFBC3E8226CE1D25 has correct frames: [76, 89]
# Video 0XFBC3E8226CE1D25 has correct frames: [76, 89]
# Video 0XFBC3E8226CE1D25 has correct frames: [76, 89]
# Video 0XFBC3E8226CE1D25 has correct frames: [76, 89]
# Video 0XFBC3E8226CE1D25 has correct frames: [76, 89]
# INFO:root:Checking video 10008/10025: 0XFBD22BB93EE05C1
# Checking video 10008/10025: 0XFBD22BB93EE05C1
# Checking video 10008/10025: 0XFBD22BB93EE05C1
# Checking video 10008/10025: 0XFBD22BB93EE05C1
# Checking video 10008/10025: 0XFBD22BB93EE05C1
# INFO:root:Video 0XFBD22BB93EE05C1 has correct frames: [39, 56]
# Video 0XFBD22BB93EE05C1 has correct frames: [39, 56]
# Video 0XFBD22BB93EE05C1 has correct frames: [39, 56]
# Video 0XFBD22BB93EE05C1 has correct frames: [39, 56]
# Video 0XFBD22BB93EE05C1 has correct frames: [39, 56]
# INFO:root:Checking video 10009/10025: 0XFC193B557F698B6
# Checking video 10009/10025: 0XFC193B557F698B6
# Checking video 10009/10025: 0XFC193B557F698B6
# Checking video 10009/10025: 0XFC193B557F698B6
# Checking video 10009/10025: 0XFC193B557F698B6
# INFO:root:Video 0XFC193B557F698B6 has correct frames: [45, 65]
# Video 0XFC193B557F698B6 has correct frames: [45, 65]
# Video 0XFC193B557F698B6 has correct frames: [45, 65]
# Video 0XFC193B557F698B6 has correct frames: [45, 65]
# Video 0XFC193B557F698B6 has correct frames: [45, 65]
# INFO:root:Checking video 10010/10025: 0XFC2F8325071BDC2
# Checking video 10010/10025: 0XFC2F8325071BDC2
# Checking video 10010/10025: 0XFC2F8325071BDC2
# Checking video 10010/10025: 0XFC2F8325071BDC2
# Checking video 10010/10025: 0XFC2F8325071BDC2
# INFO:root:Video 0XFC2F8325071BDC2 has correct frames: [45, 59]
# Video 0XFC2F8325071BDC2 has correct frames: [45, 59]
# Video 0XFC2F8325071BDC2 has correct frames: [45, 59]
# Video 0XFC2F8325071BDC2 has correct frames: [45, 59]
# Video 0XFC2F8325071BDC2 has correct frames: [45, 59]
# INFO:root:Checking video 10011/10025: 0XFC6499D603B9E1E
# Checking video 10011/10025: 0XFC6499D603B9E1E
# Checking video 10011/10025: 0XFC6499D603B9E1E
# Checking video 10011/10025: 0XFC6499D603B9E1E
# Checking video 10011/10025: 0XFC6499D603B9E1E
# INFO:root:Video 0XFC6499D603B9E1E has correct frames: [116, 136]
# Video 0XFC6499D603B9E1E has correct frames: [116, 136]
# Video 0XFC6499D603B9E1E has correct frames: [116, 136]
# Video 0XFC6499D603B9E1E has correct frames: [116, 136]
# Video 0XFC6499D603B9E1E has correct frames: [116, 136]
# INFO:root:Checking video 10012/10025: 0XFCB2810C93F7F5D
# Checking video 10012/10025: 0XFCB2810C93F7F5D
# Checking video 10012/10025: 0XFCB2810C93F7F5D
# Checking video 10012/10025: 0XFCB2810C93F7F5D
# Checking video 10012/10025: 0XFCB2810C93F7F5D
# INFO:root:Video 0XFCB2810C93F7F5D has correct frames: [81, 90]
# Video 0XFCB2810C93F7F5D has correct frames: [81, 90]
# Video 0XFCB2810C93F7F5D has correct frames: [81, 90]
# Video 0XFCB2810C93F7F5D has correct frames: [81, 90]
# Video 0XFCB2810C93F7F5D has correct frames: [81, 90]
# INFO:root:Checking video 10013/10025: 0XFCC2AF8E23AFBA8
# Checking video 10013/10025: 0XFCC2AF8E23AFBA8
# Checking video 10013/10025: 0XFCC2AF8E23AFBA8
# Checking video 10013/10025: 0XFCC2AF8E23AFBA8
# Checking video 10013/10025: 0XFCC2AF8E23AFBA8
# INFO:root:Video 0XFCC2AF8E23AFBA8 has correct frames: [41, 57]
# Video 0XFCC2AF8E23AFBA8 has correct frames: [41, 57]
# Video 0XFCC2AF8E23AFBA8 has correct frames: [41, 57]
# Video 0XFCC2AF8E23AFBA8 has correct frames: [41, 57]
# Video 0XFCC2AF8E23AFBA8 has correct frames: [41, 57]
# INFO:root:Checking video 10014/10025: 0XFCDC29AA6B8E83B
# Checking video 10014/10025: 0XFCDC29AA6B8E83B
# Checking video 10014/10025: 0XFCDC29AA6B8E83B
# Checking video 10014/10025: 0XFCDC29AA6B8E83B
# Checking video 10014/10025: 0XFCDC29AA6B8E83B
# INFO:root:Video 0XFCDC29AA6B8E83B has correct frames: [75, 89]
# Video 0XFCDC29AA6B8E83B has correct frames: [75, 89]
# Video 0XFCDC29AA6B8E83B has correct frames: [75, 89]
# Video 0XFCDC29AA6B8E83B has correct frames: [75, 89]
# Video 0XFCDC29AA6B8E83B has correct frames: [75, 89]
# INFO:root:Checking video 10015/10025: 0XFCF860A2A9C211
# Checking video 10015/10025: 0XFCF860A2A9C211
# Checking video 10015/10025: 0XFCF860A2A9C211
# Checking video 10015/10025: 0XFCF860A2A9C211
# Checking video 10015/10025: 0XFCF860A2A9C211
# INFO:root:Video 0XFCF860A2A9C211 has correct frames: [47, 63]
# Video 0XFCF860A2A9C211 has correct frames: [47, 63]
# Video 0XFCF860A2A9C211 has correct frames: [47, 63]
# Video 0XFCF860A2A9C211 has correct frames: [47, 63]
# Video 0XFCF860A2A9C211 has correct frames: [47, 63]
# INFO:root:Checking video 10016/10025: 0XFD06AD51C6DA6E5
# Checking video 10016/10025: 0XFD06AD51C6DA6E5
# Checking video 10016/10025: 0XFD06AD51C6DA6E5
# Checking video 10016/10025: 0XFD06AD51C6DA6E5
# Checking video 10016/10025: 0XFD06AD51C6DA6E5
# INFO:root:Video 0XFD06AD51C6DA6E5 has correct frames: [47, 62]
# Video 0XFD06AD51C6DA6E5 has correct frames: [47, 62]
# Video 0XFD06AD51C6DA6E5 has correct frames: [47, 62]
# Video 0XFD06AD51C6DA6E5 has correct frames: [47, 62]
# Video 0XFD06AD51C6DA6E5 has correct frames: [47, 62]
# INFO:root:Checking video 10017/10025: 0XFD513BE6D49349F
# Checking video 10017/10025: 0XFD513BE6D49349F
# Checking video 10017/10025: 0XFD513BE6D49349F
# Checking video 10017/10025: 0XFD513BE6D49349F
# Checking video 10017/10025: 0XFD513BE6D49349F
# INFO:root:Video 0XFD513BE6D49349F has correct frames: [43, 59]
# Video 0XFD513BE6D49349F has correct frames: [43, 59]
# Video 0XFD513BE6D49349F has correct frames: [43, 59]
# Video 0XFD513BE6D49349F has correct frames: [43, 59]
# Video 0XFD513BE6D49349F has correct frames: [43, 59]
# INFO:root:Checking video 10018/10025: 0XFD9464CF9E40B66
# Checking video 10018/10025: 0XFD9464CF9E40B66
# Checking video 10018/10025: 0XFD9464CF9E40B66
# Checking video 10018/10025: 0XFD9464CF9E40B66
# Checking video 10018/10025: 0XFD9464CF9E40B66
# INFO:root:Video 0XFD9464CF9E40B66 has correct frames: [106, 121]
# Video 0XFD9464CF9E40B66 has correct frames: [106, 121]
# Video 0XFD9464CF9E40B66 has correct frames: [106, 121]
# Video 0XFD9464CF9E40B66 has correct frames: [106, 121]
# Video 0XFD9464CF9E40B66 has correct frames: [106, 121]
# INFO:root:Checking video 10019/10025: 0XFDB874C30A9C923
# Checking video 10019/10025: 0XFDB874C30A9C923
# Checking video 10019/10025: 0XFDB874C30A9C923
# Checking video 10019/10025: 0XFDB874C30A9C923
# Checking video 10019/10025: 0XFDB874C30A9C923
# INFO:root:Video 0XFDB874C30A9C923 has correct frames: [53, 73]
# Video 0XFDB874C30A9C923 has correct frames: [53, 73]
# Video 0XFDB874C30A9C923 has correct frames: [53, 73]
# Video 0XFDB874C30A9C923 has correct frames: [53, 73]
# Video 0XFDB874C30A9C923 has correct frames: [53, 73]
# INFO:root:Checking video 10020/10025: 0XFDC39A88895DE1E
# Checking video 10020/10025: 0XFDC39A88895DE1E
# Checking video 10020/10025: 0XFDC39A88895DE1E
# Checking video 10020/10025: 0XFDC39A88895DE1E
# Checking video 10020/10025: 0XFDC39A88895DE1E
# INFO:root:Video 0XFDC39A88895DE1E has correct frames: [42, 63]
# Video 0XFDC39A88895DE1E has correct frames: [42, 63]
# Video 0XFDC39A88895DE1E has correct frames: [42, 63]
# Video 0XFDC39A88895DE1E has correct frames: [42, 63]
# Video 0XFDC39A88895DE1E has correct frames: [42, 63]
# INFO:root:Checking video 10021/10025: 0XFDFBA5702E94ABF
# Checking video 10021/10025: 0XFDFBA5702E94ABF
# Checking video 10021/10025: 0XFDFBA5702E94ABF
# Checking video 10021/10025: 0XFDFBA5702E94ABF
# Checking video 10021/10025: 0XFDFBA5702E94ABF
# INFO:root:Video 0XFDFBA5702E94ABF has correct frames: [100, 117]
# Video 0XFDFBA5702E94ABF has correct frames: [100, 117]
# Video 0XFDFBA5702E94ABF has correct frames: [100, 117]
# Video 0XFDFBA5702E94ABF has correct frames: [100, 117]
# Video 0XFDFBA5702E94ABF has correct frames: [100, 117]
# INFO:root:Checking video 10022/10025: 0XFDFD17B7CCFE5AF
# Checking video 10022/10025: 0XFDFD17B7CCFE5AF
# Checking video 10022/10025: 0XFDFD17B7CCFE5AF
# Checking video 10022/10025: 0XFDFD17B7CCFE5AF
# Checking video 10022/10025: 0XFDFD17B7CCFE5AF
# INFO:root:Video 0XFDFD17B7CCFE5AF has correct frames: [66, 85]
# Video 0XFDFD17B7CCFE5AF has correct frames: [66, 85]
# Video 0XFDFD17B7CCFE5AF has correct frames: [66, 85]
# Video 0XFDFD17B7CCFE5AF has correct frames: [66, 85]
# Video 0XFDFD17B7CCFE5AF has correct frames: [66, 85]
# INFO:root:Checking video 10023/10025: 0XFE6E32991136338
# Checking video 10023/10025: 0XFE6E32991136338
# Checking video 10023/10025: 0XFE6E32991136338
# Checking video 10023/10025: 0XFE6E32991136338
# Checking video 10023/10025: 0XFE6E32991136338
# INFO:root:Video 0XFE6E32991136338 has correct frames: [31, 45]
# Video 0XFE6E32991136338 has correct frames: [31, 45]
# Video 0XFE6E32991136338 has correct frames: [31, 45]
# Video 0XFE6E32991136338 has correct frames: [31, 45]
# Video 0XFE6E32991136338 has correct frames: [31, 45]
# INFO:root:Checking video 10024/10025: 0XFE83FF3D3B13C3A
# Checking video 10024/10025: 0XFE83FF3D3B13C3A
# Checking video 10024/10025: 0XFE83FF3D3B13C3A
# Checking video 10024/10025: 0XFE83FF3D3B13C3A
# Checking video 10024/10025: 0XFE83FF3D3B13C3A
# INFO:root:Video 0XFE83FF3D3B13C3A has correct frames: [49, 67]
# Video 0XFE83FF3D3B13C3A has correct frames: [49, 67]
# Video 0XFE83FF3D3B13C3A has correct frames: [49, 67]
# Video 0XFE83FF3D3B13C3A has correct frames: [49, 67]
# Video 0XFE83FF3D3B13C3A has correct frames: [49, 67]
# INFO:root:Checking video 10025/10025: 0XFEBEEFF93F6FEB9
# Checking video 10025/10025: 0XFEBEEFF93F6FEB9
# Checking video 10025/10025: 0XFEBEEFF93F6FEB9
# Checking video 10025/10025: 0XFEBEEFF93F6FEB9
# Checking video 10025/10025: 0XFEBEEFF93F6FEB9
# INFO:root:Video 0XFEBEEFF93F6FEB9 has correct frames: [25, 38]
# Video 0XFEBEEFF93F6FEB9 has correct frames: [25, 38]
# Video 0XFEBEEFF93F6FEB9 has correct frames: [25, 38]
# Video 0XFEBEEFF93F6FEB9 has correct frames: [25, 38]
# Video 0XFEBEEFF93F6FEB9 has correct frames: [25, 38]
# INFO:root:
# [Summary]
#
# [Summary]
#
# [Summary]
#
# [Summary]
#
# [Summary]
# INFO:root:Total folders checked: 10025
# Total folders checked: 10025
# Total folders checked: 10025
# Total folders checked: 10025
# Total folders checked: 10025
# INFO:root:Expected folders: 10025
# Expected folders: 10025
# Expected folders: 10025
# Expected folders: 10025
# Expected folders: 10025
# INFO:root:Mismatches found: 0
# Mismatches found: 0
# Mismatches found: 0
# Mismatches found: 0
# Mismatches found: 0
# INFO:root:All folders contain the correct 2 frames matching the CSV.
# All folders contain the correct 2 frames matching the CSV.
# All folders contain the correct 2 frames matching the CSV.
# All folders contain the correct 2 frames matching the CSV.
# All folders contain the correct 2 frames matching the CSV.
# Verification complete. Check /content/drive/MyDrive/✨ GP ✨/EchoNet_Dataset/EchoNet-Dynamic/verify_masktracings_log_20250509_180348.txt for details.
